# %% [markdown]
# ### Imports and Configs

# %%
# Deafault Imports
import os
import logging
import functools
import warnings as wr
import numpy as np
import random as rnd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras as tfk
from keras import layers as tkl
from keras import models as tkm
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# !wget https://storage.googleapis.com/storage.barbiero.dev/public_data_clean.npz
# Out:
# --2023-11-09 20:09:22--  https://storage.googleapis.com/storage.barbiero.dev/public_data_clean.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.24.207, 142.251.10.207, 142.251.12.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.24.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 536546306 (512M) [application/octet-stream]
# Saving to: ‘public_data_clean.npz’
#
# public_data_clean.n 100%[===================>] 511.69M  12.1MB/s    in 44s
#
# 2023-11-09 20:10:09 (11.5 MB/s) - ‘public_data_clean.npz’ saved [536546306/536546306]

# %%
# Random Configuration - All
RND = True
if not RND:
  SEED = 76998669
  os.environ['PYTHONHASHSEED'] = str(SEED)
  tf.compat.v1.set_random_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rnd.seed(SEED)

# OS Configuration
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

# Warning Congiguration
wr.simplefilter(action='ignore', category=FutureWarning)
wr.simplefilter(action='ignore', category=Warning)

# TensorFlow Configuration
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
# Plotting Functions
def plot_losses(history, figsize, name_jpg):
  best_epoch = np.argmax(history['val_accuracy'])
  fig, axes = plt.subplots(2,1, figsize=figsize, dpi=200)

  axes[0].plot(history['loss'], label='Training Loss', color='#9859C5', alpha=.8)
  axes[0].plot(history['val_loss'], label='Validation Loss', color='#4D61E2', alpha=.8)
  axes[0].set_title('Loss')
  axes[0].legend()
  axes[0].grid(alpha=.3)

  axes[1].plot(history['accuracy'], label='Training Accuracy', color='#9859C5', alpha=.8)
  axes[1].plot(history['val_accuracy'], label='Validation Accuracy', color='#4D61E2', alpha=.8)
  axes[1].plot(best_epoch, history['val_accuracy'][best_epoch], marker='d', alpha=0.8, markersize=10, color='#4D61E2')
  axes[1].set_title('Accuracy')
  axes[1].legend()
  axes[1].grid(alpha=.3)

  plt.savefig(name_jpg)
  plt.show()

def plot_images(images, labels, index=0, rows=1, cols=1, normalized=False):
  data_rescaling = tkl.Rescaling(scale=1./255)
  if normalized==False:
    IMGS_= data_rescaling(images)
  size = rows*cols
  diff = len(images)-(size+index)
  if diff <= 0:
    size = len(images)-index
    plt.figure(figsize=(cols,rows), dpi=200)
    for i in range(size):
      ax = plt.subplot(rows, cols, i + 1)
      plt.imshow(IMGS_[index + i])
      plt.title(labels[i], fontdict={"fontsize":5}, pad=2)
      plt.axis("off")

#plot_images(IMGS[:25], LBLS[:25], 0, 5, 5)

# %% [markdown]
# ### Data Initizialization

# %%
# Initializate
DATA = np.load('public_data_clean.npz', allow_pickle=True)
KEYS = list(DATA.keys())

IMGS = np.array(DATA[KEYS[0]])
LIMG = len(IMGS)
LBLS = np.array(DATA[KEYS[1]])
LBLS_ = np.array(DATA[KEYS[1]])
LLBL = len(LBLS)

BATCH = 32
TEST_PERC = 0.15
VALI_PERC = 0.15

MPLBL = {0: "healthy", 1: "unhealthy"}
RMLBL = {"healthy": 0, "unhealthy": 1}
LBLS = np.array([RMLBL[l] for l in LBLS])
LBLS = tfk.utils.to_categorical(LBLS, len(np.unique(LBLS)))

print('Images: ', LIMG)
print('Labels: ', LLBL)
print()
# Out:
# Images:  4850
# Labels:  4850

# %%
# Augmentation Andrea
def balance_sets_over(images,labels):
    datagen = ImageDataGenerator(
        rotation_range=359,
        horizontal_flip=True
    )

    negative_n = functools.reduce(lambda a, b: a+b, labels)
    print(negative_n)
    positive_n = len(images) - negative_n
    print(positive_n)
    to_add = int(positive_n - negative_n)
    to_delete = to_add
    X_n = images[labels == 1]
    y_n = labels[labels == 1]

    for img in datagen.flow(X_n,y_n,batch_size=1):
      if to_add <= 0:
        break
      to_add -= 1
      images = np.insert(images,0,img[0][0],axis=0)
      labels = np.insert(labels,0,img[1][0],axis=0)

    print(functools.reduce(lambda a, b: a+b, labels))
    print(len(images) - negative_n)
    return images,labels

def gen_negatives(images,labels,to_generate):
    datagen = ImageDataGenerator(
        rotation_range=360,
        horizontal_flip=True,
        vertical_flip=True)
    X_n = images[labels == 1]
    y_n = labels[labels == 1]
    to_add = to_generate
    for img in datagen.flow(X_n,y_n,batch_size=1):
      if to_add <= 0:
        break
      to_add -= 1
      images = np.insert(images,0,img[0][0],axis=0)
      labels = np.insert(labels,0,img[1][0],axis=0)
    return images,labels

images, labels = gen_negatives(IMGS,LBLS,700)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-02ed88c00fd2> in <cell line: 44>()
#      42     return images,labels
#      43
# ---> 44 images, labels = gen_negatives(IMGS,LBLS_,700)
#
# <ipython-input-6-02ed88c00fd2> in gen_negatives(images, labels, to_generate)
#      34     y_n = labels[labels == 1]
#      35     to_add = to_generate
# ---> 36     for img in datagen.flow(X_n,y_n,batch_size=1):
#      37       if to_add <= 0:
#      38         break
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in flow(self, x, y, batch_size, shuffle, sample_weight, seed, save_to_dir, save_prefix, save_format, ignore_class_split, subset)
#    1543
#    1544         """
# -> 1545         return NumpyArrayIterator(
#    1546             x,
#    1547             y,
#
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py in __init__(self, x, y, image_data_generator, batch_size, shuffle, sample_weight, seed, data_format, save_to_dir, save_prefix, save_format, subset, ignore_class_split, dtype)
#     756         self.x_misc = x_misc
#     757         if self.x.ndim != 4:
# --> 758             raise ValueError(
#     759                 "Input data in `NumpyArrayIterator` "
#     760                 "should have rank 4. You passed an array "
#
# ValueError: ('Input data in `NumpyArrayIterator` should have rank 4. You passed an array with shape', (0, 4850, 96, 96, 3))

# %%
def pick_random_label(i, lbls, lbl):
  if lbls[i] == lbl:
    return True
  else:
    return False

def manual_augmentation(imgs, lbls):
    global LBLS, IMGS

    cardinality = pd.DataFrame(lbls, columns=['class'])['class'].value_counts()       # Store the Cardinality of the SETS "healthy", "unhealthy"
    ch = cardinality['healthy']
    cu = cardinality['unhealthy']
    diff = ch-cu
    print(cardinality)

    i_arr = []
    ROWS = 2
    COLS = 4
    augm = []
    augm_lbl = []

    if diff > 0:
      print("Augment the Unhealthy: ", diff, int(diff/7))
      for z in range(int(diff/7)):
        index = rnd.randint(0, len(lbls)-1)
        while not pick_random_label(index, lbls, "unhealthy") or index in i_arr:
          i_arr.append(index)
          index = rnd.randint(0, len(lbls)-1)

        if lbls[index] == "unhealthy":
          i_arr.append(index)
          img = imgs[index]
          for row in range(ROWS):
              for col in range(COLS):
                  img = np.rot90(img)
                  if row==0 and col==3:
                      continue
                  augm.append(img)
                  augm_lbl.append(lbls[index])
              if row == 0:
                  img = np.flipud(img)

    else:
      print("Augment the Healthy: ", diff)
      for z in range(int(-diff/7)):
        index = rnd.randint(0, len(lbls)-1)
        while not pick_random_label(index, lbls, "unhealthy") or index in i_arr:
          i_arr.append(index)
          index = rnd.randint(0, len(lbls)-1)

        if lbls[index] == "unhealthy":
          i_arr.append(index)
          img = imgs[index]
          for row in range(ROWS):
              for col in range(COLS):
                  img = np.rot90(img)
                  if row==0 and col==3:
                      continue
                  augm.append(img)
                  augm_lbl.append(lbls[index])
              if row == 0:
                  img = np.flipud(img)


    print(len(augm), len(augm_lbl), len(i_arr))
    plot_images(augm[:7], augm_lbl[:7],0,1,7)

    augm_lbl = list(map(lambda x: 0 if x == "healthy" else 1, augm_lbl))
    augm_lbl = tfk.utils.to_categorical(augm_lbl, len(np.unique(LBLS)))

    for i in range(len(augm_lbl)):
      IMGS = np.append(IMGS, [augm[i]], axis=0)
      LBLS = np.append(LBLS, [augm_lbl[i]], axis=0)


manual_augmentation(IMGS, LBLS_)
print(len(IMGS),len(LBLS), len(LBLS_))
# Out:
# healthy      3060
# unhealthy    1790
# Name: class, dtype: int64
# Augment the Unhealthy:  1270 181
# 1267 1267 519
# 6117 6117 4850

# %%
plot_images(IMGS[-7:], LBLS[-7:], 0, 1, 7)

# %%
LBLS__ = list(map(lambda x: "unhealthy" if x[0]==0. and x[1]==1. else "healthy", LBLS))
print(pd.DataFrame(LBLS__, columns=['class'])['class'].value_counts() )
# Out:
# healthy      3060
# unhealthy    3057
# Name: class, dtype: int64

# %%
np.savez_compressed("augm_alex.npz", IMGS, LBLS)

# %%
# Split the Data Set into Training XT YT, Validation XV YV, Test XTE YTE
Xtrv, XTE, Ytrv, YTE = train_test_split(
    IMGS,
    LBLS,
    test_size=int(TEST_PERC * LIMG),
    **({"random_state":SEED} if not RND else {}),
    stratify=LBLS
)

XT, XV, YT, YV = train_test_split(
    Xtrv,
    Ytrv,
    test_size=int(VALI_PERC*LIMG),
    **({"random_state":SEED} if not RND else {}),
    stratify=Ytrv
)

# Shapes
print('Training Set Shape: ', XT.shape, YT.shape)
print('Validation Set Shape: ', XV.shape, YV.shape)
print('Test Set Shape: ', XTE.shape, YTE.shape)
print()

# Get the Shape of IN OUT
input_shape = XT.shape[1:]
output_shape = YT.shape[1]                                                        # Enable for MultiClass Problem

print(f'Input shape of the Network: {input_shape}')
print(f'Output shape of the Network: {output_shape}')
print()
# Out:
# Training Set Shape:  (4663, 96, 96, 3) (4663, 2)
# Validation Set Shape:  (727, 96, 96, 3) (727, 2)
# Test Set Shape:  (727, 96, 96, 3) (727, 2)
#
# Input shape of the Network: (96, 96, 3)
# Output shape of the Network: 2

# %% [markdown]
# **Augmentation Layers**

# %%
data_rescaling = tkl.Rescaling(scale=1./255)                                      # Normalize the Images from 0..255 to 0..1
data_backscaling = tkl.Rescaling(scale=1.*255)                                    # Normalize the Images from 0..1 to 0..255

data_rescaling_c = tkl.Rescaling(scale=1./127.5, offset=-1)                       # Normalize the Images from 0..255 to -1..1
data_backscaling_c = tkl.Rescaling(scale=1.*127.5, offset=1)                      # Normalize the Images from -1..1 to 0..255

data_alex_augmentation = tkm.Sequential([
  tkl.RandomFlip('horizontal'),
  tkl.RandomRotation(359),
  tkl.RandomBrightness(factor=0.35),
  tkl.RandomContrast(factor=(0,0.9))
])

# %% [markdown]
# ### Training

# %% [markdown]
# **Define the Model**

# %%
from keras.applications.convnext import preprocess_input

def apple_elixir_model(input_shape, output_shape):

  preprocessing = tfk.Sequential([
      tkl.RandomTranslation(height_factor=(-0.3,0.3),width_factor=(-0.3,0.3)),
      tkl.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2)),
      tkl.RandomFlip('horizontal'),
      tkl.RandomRotation(factor=359)
    ], name='preprocessing'
  )

  # TO CHANGE - res of the Model
  res = tfk.applications.ConvNeXtBase(
    input_shape=input_shape,
    include_top=False,
    weights="imagenet",
    classes=2,
    classifier_activation='softmax'
  )

  res.trainable = False
  input_layer = tkl.Input(input_shape)

  # x = data_rescaling_c(input_layer)
  x = preprocess_input(input_layer)
  x = preprocessing(x)
  x = res(x)
  x = tkl.GlobalAveragePooling2D()(x)
  x = tkl.Dense(units=128,activation=tkl.LeakyReLU(alpha=0.3))(x)              # maybe we have to use leakyrelu
  x = tkl.Dropout(0.7)(x)

  # x = tkl.Dense(units=2048,activation='relu')(x)
  # x = tkl.Dense(units=2048,activation='relu')(x)
  # x = tkl.Dense(units=1024,activation='relu')(x)

  output_layer = tkl.Dense(units=output_shape,activation='softmax')(x)
  model =tfk.Model(input_layer, output_layer)

  # Compile the model
  model.compile(
      loss=tfk.losses.CategoricalCrossentropy(),
      optimizer=tfk.optimizers.Nadam(learning_rate=0.0001, weight_decay=0.001),
      metrics=['accuracy']
  )

  return model

model = apple_elixir_model(input_shape,output_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 16s 0us/step

# %% [markdown]
# **Train the Model**

# %%
# Train the model
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=20,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',                         # Metric to monitor (validation mean squared error in this case)
    patience=5,                                     # Number of epochs with no improvement after which learning rate will be reduced
    factor=0.85,                                    # Factor by which the learning rate will be reduced (0.999 in this case)
    mode='max',                                     # Mode to decide when to reduce learning rate ('min' means reduce when metric stops decreasing)
    min_lr=1e-7                                     # Minimum learning rate
)

callbacks = [early_stopping,lr_scheduler]

history = model.fit(
    x = XT,
    y = YT,
    batch_size = 32,
    epochs = 300,
    validation_data = (XV, YV),
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 146/146 [==============================] - 70s 263ms/step - loss: 0.9818 - accuracy: 0.5481 - val_loss: 0.6722 - val_accuracy: 0.6135 - lr: 1.0000e-04
# Epoch 2/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.7217 - accuracy: 0.6331 - val_loss: 0.5570 - val_accuracy: 0.7043 - lr: 1.0000e-04
# Epoch 3/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.6606 - accuracy: 0.6648 - val_loss: 0.5429 - val_accuracy: 0.7153 - lr: 1.0000e-04
# Epoch 4/300
# 146/146 [==============================] - 23s 154ms/step - loss: 0.6309 - accuracy: 0.6745 - val_loss: 0.5022 - val_accuracy: 0.7510 - lr: 1.0000e-04
# Epoch 5/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.6009 - accuracy: 0.6974 - val_loss: 0.4844 - val_accuracy: 0.7772 - lr: 1.0000e-04
# Epoch 6/300
# 146/146 [==============================] - 22s 152ms/step - loss: 0.5870 - accuracy: 0.7021 - val_loss: 0.5468 - val_accuracy: 0.7084 - lr: 1.0000e-04
# Epoch 7/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.5573 - accuracy: 0.7225 - val_loss: 0.4668 - val_accuracy: 0.7895 - lr: 1.0000e-04
# Epoch 8/300
# 146/146 [==============================] - 25s 172ms/step - loss: 0.5578 - accuracy: 0.7257 - val_loss: 0.4595 - val_accuracy: 0.7909 - lr: 1.0000e-04
# Epoch 9/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.5569 - accuracy: 0.7289 - val_loss: 0.4617 - val_accuracy: 0.7923 - lr: 1.0000e-04
# Epoch 10/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.5317 - accuracy: 0.7369 - val_loss: 0.4457 - val_accuracy: 0.8033 - lr: 1.0000e-04
# Epoch 11/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.5142 - accuracy: 0.7444 - val_loss: 0.4201 - val_accuracy: 0.8129 - lr: 1.0000e-04
# Epoch 12/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.5181 - accuracy: 0.7480 - val_loss: 0.4064 - val_accuracy: 0.8253 - lr: 1.0000e-04
# Epoch 13/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.5219 - accuracy: 0.7431 - val_loss: 0.4157 - val_accuracy: 0.8184 - lr: 1.0000e-04
# Epoch 14/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.5068 - accuracy: 0.7564 - val_loss: 0.4078 - val_accuracy: 0.8157 - lr: 1.0000e-04
# Epoch 15/300
# 146/146 [==============================] - 24s 168ms/step - loss: 0.5054 - accuracy: 0.7459 - val_loss: 0.4161 - val_accuracy: 0.8143 - lr: 1.0000e-04
# Epoch 16/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.5042 - accuracy: 0.7512 - val_loss: 0.4144 - val_accuracy: 0.8184 - lr: 1.0000e-04
# Epoch 17/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.5045 - accuracy: 0.7536 - val_loss: 0.3835 - val_accuracy: 0.8294 - lr: 1.0000e-04
# Epoch 18/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4886 - accuracy: 0.7635 - val_loss: 0.3949 - val_accuracy: 0.8212 - lr: 1.0000e-04
# Epoch 19/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.4754 - accuracy: 0.7686 - val_loss: 0.3809 - val_accuracy: 0.8281 - lr: 1.0000e-04
# Epoch 20/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.
300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4424 - accuracy: 0.7903 - val_loss: 0.3810 - val_accuracy: 0.8391 - lr: 6.1412e-05
# Epoch 42/300
# 146/146 [==============================] - 24s 168ms/step - loss: 0.4379 - accuracy: 0.7980 - val_loss: 0.3701 - val_accuracy: 0.8404 - lr: 6.1412e-05
# Epoch 43/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4323 - accuracy: 0.7956 - val_loss: 0.3688 - val_accuracy: 0.8404 - lr: 6.1412e-05
# Epoch 44/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4383 - accuracy: 0.7973 - val_loss: 0.3906 - val_accuracy: 0.8322 - lr: 6.1412e-05
# Epoch 45/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.4392 - accuracy: 0.7916 - val_loss: 0.3538 - val_accuracy: 0.8473 - lr: 6.1412e-05
# Epoch 46/300
# 146/146 [==============================] - 22s 152ms/step - loss: 0.4333 - accuracy: 0.7954 - val_loss: 0.3593 - val_accuracy: 0.8459 - lr: 5.2201e-05
# Epoch 47/300
# 146/146 [==============================] - 22s 150ms/step - loss: 0.4272 - accuracy: 0.7999 - val_loss: 0.3673 - val_accuracy: 0.8459 - lr: 5.2201e-05
# Epoch 48/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4328 - accuracy: 0.7928 - val_loss: 0.3707 - val_accuracy: 0.8459 - lr: 5.2201e-05
# Epoch 49/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.4257 - accuracy: 0.8053 - val_loss: 0.3507 - val_accuracy: 0.8487 - lr: 5.2201e-05
# Epoch 50/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4382 - accuracy: 0.7905 - val_loss: 0.3663 - val_accuracy: 0.8514 - lr: 5.2201e-05
# Epoch 51/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4252 - accuracy: 0.7976 - val_loss: 0.3751 - val_accuracy: 0.8473 - lr: 4.4371e-05
# Epoch 52/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4265 - accuracy: 0.7926 - val_loss: 0.3596 - val_accuracy: 0.8514 - lr: 4.4371e-05
# Epoch 53/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4271 - accuracy: 0.8029 - val_loss: 0.3584 - val_accuracy: 0.8528 - lr: 4.4371e-05
# Epoch 54/300
# 146/146 [==============================] - 24s 168ms/step - loss: 0.4321 - accuracy: 0.7879 - val_loss: 0.3602 - val_accuracy: 0.8514 - lr: 4.4371e-05
# Epoch 55/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4375 - accuracy: 0.7931 - val_loss: 0.3472 - val_accuracy: 0.8446 - lr: 4.4371e-05
# Epoch 56/300
# 146/146 [==============================] - 24s 166ms/step - loss: 0.4231 - accuracy: 0.8029 - val_loss: 0.3565 - val_accuracy: 0.8528 - lr: 3.7715e-05
# Epoch 57/300
# 146/146 [==============================] - 22s 151ms/step - loss: 0.4201 - accuracy: 0.8016 - val_loss: 0.3617 - val_accuracy: 0.8487 - lr: 3.7715e-05
# Epoch 58/300
# 146/146 [==============================] - 24s 168ms/step - loss: 0.4363 - accuracy: 0.7918 - val_loss: 0.3532 - val_accuracy: 0.8514 - lr: 3.7715e-05
# Epoch 59/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4255 - accuracy: 0.7980 - val_loss: 0.3824 - val_accuracy: 0.8377 - lr: 3.7715e-05
# Epoch 60/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4204 - accuracy: 0.8068 - val_loss: 0.3550 - val_accuracy: 0.8514 - lr: 3.7715e-05

# %% [markdown]
# ### Saving and Plotting

# %%
NAME_MODEL = "ConvNeXtV2_004"
NAME_PLOT = NAME_MODEL + "_plot"

# %% [markdown]
# **Plot Loss + Test Prediction Accuracy**

# %%
plot_losses(history, (20,5), NAME_PLOT)

test_predictions = model.predict(XTE, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)
test_gt = np.argmax(YTE, axis=-1)
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-2303abaab143> in <cell line: 3>()
#       1 plot_losses(history, (20,5), NAME_PLOT)
#       2
# ----> 3 test_predictions = model.predict(XTE, verbose=0)
#       4 test_predictions = np.argmax(test_predictions, axis=-1)
#       5 test_gt = np.argmax(YTE, axis=-1)
#
# NameError: name 'model' is not defined

# %% [markdown]
# **Plot Confusion Matrix**

# %%
# Compute the confusion matrix
test_predictions = model.predict(XT, verbose=0)
cm = confusion_matrix(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1))
precision = precision_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(5, 4), dpi=200)
sns.heatmap(cm.T, annot=True, cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.8381
# Precision: 0.8404
# Recall: 0.8381
# F1: 0.8378

# %%
model.save(NAME_MODEL)

# %%
# !zip -r {NAME_MODEL}.zip {NAME_MODEL} {NAME_PLOT}.png
# Out:
# 	zip warning: name not matched: ConvNeXtV2_004_plot.png
#   adding: ConvNeXtV2_004/ (stored 0%)
#   adding: ConvNeXtV2_004/keras_metadata.pb (deflated 96%)
#   adding: ConvNeXtV2_004/variables/ (stored 0%)
#   adding: ConvNeXtV2_004/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXtV2_004/variables/variables.index (deflated 77%)
#   adding: ConvNeXtV2_004/fingerprint.pb (stored 0%)
#   adding: ConvNeXtV2_004/saved_model.pb (deflated 92%)
#   adding: ConvNeXtV2_004/assets/ (stored 0%)

# %%
del model

# %% [markdown]
# ### Tuning

# %%
ft_model = tfk.models.load_model(NAME_MODEL)

# %%
ft_model.get_layer('convnext_base').trainable = True
c = 0
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers):
   c += 1

print(c)
# Out:
# 295

# %%
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers[:200]):
  layer.trainable=False

ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Nadam(learning_rate=0.001, weight_decay=0.001), metrics=['accuracy'])

# %% [markdown]
# **Train the Tuning Model**

# %%
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=20,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',         # Metric to monitor (validation mean squared error in this case)
    patience=5,                     # Number of epochs with no improvement after which learning rate will be reduced
    factor=0.80,                    # Factor by which the learning rate will be reduced (0.999 in this case)
    mode='max',                     # Mode to decide when to reduce learning rate ('min' means reduce when metric stops decreasing)
    min_lr=1e-7                     # Minimum learning rate
)

callbacks = [early_stopping,lr_scheduler]

history = ft_model.fit(
    x = XT,                         # We need to apply the preprocessing thought for the MobileNetV2 network
    y = YT,
    batch_size = 32,
    epochs = 300,
    validation_data = (XV, YV),     # We need to apply the preprocessing thought for the MobileNetV2 network
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 146/146 [==============================] - 102s 339ms/step - loss: 0.5571 - accuracy: 0.7551 - val_loss: 0.3655 - val_accuracy: 0.8597 - lr: 0.0010
# Epoch 2/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.3807 - accuracy: 0.8389 - val_loss: 0.2537 - val_accuracy: 0.8927 - lr: 0.0010
# Epoch 3/300
# 146/146 [==============================] - 38s 257ms/step - loss: 0.3181 - accuracy: 0.8647 - val_loss: 0.2312 - val_accuracy: 0.9065 - lr: 0.0010
# Epoch 4/300
# 146/146 [==============================] - 37s 255ms/step - loss: 0.2757 - accuracy: 0.8846 - val_loss: 0.3156 - val_accuracy: 0.8831 - lr: 0.0010
# Epoch 5/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.2585 - accuracy: 0.8983 - val_loss: 0.2170 - val_accuracy: 0.9120 - lr: 0.0010
# Epoch 6/300
# 146/146 [==============================] - 35s 237ms/step - loss: 0.2241 - accuracy: 0.9080 - val_loss: 0.2181 - val_accuracy: 0.9010 - lr: 0.0010
# Epoch
300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0687 - accuracy: 0.9773 - val_loss: 0.2655 - val_accuracy: 0.9188 - lr: 5.1200e-04
# Epoch 29/300
# 146/146 [==============================] - 37s 255ms/step - loss: 0.0605 - accuracy: 0.9809 - val_loss: 0.2943 - val_accuracy: 0.9257 - lr: 5.1200e-04
# Epoch 30/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.0646 - accuracy: 0.9760 - val_loss: 0.2276 - val_accuracy: 0.9285 - lr: 5.1200e-04
# Epoch 31/300
# 146/146 [==============================] - 37s 254ms/step - loss: 0.0563 - accuracy: 0.9798 - val_loss: 0.2986 - val_accuracy: 0.9298 - lr: 5.1200e-04
# Epoch 32/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.0684 - accuracy: 0.9794 - val_loss: 0.2295 - val_accuracy: 0.9298 - lr: 4.0960e-04
# Epoch 33/300
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0488 - accuracy: 0.9826 - val_loss: 0.2461 - val_accuracy: 0.9230 - lr: 4.0960e-04
# Epoch 34/300
# 146/146 [==============================] - 37s 254ms/step - loss: 0.0536 - accuracy: 0.9828 - val_loss: 0.2990 - val_accuracy: 0.9285 - lr: 4.0960e-04
# Epoch 35/300
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0455 - accuracy: 0.9839 - val_loss: 0.2344 - val_accuracy: 0.9340 - lr: 4.0960e-04
# Epoch 36/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0495 - accuracy: 0.9818 - val_loss: 0.2571 - val_accuracy: 0.9202 - lr: 4.0960e-04
# Epoch 37/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0466 - accuracy: 0.9850 - val_loss: 0.2646 - val_accuracy: 0.9188 - lr: 3.2768e-04
# Epoch 38/300
# 146/146 [==============================] - 37s 257ms/step - loss: 0.0465 - accuracy: 0.9846 - val_loss: 0.2570 - val_accuracy: 0.9298 - lr: 3.2768e-04
# Epoch 39/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0474 - accuracy: 0.9824 - val_loss: 0.2598 - val_accuracy: 0.9298 - lr: 3.2768e-04
# Epoch 40/300
# 146/146 [==============================] - 36s 243ms/step - loss: 0.0432 - accuracy: 0.9852 - val_loss: 0.2585 - val_accuracy: 0.9367 - lr: 3.2768e-04
# Epoch 41/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0375 - accuracy: 0.9871 - val_loss: 0.2495 - val_accuracy: 0.9326 - lr: 3.2768e-04
# Epoch 42/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.0287 - accuracy: 0.9886 - val_loss: 0.3654 - val_accuracy: 0.9298 - lr: 3.2768e-04
# Epoch 43/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0391 - accuracy: 0.9873 - val_loss: 0.3036 - val_accuracy: 0.9230 - lr: 3.2768e-04
# Epoch 44/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0450 - accuracy: 0.9837 - val_loss: 0.2958 - val_accuracy: 0.9188 - lr: 3.2768e-04
# Epoch 45/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0348 - accuracy: 0.9858 - val_loss: 0.3022 - val_accuracy: 0.9257 - lr: 3.2768e-04
# Epoch 46/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0335 - accuracy: 0.9865 - val_loss: 0.2818 - val_accuracy: 0.9243 - lr: 2.6214e-04
# Epoch 47/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0329 - accuracy: 0.9891 - val_loss: 0.2408 - val_accuracy: 0.9367 - lr: 2.6214e-04
# Epoch 48/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.0270 - accuracy: 0.9893 - val_loss: 0.2858 - val_accuracy: 0.9285 - lr: 2.6214e-04
# Epoch 49/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0247 - accuracy: 0.9912 - val_loss: 0.3529 - val_accuracy: 0.9257 - lr: 2.6214e-04
# Epoch 50/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0251 - accuracy: 0.9914 - val_loss: 0.2824 - val_accuracy: 0.9312 - lr: 2.6214e-04
# Epoch 51/300
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0369 - accuracy: 0.9884 - val_loss: 0.3226 - val_accuracy: 0.9285 - lr: 2.0972e-04
# Epoch 52/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.0240 - accuracy: 0.9919 - val_loss: 0.3041 - val_accuracy: 0.9298 - lr: 2.0972e-04
# Epoch 53/300
# 146/146 [==============================] - 37s 253ms/step - loss: 0.0213 - accuracy: 0.9923 - val_loss: 0.3356 - val_accuracy: 0.9326 - lr: 2.0972e-04
# Epoch 54/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0273 - accuracy: 0.9916 - val_loss: 0.2685 - val_accuracy: 0.9326 - lr: 2.0972e-04
# Epoch 55/300
# 146/146 [==============================] - 35s 237ms/step - loss: 0.0263 - accuracy: 0.9910 - val_loss: 0.2953 - val_accuracy: 0.9354 - lr: 2.0972e-04
# Epoch 56/300
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0208 - accuracy: 0.9923 - val_loss: 0.2664 - val_accuracy: 0.9367 - lr: 1.6777e-04
# Epoch 57/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0238 - accuracy: 0.9916 - val_loss: 0.3128 - val_accuracy: 0.9271 - lr: 1.6777e-04
# Epoch 58/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0284 - accuracy: 0.9919 - val_loss: 0.2932 - val_accuracy: 0.9298 - lr: 1.6777e-04
# Epoch 59/300
# 146/146 [==============================] - 37s 255ms/step - loss: 0.0245 - accuracy: 0.9910 - val_loss: 0.2677 - val_accuracy: 0.9340 - lr: 1.6777e-04
# Epoch 60/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0247 - accuracy: 0.9899 - val_loss: 0.2588 - val_accuracy: 0.9340 - lr: 1.6777e-04

# %%
FT_NAME = NAME_MODEL+"_Tuning"
FT_PLOT = NAME_PLOT+"_Tuning"

# %% [markdown]
# **Plot Loss + Test Prediction Accuracy**

# %%
plot_losses(history, (20,5), FT_NAME)

# %%
test_predictions = ft_model.predict(XTE, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)
test_gt = np.argmax(YTE, axis=-1)
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
print()
# Out:
# Accuracy Score over the Test Set: 0.9505

# %% [markdown]
# **Plot Confusion Matrix**

# %%
# Compute the confusion matrix
test_predictions = ft_model.predict(XT, verbose=0)
cm = confusion_matrix(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1))
precision = precision_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(YT, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10, 8), dpi=200)
sns.heatmap(cm.T, annot=True, cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()

# %% [markdown]
# ### Saving

# %%
ft_model.save(NAME_MODEL+"_Tuning")

# %%
# !zip -r {FT_NAME}.zip {FT_NAME} {FT_PLOT}.png
# Out:
# 	zip warning: name not matched: ConvNeXtV2_004_plot_Tuning.png
#   adding: ConvNeXtV2_004_Tuning/ (stored 0%)
#   adding: ConvNeXtV2_004_Tuning/keras_metadata.pb (deflated 96%)
#   adding: ConvNeXtV2_004_Tuning/variables/ (stored 0%)
#   adding: ConvNeXtV2_004_Tuning/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXtV2_004_Tuning/variables/variables.index (deflated 78%)
#   adding: ConvNeXtV2_004_Tuning/fingerprint.pb (stored 0%)
#   adding: ConvNeXtV2_004_Tuning/saved_model.pb (deflated 92%)
#   adding: ConvNeXtV2_004_Tuning/assets/ (stored 0%)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
