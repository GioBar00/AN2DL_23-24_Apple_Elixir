# %% [markdown]
# **Mount the Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Imports and Configs

# %% [markdown]
# **Imports**

# %%
# Deafault Imports
import os
import logging
import functools
import warnings as wr
import numpy as np
import random as rnd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras as tfk
from keras import layers as tkl
from keras import models as tkm
from keras.preprocessing.image import ImageDataGenerator, random_shear, random_shift
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# !wget https://storage.googleapis.com/storage.barbiero.dev/public_data_clean.npz
# Out:
# --2023-11-10 18:28:08--  https://storage.googleapis.com/storage.barbiero.dev/public_data_clean.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.153.207, 142.250.145.207, 74.125.128.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.153.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 536546306 (512M) [application/octet-stream]
# Saving to: ‘public_data_clean.npz’
#
# public_data_clean.n 100%[===================>] 511.69M   143MB/s    in 3.7s
#
# 2023-11-10 18:28:12 (137 MB/s) - ‘public_data_clean.npz’ saved [536546306/536546306]

# %% [markdown]
# **Randomnes and Configurations**

# %%
# Random Configuration - All
RND = True
if not RND:
  SEED = 76998669
  os.environ['PYTHONHASHSEED'] = str(SEED)
  tf.compat.v1.set_random_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rnd.seed(SEED)

# OS Configuration
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

# Warning Congiguration
wr.simplefilter(action='ignore', category=FutureWarning)
wr.simplefilter(action='ignore', category=Warning)

# TensorFlow Configuration
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# **Defining Functions**

# %%
# Plotting Functions
def plot_losses(history, figsize, name_jpg):
  best_epoch = np.argmax(history['val_accuracy'])
  fig, axes = plt.subplots(2,1, figsize=figsize, dpi=200)

  axes[0].plot(history['loss'], label='Training Loss', color='#9859C5', alpha=.8)
  axes[0].plot(history['val_loss'], label='Validation Loss', color='#4D61E2', alpha=.8)
  axes[0].set_title('Loss')
  axes[0].legend()
  axes[0].grid(alpha=.3)

  axes[1].plot(history['accuracy'], label='Training Accuracy', color='#9859C5', alpha=.8)
  axes[1].plot(history['val_accuracy'], label='Validation Accuracy', color='#4D61E2', alpha=.8)
  axes[1].plot(best_epoch, history['val_accuracy'][best_epoch], marker='d', alpha=0.8, markersize=10, color='#4D61E2')
  axes[1].set_title('Accuracy')
  axes[1].legend()
  axes[1].grid(alpha=.3)

  plt.savefig(name_jpg)
  plt.show()
def plot_confusion_matrix(model, test, test_lbls, figsize, name_jpg):
  # Compute the confusion matrix
  tp = model.predict(test, verbose=0)
  cm = confusion_matrix(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1))

  # Compute classification metrics
  accuracy = accuracy_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1))
  precision = precision_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1), average='macro')
  recall = recall_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1), average='macro')
  f1 = f1_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1), average='macro')

  # Display the computed metrics
  print('Accuracy:\t', accuracy.round(4))
  print('Precision:\t', precision.round(4))
  print('Recall:\t\t', recall.round(4))
  print('F1:\t\t', f1.round(4))

  # Plot the confusion matrix
  plt.figure(figsize=figsize, dpi=200)
  sns.heatmap(cm.T, annot=True, cmap='Blues')
  plt.xlabel('True labels')
  plt.ylabel('Predicted labels')
  plt.savefig(name_jpg)
  plt.show()
def plot_images(images, labels, index=0, rows=1, cols=1, normalized=False):
  data_rescaling = tkl.Rescaling(scale=1./255)
  if normalized==False:
    IMGS_= data_rescaling(images)
  size = rows*cols
  diff = len(images)-(size+index)
  if diff <= 0:
    size = len(images)-index
    plt.figure(figsize=(cols,rows), dpi=200)
    for i in range(size):
      ax = plt.subplot(rows, cols, i + 1)
      plt.imshow(IMGS_[index + i])
      plt.title(labels[i], fontdict={"fontsize":5}, pad=2)
      plt.axis("off")

#plot_images(IMGS[:25], LBLS[:25], 0, 5, 5)

# Data Agumentation Functions
def pick_random_label(i, lbls, lbl):
  if lbls[i] == lbl:
    return True
  else:
    return False
def manual_augmentation(imgs, lbls):
    global LBLS, IMGS

    cardinality = pd.DataFrame(lbls, columns=['class'])['class'].value_counts()       # Store the Cardinality of the SETS "healthy", "unhealthy"
    ch = cardinality['healthy']
    cu = cardinality['unhealthy']
    diff = ch-cu
    print(cardinality)

    i_arr = []
    ROWS = 2
    COLS = 4
    augm = []
    augm_lbl = []

    if diff > 0:
      print("Augment the Unhealthy: ", diff, int(diff/7))
      for z in range(int(diff/7)):
        index = rnd.randint(0, len(lbls)-1)
        while not pick_random_label(index, lbls, "unhealthy") or index in i_arr:
          i_arr.append(index)
          index = rnd.randint(0, len(lbls)-1)

        if lbls[index] == "unhealthy":
          i_arr.append(index)
          img = imgs[index]
          for row in range(ROWS):
              for col in range(COLS):
                  img = np.rot90(img)
                  if row==0 and col==3:
                      continue
                  augm.append(img)
                  augm_lbl.append(lbls[index])
              if row == 0:
                  img = np.flipud(img)

    else:
      print("Augment the Healthy: ", diff)
      for z in range(int(-diff/7)):
        index = rnd.randint(0, len(lbls)-1)
        while not pick_random_label(index, lbls, "unhealthy") or index in i_arr:
          i_arr.append(index)
          index = rnd.randint(0, len(lbls)-1)

        if lbls[index] == "unhealthy":
          i_arr.append(index)
          img = imgs[index]
          for row in range(ROWS):
              for col in range(COLS):
                  img = np.rot90(img)
                  if row==0 and col==3:
                      continue
                  augm.append(img)
                  augm_lbl.append(lbls[index])
              if row == 0:
                  img = np.flipud(img)


    print(len(augm), len(augm_lbl), len(i_arr))
    plot_images(augm[:7], augm_lbl[:7],0,1,7)

    augm_lbl = list(map(lambda x: 0 if x == "healthy" else 1, augm_lbl))
    augm_lbl = tfk.utils.to_categorical(augm_lbl, len(np.unique(LBLS)))

    for i in range(len(augm_lbl)):
      IMGS = np.append(IMGS, [augm[i]], axis=0)
      LBLS = np.append(LBLS, [augm_lbl[i]], axis=0)

# Test
def test_prediction(model, test, test_lbls):
  tp = model.predict(test, verbose=0)
  tp = np.argmax(tp, axis=-1)
  tgt = np.argmax(test_lbls, axis=-1)
  test_accuracy = accuracy_score(tgt, tp)
  print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
  print()

# %% [markdown]
# ### Data Initizialization

# %%
# Initializate
DATA = np.load('public_data_clean.npz', allow_pickle=True)
KEYS = list(DATA.keys())

IMGS = np.array(DATA[KEYS[0]])
LIMG = len(IMGS)
LBLS = np.array(DATA[KEYS[1]])
LBLS_ = np.array(DATA[KEYS[1]])
LLBL = len(LBLS)

BATCH = 32
TEST_PERC = 0.15
VALI_PERC = 0.15

MPLBL = {0: "healthy", 1: "unhealthy"}
RMLBL = {"healthy": 0, "unhealthy": 1}
LBLS = np.array([RMLBL[l] for l in LBLS])
LBLS = tfk.utils.to_categorical(LBLS, len(np.unique(LBLS)))

print('Images: ', LIMG)
print('Labels: ', LLBL)
print()
# Out:
# Images:  4850
# Labels:  4850

# %%
manual_augmentation(IMGS, LBLS_)
print(len(IMGS))
# Out:
# healthy      3060
# unhealthy    1790
# Name: class, dtype: int64
# Augment the Unhealthy:  1270 181
# 1267 1267 500
# 6117

# %%
# plot_images(IMGS[-7:], LBLS[-7:], 0, 1, 7)

# %%
# LBLS__ = list(map(lambda x: "unhealthy" if x[0]==0. and x[1]==1. else "healthy", LBLS))
# print(pd.DataFrame(LBLS__, columns=['class'])['class'].value_counts() )

# %%
# Split the Data Set into Training XT YT, Validation XV YV, Test XTE YTE
Xtrv, XTE, Ytrv, YTE = train_test_split(
    IMGS,
    LBLS,
    test_size=int(TEST_PERC * LIMG),
    **({"random_state":SEED} if not RND else {}),
    stratify=LBLS
)

XT, XV, YT, YV = train_test_split(
    Xtrv,
    Ytrv,
    test_size=int(VALI_PERC*LIMG),
    **({"random_state":SEED} if not RND else {}),
    stratify=Ytrv
)

# Shapes
print('Training Set Shape: ', XT.shape, YT.shape)
print('Validation Set Shape: ', XV.shape, YV.shape)
print('Test Set Shape: ', XTE.shape, YTE.shape)
print()

# Get the Shape of IN OUT
input_shape = XT.shape[1:]
output_shape = YT.shape[1]                                                        # Enable for MultiClass Problem

print(f'Input shape of the Network: {input_shape}')
print(f'Output shape of the Network: {output_shape}')
print()
# Out:
# Training Set Shape:  (4663, 96, 96, 3) (4663, 2)
# Validation Set Shape:  (727, 96, 96, 3) (727, 2)
# Test Set Shape:  (727, 96, 96, 3) (727, 2)
#
# Input shape of the Network: (96, 96, 3)
# Output shape of the Network: 2

# %%
np.savez_compressed("augm_alex_split_001.npz", Xtrv, XTE, Ytrv, YTE)

# %% [markdown]
# **Augmentation Layers**

# %%
# Rescaling
data_rescaling = tkl.Rescaling(scale=1./255)                                      # Normalize the Images from 0..255 to 0..1
data_backscaling = tkl.Rescaling(scale=1.*255)                                    # Normalize the Images from 0..1 to 0..255

data_rescaling_c = tkl.Rescaling(scale=1./127.5, offset=-1)                       # Normalize the Images from 0..255 to -1..1
data_backscaling_c = tkl.Rescaling(scale=1.*127.5, offset=1)                      # Normalize the Images from -1..1 to 0..255

# Agumentation
augm_91 = tkm.Sequential([
    tkl.RandomTranslation(height_factor=(-0.3,0.3),width_factor=(-0.3,0.3)),
    tkl.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2)),
    tkl.RandomFlip('horizontal'),
    tkl.RandomRotation(factor=359)
])

# %% [markdown]
# ### Training

# %% [markdown]
# **Define the Model**

# %%
from keras.applications.convnext import preprocess_input

def apple_elixir_model(input_shape, output_shape):

  preprocessing = tfk.Sequential([
      # tkl.RandomContrast(factor=(0,0.3)),
      # tkl.RandomBrightness(factor=(0,0.3)),
      tkl.RandomTranslation(height_factor=(-0.3,0.3),width_factor=(-0.3,0.3)),
      tkl.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2)),
      tkl.RandomFlip('horizontal'),
      tkl.RandomRotation(factor=359)
    ], name='preprocessing'
  )

  # TO CHANGE - res of the Model
  res = tfk.applications.ConvNeXtBase(
    input_shape=input_shape,
    include_top=False,
    weights="imagenet",
    classes=2,
    classifier_activation='softmax'
  )

  res.trainable = False
  input_layer = tkl.Input(input_shape)

  # x = data_rescaling_c(input_layer)
  x = preprocess_input(input_layer)
  x = preprocessing(x)
  x = res(x)
  x = tkl.GlobalAveragePooling2D()(x)
  x = tkl.Dense(units=128,activation=tkl.LeakyReLU(alpha=0.3))(x)                 # maybe we have to use leakyrelu
  x = tkl.Dropout(0.7)(x)

  # x = tkl.Dense(units=2048,activation='relu')(x)
  # x = tkl.Dense(units=2048,activation='relu')(x)
  # x = tkl.Dense(units=1024,activation='relu')(x)

  output_layer = tkl.Dense(units=output_shape,activation='softmax')(x)
  model =tfk.Model(input_layer, output_layer)

  # Compile the model
  model.compile(
      loss=tfk.losses.CategoricalCrossentropy(),
      optimizer=tfk.optimizers.Nadam(learning_rate=0.0001, weight_decay=0.001),
      metrics=['accuracy']
  )

  return model

model = apple_elixir_model(input_shape,output_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 11s 0us/step

# %% [markdown]
# **Train the Model**

# %%
# Train the model
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',                         # Metric to monitor (validation mean squared error in this case)
    patience=5,                                     # Number of epochs with no improvement after which learning rate will be reduced
    factor=0.85,                                    # Factor by which the learning rate will be reduced (0.999 in this case)
    mode='max',                                     # Mode to decide when to reduce learning rate ('min' means reduce when metric stops decreasing)
    min_lr=1e-7                                     # Minimum learning rate
)

callbacks = [early_stopping, lr_scheduler]

history = model.fit(
    x = XT,
    y = YT,
    batch_size = 32,
    epochs = 300,
    validation_data = (XV, YV),
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 146/146 [==============================] - 67s 248ms/step - loss: 0.8872 - accuracy: 0.5797 - val_loss: 0.6069 - val_accuracy: 0.6479 - lr: 1.0000e-04
# Epoch 2/300
# 146/146 [==============================] - 23s 156ms/step - loss: 0.6659 - accuracy: 0.6509 - val_loss: 0.5768 - val_accuracy: 0.6823 - lr: 1.0000e-04
# Epoch 3/300
# 146/146 [==============================] - 23s 157ms/step - loss: 0.6259 - accuracy: 0.6785 - val_loss: 0.5415 - val_accuracy: 0.7015 - lr: 1.0000e-04
# Epoch 4/300
# 146/146 [==============================] - 25s 171ms/step - loss: 0.5882 - accuracy: 0.7041 - val_loss: 0.5456 - val_accuracy: 0.6960 - lr: 1.0000e-04
# Epoch 5/300
# 146/146 [==============================] - 25s 172ms/step - loss: 0.5579 - accuracy: 0.7199 - val_loss: 0.5263 - val_accuracy: 0.7194 - lr: 1.0000e-04
# Epoch 6/300
# 146/146 [==============================] - 25s 171ms/step - loss: 0.5489 - accuracy: 0.7285 - val_loss: 0.5380 - val_accuracy: 0.7098 - lr: 1.0000e-04
# Epoch 7/300
# 146/146 [==============================] - 22s 154ms/step - loss: 0.5205 - accuracy: 0.7435 - val_loss: 0.4819 - val_accuracy: 0.7565 - lr: 1.0000e-04
# Epoch 8/300
# 146/146 [==============================] - 25s 171ms/step - loss: 0.5248 - accuracy: 0.7424 - val_loss: 0.4964 - val_accuracy: 0.7359 - lr: 1.0000e-04
# Epoch 9/300
# 146/146 [==============================] - 24s 161ms/step - loss: 0.5181 - accuracy: 0.7523 - val_loss: 0.4583 - val_accuracy: 0.7689 - lr: 1.0000e-04
# Epoch 10/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.5016 - accuracy: 0.7602 - val_loss: 0.4873 - val_accuracy: 0.7538 - lr: 1.0000e-04
# Epoch 11/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.5068 - accuracy: 0.7508 - val_loss: 0.5010 - val_accuracy: 0.7428 - lr: 1.0000e-04
# Epoch 12/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.4827 - accuracy: 0.7667 - val_loss: 0.4809 - val_accuracy: 0.7620 - lr: 1.0000e-04
# Epoch 13/300
# 146/146 [==============================] - 25s 172ms/step - loss: 0.4859 - accuracy: 0.7669 - val_loss: 0.4515 - val_accuracy: 0.7730 - lr: 1.0000e-04
# Epoch 14/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.4868 - accuracy: 0.7579 - val_loss: 0.4358 - val_accuracy: 0.7813 - lr: 1.0000e-04
# Epoch 15/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.4713 - accuracy: 0.7772 - val_loss: 0.4256 - val_accuracy: 0.7854 - lr: 1.0000e-04
# Epoch 16/300
# 146/146 [==============================] - 23s 159ms/step - loss: 0.4564 - accuracy: 0.7922 - val_loss: 0.4562 - val_accuracy: 0.7717 - lr: 1.0000e-04
# Epoch 17/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.4573 - accuracy: 0.7851 - val_loss: 0.4263 - val_accuracy: 0.7868 - lr: 1.0000e-04
# Epoch 18/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4649 - accuracy: 0.7770 - val_loss: 0.4701 - val_accuracy: 0.7675 - lr: 1.0000e-04
# Epoch 19/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.4555 - accuracy: 0.7768 - val_loss: 0.4496 - val_accuracy: 0.7772 - lr: 1.0000e-04
# Epoch 20/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4659 - accuracy: 0.7817 - val_loss: 0.4418 - val_accuracy: 0.7854 - lr: 1.0000e-04
# Epoch 21/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.4506 - accuracy: 0.7892 - val_loss: 0.4308 - val_accuracy: 0.7840 - lr: 1.0000e-04
# Epoch 22/300
# 146/146 [==============================] - 25s 174ms/step - loss: 0.4413 - accuracy: 0.7896 - val_loss: 0.3985 - val_accuracy: 0.8088 - lr: 1.0000e-04
# Epoch 23/300
# 146/146 [==============================] - 22s 152ms/step - loss: 0.4490 - accuracy: 0.7943 - val_loss: 0.4270 - val_accuracy: 0.7992 - lr: 1.0000e-04
# Epoch 24/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.4412 - accuracy: 0.7982 - val_loss: 0.4212 - val_accuracy: 0.8074 - lr: 1.0000e-04
# Epoch 25/300
# 146/146 [==============================] - 24s 168ms/step - loss: 0.4376 - accuracy: 0.8076 - val_loss: 0.4442 - val_accuracy: 0.7923 - lr: 1.0000e-04
# Epoch 26/300
# 146/146 [==============================] - 25s 171ms/step - loss: 0.4460 - accuracy: 0.7920 - val_loss: 0.4201 - val_accuracy: 0.8033 - lr: 1.0000e-04
# Epoch 27/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4262 - accuracy: 0.7991 - val_loss: 0.3998 - val_accuracy: 0.8102 - lr: 1.0000e-04
# Epoch 28/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4262 - accuracy: 0.7991 - val_loss: 0.4400 - val_accuracy: 0.7882 - lr: 1.0000e-04
# Epoch 29/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.4260 - accuracy: 0.8003 - val_loss: 0.4169 - val_accuracy: 0.7992 - lr: 1.0000e-04
# Epoch 30/300
# 146/146 [==============================] - 25s 171ms/step - loss: 0.4396 - accuracy: 0.7954 - val_loss: 0.4034 - val_accuracy: 0.8116 - lr: 1.0000e-04
# Epoch 31/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.4292 - accuracy: 0.7995 - val_loss: 0.4073 - val_accuracy: 0.8047 - lr: 1.0000e-04
# Epoch 32/300
# 146/146 [==============================] - 22s 151ms/step - loss: 0.4315 - accuracy: 0.7935 - val_loss: 0.4197 - val_accuracy: 0.7992 - lr: 1.0000e-04
# Epoch 33/300
# 146/146 [==============================] - 22s 154ms/step - loss: 0.4323 - accuracy: 0.8021 - val_loss: 0.3975 - val_accuracy: 0.8116 - lr: 1.0000e-04
# Epoch 34/300
# 146/146 [==============================] - 22s 152ms/step - loss: 0.4304 - accuracy: 0.8033 - val_loss: 0.4048 - val_accuracy: 0.8061 - lr: 1.0000e-04
# Epoch 35/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.4278 - accuracy: 0.8003 - val_loss: 0.4034 - val_accuracy: 0.8157 - lr: 1.0000e-04
# Epoch 36/300
# 146/146 [==============================] - 24s 161ms/step - loss: 0.4245 - accuracy: 0.8061 - val_loss: 0.4114 - val_accuracy: 0.8088 - lr: 1.0000e-04
# Epoch 37/300
# 146/146 [==============================] - 24s 168ms/step - loss: 0.4218 - accuracy: 0.7969 - val_loss: 0.3995 - val_accuracy: 0.8157 - lr: 1.0000e-04
# Epoch 38/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4223 - accuracy: 0.8051 - val_loss: 0.4257 - val_accuracy: 0.7937 - lr: 1.0000e-04
# Epoch 39/300
# 146/146 [==============================] - 24s 167ms/step - loss: 0.4157 - accuracy: 0.8063 - val_loss: 0.3944 - val_accuracy: 0.8143 - lr: 1.0000e-04
# Epoch 40/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.4253 - accuracy: 0.8068 - val_loss: 0.3766 - val_accuracy: 0.8267 - lr: 1.0000e-04
# Epoch 41/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4117 - accuracy: 0.8111 - val_loss: 0.3916 - val_accuracy: 0.8226 - lr: 1.0000e-04
# Epoch 42/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.4163 - accuracy: 0.8036 - val_loss: 0.4122 - val_accuracy: 0.8047 - lr: 1.0000e-04
# Epoch 43/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.4076 - accuracy: 0.8139 - val_loss: 0.4459 - val_accuracy: 0.7868 - lr: 1.0000e-04
# Epoch 44/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.4167 - accuracy: 0.8091 - val_loss: 0.3834 - val_accuracy: 0.8212 - lr: 1.0000e-04
# Epoch 45/300
# 146/146 [==============================] - 22s 151ms/step - loss: 0.4213 - accuracy: 0.8106 - val_loss: 0.4188 - val_accuracy: 0.7950 - lr: 1.0000e-04
# Epoch 46/300
# 146/146 [==============================] - 25s 172ms/step - loss: 0.4097 - accuracy: 0.8066 - val_loss: 0.3931 - val_accuracy: 0.8129 - lr: 8.5000e-05
# Epoch 47/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4165 - accuracy: 0.8061 - val_loss: 0.3878 - val_accuracy: 0.8171 - lr: 8.5000e-05
# Epoch 48/300
# 146/146 [==============================] - 24s 166ms/step - loss: 0.4110 - accuracy: 0.8076 - val_loss: 0.4066 - val_accuracy: 0.8102 - lr: 8.5000e-05
# Epoch 49/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4024 - accuracy: 0.8194 - val_loss: 0.3820 - val_accuracy: 0.8239 - lr: 8.5000e-05
# Epoch 50/300
# 146/146 [==============================] - 23s 154ms/step - loss: 0.4094 - accuracy: 0.8078 - val_loss: 0.3809 - val_accuracy: 0.8212 - lr: 8.5000e-05
# Epoch 51/300
# 146/146 [==============================] - 22s 152ms/step - loss: 0.4003 - accuracy: 0.8083 - val_loss: 0.3728 - val_accuracy: 0.8226 - lr: 7.2250e-05
# Epoch 52/300
# 146/146 [==============================] - 24s 168ms/step - loss: 0.4043 - accuracy: 0.8136 - val_loss: 0.3884 - val_accuracy: 0.8212 - lr: 7.2250e-05
# Epoch 53/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4032 - accuracy: 0.8166 - val_loss: 0.3792 - val_accuracy: 0.8157 - lr: 7.2250e-05
# Epoch 54/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4111 - accuracy: 0.8098 - val_loss: 0.3763 - val_accuracy: 0.8294 - lr: 7.2250e-05
# Epoch 55/300
# 146/146 [==============================] - 22s 151ms/step - loss: 0.3961 - accuracy: 0.8179 - val_loss: 0.3900 - val_accuracy: 0.8239 - lr: 7.2250e-05
# Epoch 56/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.4067 - accuracy: 0.8141 - val_loss: 0.3758 - val_accuracy: 0.8267 - lr: 7.2250e-05
# Epoch 57/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.4180 - accuracy: 0.8031 - val_loss: 0.4000 - val_accuracy: 0.8184 - lr: 7.2250e-05
# Epoch 58/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.4061 - accuracy: 0.8055 - val_loss: 0.3883 - val_accuracy: 0.8239 - lr: 7.2250e-05
# Epoch 59/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4002 - accuracy: 0.8141 - val_loss: 0.3844 - val_accuracy: 0.8308 - lr: 7.2250e-05
# Epoch 60/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4093 - accuracy: 0.8102 - val_loss: 0.3924 - val_accuracy: 0.8171 - lr: 7.2250e-05
# Epoch 61/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.3990 - accuracy: 0.8169 - val_loss: 0.3663 - val_accuracy: 0.8308 - lr: 7.2250e-05
# Epoch 62/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.3947 - accuracy: 0.8203 - val_loss: 0.3657 - val_accuracy: 0.8322 - lr: 7.2250e-05
# Epoch 63/300
# 146/146 [==============================] - 23s 157ms/step - loss: 0.4010 - accuracy: 0.8106 - val_loss: 0.3678 - val_accuracy: 0.8294 - lr: 7.2250e-05
# Epoch 64/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.3966 - accuracy: 0.8184 - val_loss: 0.3633 - val_accuracy: 0.8336 - lr: 7.2250e-05
# Epoch 65/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.3892 - accuracy: 0.8338 - val_loss: 0.3888 - val_accuracy: 0.8294 - lr: 7.2250e-05
# Epoch 66/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.3997 - accuracy: 0.8171 - val_loss: 0.3669 - val_accuracy: 0.8253 - lr: 7.2250e-05
# Epoch 67/300
# 146/146 [==============================] - 25s 171ms/step - loss: 0.3909 - accuracy: 0.8207 - val_loss: 0.3762 - val_accuracy: 0.8253 - lr: 7.2250e-05
# Epoch 68/300
# 146/146 [==============================] - 23s 154ms/step - loss: 0.4013 - accuracy: 0.8171 - val_loss: 0.3792 - val_accuracy: 0.8212 - lr: 7.2250e-05
# Epoch 69/300
# 146/146 [==============================] - 22s 151ms/step - loss: 0.3882 - accuracy: 0.8246 - val_loss: 0.3676 - val_accuracy: 0.8322 - lr: 7.2250e-05
# Epoch 70/300
# 146/146 [==============================] - 26s 177ms/step - loss: 0.3970 - accuracy: 0.8154 - val_loss: 0.3695 - val_accuracy: 0.8281 - lr: 6.1412e-05
# Epoch 71/300
# 146/146 [==============================] - 25s 171ms/step - loss: 0.3971 - accuracy: 0.8175 - val_loss: 0.3844 - val_accuracy: 0.8212 - lr: 6.1412e-05
# Epoch 72/300
# 146/146 [==============================] - 23s 154ms/step - loss: 0.3837 - accuracy: 0.8252 - val_loss: 0.3923 - val_accuracy: 0.8184 - lr: 6.1412e-05
# Epoch 73/300
# 146/146 [==============================] - 22s 151ms/step - loss: 0.3953 - accuracy: 0.8173 - val_loss: 0.3669 - val_accuracy: 0.8308 - lr: 6.1412e-05
# Epoch 74/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.4006 - accuracy: 0.8173 - val_loss: 0.3997 - val_accuracy: 0.8157 - lr: 6.1412e-05
# Epoch 75/300
# 146/146 [==============================] - 23s 154ms/step - loss: 0.3961 - accuracy: 0.8201 - val_loss: 0.3820 - val_accuracy: 0.8212 - lr: 5.2201e-05
# Epoch 76/300
# 146/146 [==============================] - 25s 172ms/step - loss: 0.3916 - accuracy: 0.8203 - val_loss: 0.3662 - val_accuracy: 0.8363 - lr: 5.2201e-05
# Epoch 77/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.3837 - accuracy: 0.8216 - val_loss: 0.3810 - val_accuracy: 0.8281 - lr: 5.2201e-05
# Epoch 78/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.3912 - accuracy: 0.8218 - val_loss: 0.3859 - val_accuracy: 0.8212 - lr: 5.2201e-05
# Epoch 79/300
# 146/146 [==============================] - 23s 154ms/step - loss: 0.3910 - accuracy: 0.8250 - val_loss: 0.4019 - val_accuracy: 0.8171 - lr: 5.2201e-05
# Epoch 80/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.3862 - accuracy: 0.8276 - val_loss: 0.3709 - val_accuracy: 0.8239 - lr: 5.2201e-05
# Epoch 81/300
# 146/146 [==============================] - 22s 153ms/step - loss: 0.3948 - accuracy: 0.8218 - val_loss: 0.3657 - val_accuracy: 0.8322 - lr: 5.2201e-05
# Epoch 82/300
# 146/146 [==============================] - 25s 172ms/step - loss: 0.3977 - accuracy: 0.8216 - val_loss: 0.3567 - val_accuracy: 0.8349 - lr: 4.4371e-05
# Epoch 83/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.3831 - accuracy: 0.8256 - val_loss: 0.3628 - val_accuracy: 0.8253 - lr: 4.4371e-05
# Epoch 84/300
# 146/146 [==============================] - 25s 170ms/step - loss: 0.3818 - accuracy: 0.8263 - val_loss: 0.3836 - val_accuracy: 0.8184 - lr: 4.4371e-05
# Epoch 85/300
# 146/146 [==============================] - 25s 169ms/step - loss: 0.3793 - accuracy: 0.8282 - val_loss: 0.3732 - val_accuracy: 0.8267 - lr: 4.4371e-05
# Epoch 86/300
# 146/146 [==============================] - 22s 154ms/step - loss: 0.3862 - accuracy: 0.8184 - val_loss: 0.3562 - val_accuracy: 0.8336 - lr: 4.4371e-05
# Epoch 87/300
# 146/146 [==============================] - 25s 172ms/step - loss: 0.3839 - accuracy: 0.8269 - val_loss: 0.3741 - val_accuracy: 0.8239 - lr: 3.7715e-05
# Epoch 88/300
# 146/146 [==============================] - 23s 155ms/step - loss: 0.3795 - accuracy: 0.8321 - val_loss: 0.3864 - val_accuracy: 0.8212 - lr: 3.7715e-05
# Epoch 89/300
# 146/146 [==============================] - 25s 168ms/step - loss: 0.3777 - accuracy: 0.8299 - val_loss: 0.3637 - val_accuracy: 0.8322 - lr: 3.7715e-05
# Epoch 90/300
# 146/146 [==============================] - 23s 154ms/step - loss: 0.3788 - accuracy: 0.8282 - val_loss: 0.3697 - val_accuracy: 0.8308 - lr: 3.7715e-05
# Epoch 91/300
# 146/146 [==============================] - 23s 157ms/step - loss: 0.3879 - accuracy: 0.8233 - val_loss: 0.3776 - val_accuracy: 0.8239 - lr: 3.7715e-05

# %% [markdown]
# ### Saving and Plotting

# %%
NAME_MODEL = "ConvNeXtV2_006_1"
NAME_PLOT = NAME_MODEL + "_plot"
NAME_CMATRIX = NAME_MODEL + "_cmatrix"

# %% [markdown]
# **Test Prediction Accuracy**

# %%
test_prediction(model, XTE, YTE)
# Out:
# Accuracy Score over the Test Set: 0.8803

# %% [markdown]
# **Plots Loss**

# %%
plot_losses(history, (20,5), NAME_PLOT)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(model, XTE, YTE, (5,4), NAME_CMATRIX)
# Out:
# Accuracy:	 0.8803
# Precision:	 0.8848
# Recall:	 0.8803
# F1:	 0.88

# %% [markdown]
# **Save the Model**

# %%
model.save(NAME_MODEL)

# %% [markdown]
# **Zip Model and Plots**

# %%
# !zip -r {NAME_MODEL}.zip {NAME_MODEL} {NAME_PLOT}.png {NAME_CMATRIX}.png
# Out:
#   adding: ConvNeXtV2_006/ (stored 0%)
#   adding: ConvNeXtV2_006/variables/ (stored 0%)
#   adding: ConvNeXtV2_006/variables/variables.index (deflated 77%)
#   adding: ConvNeXtV2_006/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXtV2_006/saved_model.pb (deflated 92%)
#   adding: ConvNeXtV2_006/fingerprint.pb (stored 0%)
#   adding: ConvNeXtV2_006/keras_metadata.pb (deflated 96%)
#   adding: ConvNeXtV2_006/assets/ (stored 0%)
#   adding: ConvNeXtV2_006_plot.png (deflated 12%)
#   adding: ConvNeXtV2_006_cmatrix.png (deflated 17%)

# %% [markdown]
# **Delete the Model**

# %%
del model

# %% [markdown]
# ## Tuning

# %% [markdown]
# **Load the Model**

# %%
ft_model = tfk.models.load_model(NAME_MODEL)

# %% [markdown]
# **Count the Layers**

# %%
ft_model.get_layer('convnext_base').trainable = True
c = 0
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers):
   c += 1

print("Layers: ",c)
print()
# Out:
# Layers:  295

# %% [markdown]
# **Train only the Last Layers**

# %%
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers[:200]):
  layer.trainable=False

ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Nadam(learning_rate=0.001, weight_decay=0.001), metrics=['accuracy'])

# %% [markdown]
# **Train the Tuning Model**

# %%
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',         # Metric to monitor (validation mean squared error in this case)
    patience=5,                     # Number of epochs with no improvement after which learning rate will be reduced
    factor=0.80,                    # Factor by which the learning rate will be reduced (0.999 in this case)
    mode='max',                     # Mode to decide when to reduce learning rate ('min' means reduce when metric stops decreasing)
    min_lr=1e-7                     # Minimum learning rate
)

callbacks = [early_stopping,lr_scheduler]

history = ft_model.fit(
    x = XT,                         # We need to apply the preprocessing thought for the MobileNetV2 network
    y = YT,
    batch_size = 32,
    epochs = 300,
    validation_data = (XV, YV),     # We need to apply the preprocessing thought for the MobileNetV2 network
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 146/146 [==============================] - 101s 342ms/step - loss: 0.5363 - accuracy: 0.7746 - val_loss: 0.3743 - val_accuracy: 0.8391 - lr: 0.0010
# Epoch 2/300
# 146/146 [==============================] - 36s 243ms/step - loss: 0.3451 - accuracy: 0.8525 - val_loss: 0.2708 - val_accuracy: 0.8831 - lr: 0.0010
# Epoch 3/300
# 146/146 [==============================] - 36s 246ms/step - loss: 0.3010 - accuracy: 0.8752 - val_loss: 0.2359 - val_accuracy: 0.9133 - lr: 0.0010
# Epoch 4/300
# 146/146 [==============================] - 37s 253ms/step - loss: 0.2572 - accuracy: 0.8977 - val_loss: 0.3128 - val_accuracy: 0.8817 - lr: 0.0010
# Epoch 5/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.2502 - accuracy: 0.9011 - val_loss: 0.2797 - val_accuracy: 0.8996 - lr: 0.0010
# Epoch 6/300
# 146/146 [==============================] - 37s 257ms/step - loss: 0.2315 - accuracy: 0.9093 - val_loss: 0.2006 - val_accuracy: 0.9257 - lr: 0.0010
# Epoch 7/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.2126 - accuracy: 0.9187 - val_loss: 0.2775 - val_accuracy: 0.9092 - lr: 0.0010
# Epoch 8/300
# 146/146 [==============================] - 37s 255ms/step - loss: 0.2054 - accuracy: 0.9185 - val_loss: 0.2156 - val_accuracy: 0.9257 - lr: 0.0010
# Epoch 9/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.1872 - accuracy: 0.9312 - val_loss: 0.2288 - val_accuracy: 0.9023 - lr: 0.0010
# Epoch 10/300
# 146/146 [==============================] - 38s 257ms/step - loss: 0.1854 - accuracy: 0.9320 - val_loss: 0.2494 - val_accuracy: 0.9010 - lr: 0.0010
# Epoch 11/300
# 146/146 [==============================] - 38s 258ms/step - loss: 0.1747 - accuracy: 0.9342 - val_loss: 0.1913 - val_accuracy: 0.9230 - lr: 0.0010
# Epoch 12/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.1553 - accuracy: 0.9385 - val_loss: 0.2708 - val_accuracy: 0.9092 - lr: 8.0000e-04
# Epoch 13/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.1510 - accuracy: 0.9449 - val_loss: 0.2488 - val_accuracy: 0.9120 - lr: 8.0000e-04
# Epoch 14/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.1361 - accuracy: 0.9492 - val_loss: 0.1785 - val_accuracy: 0.9354 - lr: 8.0000e-04
# Epoch 15/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.1326 - accuracy: 0.9515 - val_loss: 0.2519 - val_accuracy: 0.9078 - lr: 8.0000e-04
# Epoch 16/300
# 146/146 [==============================] - 36s 245ms/step - loss: 0.1338 - accuracy: 0.9490 - val_loss: 0.1956 - val_accuracy: 0.9381 - lr: 8.0000e-04
# Epoch 17/300
# 146/146 [==============================] - 37s 254ms/step - loss: 0.1271 - accuracy: 0.9517 - val_loss: 0.2052 - val_accuracy: 0.9326 - lr: 8.0000e-04
# Epoch 18/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.1203 - accuracy: 0.9565 - val_loss: 0.1989 - val_accuracy: 0.9133 - lr: 8.0000e-04
# Epoch 19/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.1218 - accuracy: 0.9563 - val_loss: 0.1964 - val_accuracy: 0.9216 - lr: 8.0000e-04
# Epoch 20/300
# 146/146 [==============================] - 37s 255ms/step - loss: 0.1152 - accuracy: 0.9575 - val_loss: 0.1746 - val_accuracy: 0.9381 - lr: 8.0000e-04
# Epoch 21/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.1087 - accuracy: 0.9593 - val_loss: 0.2016 - val_accuracy: 0.9298 - lr: 8.0000e-04
# Epoch 22/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0906 - accuracy: 0.9689 - val_loss: 0.2498 - val_accuracy: 0.9326 - lr: 6.4000e-04
# Epoch 23/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0939 - accuracy: 0.9670 - val_loss: 0.1970 - val_accuracy: 0.9340 - lr: 6.4000e-04
# Epoch 24/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0867 - accuracy: 0.9695 - val_loss: 0.2140 - val_accuracy: 0.9340 - lr: 6.4000e-04
# Epoch 25/300
# 146/146 [==============================] - 35s 240ms/step - loss: 0.0895 - accuracy: 0.9663 - val_loss: 0.2166 - val_accuracy: 0.9367 - lr: 6.4000e-04
# Epoch 26/300
# 146/146 [==============================] - 35s 242ms/step - loss: 0.0805 - accuracy: 0.9732 - val_loss: 0.1864 - val_accuracy: 0.9312 - lr: 6.4000e-04
# Epoch 27/300
# 146/146 [==============================] - 35s 243ms/step - loss: 0.0720 - accuracy: 0.9723 - val_loss: 0.2325 - val_accuracy: 0.9354 - lr: 5.1200e-04
# Epoch 28/300
# 146/146 [==============================] - 37s 255ms/step - loss: 0.0674 - accuracy: 0.9749 - val_loss: 0.1696 - val_accuracy: 0.9340 - lr: 5.1200e-04
# Epoch 29/300
# 146/146 [==============================] - 37s 254ms/step - loss: 0.0655 - accuracy: 0.9777 - val_loss: 0.2135 - val_accuracy: 0.9340 - lr: 5.1200e-04
# Epoch 30/300
# 146/146 [==============================] - 35s 243ms/step - loss: 0.0658 - accuracy: 0.9777 - val_loss: 0.1789 - val_accuracy: 0.9422 - lr: 5.1200e-04
# Epoch 31/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0619 - accuracy: 0.9760 - val_loss: 0.2235 - val_accuracy: 0.9395 - lr: 5.1200e-04
# Epoch 32/300
# 146/146 [==============================] - 35s 238ms/step - loss: 0.0645 - accuracy: 0.9790 - val_loss: 0.1745 - val_accuracy: 0.9381 - lr: 5.1200e-04
# Epoch 33/300
# 146/146 [==============================] - 35s 242ms/step - loss: 0.0655 - accuracy: 0.9771 - val_loss: 0.1583 - val_accuracy: 0.9491 - lr: 5.1200e-04
# Epoch 34/300
# 146/146 [==============================] - 38s 258ms/step - loss: 0.0580 - accuracy: 0.9807 - val_loss: 0.2407 - val_accuracy: 0.9436 - lr: 5.1200e-04
# Epoch 35/300
# 146/146 [==============================] - 35s 239ms/step - loss: 0.0546 - accuracy: 0.9828 - val_loss: 0.2005 - val_accuracy: 0.9450 - lr: 5.1200e-04
# Epoch 36/300
# 146/146 [==============================] - 37s 254ms/step - loss: 0.0579 - accuracy: 0.9796 - val_loss: 0.2035 - val_accuracy: 0.9477 - lr: 5.1200e-04
# Epoch 37/300
# 146/146 [==============================] - 37s 254ms/step - loss: 0.0517 - accuracy: 0.9822 - val_loss: 0.2465 - val_accuracy: 0.9409 - lr: 5.1200e-04
# Epoch 38/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0616 - accuracy: 0.9798 - val_loss: 0.2501 - val_accuracy: 0.9312 - lr: 5.1200e-04
# Epoch 39/300
# 146/146 [==============================] - 37s 257ms/step - loss: 0.0529 - accuracy: 0.9794 - val_loss: 0.2495 - val_accuracy: 0.9243 - lr: 4.0960e-04
# Epoch 40/300
# 146/146 [==============================] - 35s 241ms/step - loss: 0.0555 - accuracy: 0.9796 - val_loss: 0.2276 - val_accuracy: 0.9257 - lr: 4.0960e-04
# Epoch 41/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0471 - accuracy: 0.9869 - val_loss: 0.2070 - val_accuracy: 0.9477 - lr: 4.0960e-04
# Epoch 42/300
# 146/146 [==============================] - 38s 260ms/step - loss: 0.0383 - accuracy: 0.9863 - val_loss: 0.2736 - val_accuracy: 0.9340 - lr: 4.0960e-04
# Epoch 43/300
# 146/146 [==============================] - 38s 257ms/step - loss: 0.0392 - accuracy: 0.9856 - val_loss: 0.2618 - val_accuracy: 0.9409 - lr: 4.0960e-04
# Epoch 44/300
# 146/146 [==============================] - 35s 242ms/step - loss: 0.0447 - accuracy: 0.9841 - val_loss: 0.2980 - val_accuracy: 0.9491 - lr: 3.2768e-04
# Epoch 45/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0448 - accuracy: 0.9839 - val_loss: 0.2249 - val_accuracy: 0.9422 - lr: 3.2768e-04
# Epoch 46/300
# 146/146 [==============================] - 37s 256ms/step - loss: 0.0403 - accuracy: 0.9856 - val_loss: 0.2364 - val_accuracy: 0.9450 - lr: 3.2768e-04
# Epoch 47/300
# 146/146 [==============================] - 35s 242ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 0.1889 - val_accuracy: 0.9367 - lr: 3.2768e-04
# Epoch 48/300
# 146/146 [==============================] - 38s 257ms/step - loss: 0.0386 - accuracy: 0.9871 - val_loss: 0.2789 - val_accuracy: 0.9409 - lr: 3.2768e-04

# %% [markdown]
# ### Saving and Plotting

# %%
FT_NAME = NAME_MODEL+"_Tuning"
FT_PLOT = NAME_PLOT+"_Tuning"
FT_CMATRIX = NAME_CMATRIX+"_Tuning"

# %% [markdown]
# **Test Prediction Accuracy**

# %%
test_prediction(ft_model, XTE, YTE)
# Out:
# Accuracy Score over the Test Set: 0.9629

# %% [markdown]
# **Plot Loss**

# %%
plot_losses(history, (20,5), FT_NAME)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(ft_model, XTE, YTE, (5,4), NAME_CMATRIX)
# Out:
# Accuracy:	 0.9629
# Precision:	 0.9635
# Recall:		 0.9628
# F1:		 0.9628

# %% [markdown]
# **Save the Model**

# %%
ft_model.save(NAME_MODEL+"_Tuning")

# %% [markdown]
# **Zip the Model and the Plots**

# %%
# !zip -r {FT_NAME}.zip {FT_NAME} {FT_PLOT}.png {FT_CMATRIX}.png
# Out:
# 	zip warning: name not matched: ConvNeXtV2_006_1_plot_Tuning.png
# 	zip warning: name not matched: ConvNeXtV2_006_1_cmatrix_Tuning.png
#   adding: ConvNeXtV2_006_1_Tuning/ (stored 0%)
#   adding: ConvNeXtV2_006_1_Tuning/variables/ (stored 0%)
#   adding: ConvNeXtV2_006_1_Tuning/variables/variables.index (deflated 78%)
#   adding: ConvNeXtV2_006_1_Tuning/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXtV2_006_1_Tuning/saved_model.pb (deflated 92%)
#   adding: ConvNeXtV2_006_1_Tuning/fingerprint.pb (stored 0%)
#   adding: ConvNeXtV2_006_1_Tuning/keras_metadata.pb (deflated 96%)
#   adding: ConvNeXtV2_006_1_Tuning/assets/ (stored 0%)

# %% [markdown]
# **Plot Test and Error on Test**

# %%
YTE_ = list(map(lambda x: "unhealthy" if x[0]==0. and x[1]==1. else "healthy", YTE))
plot_images(XTE[:25], YTE_[:25], 0, 5, 5)
plot_images(XTE[25:50], YTE_[25:50], 0, 5, 5)

print(len(XTE))
# Out:
# Output hidden; open in https://colab.research.google.com to view.
