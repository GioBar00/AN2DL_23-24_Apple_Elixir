# %%
# !pip install keras-cv keras-core -q --upgrade
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 12.0 MB/s eta 0:00:00

# %%
import os
import logging
import warnings as wr
import random as rnd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import keras_cv as kcv
import tensorflow as tf
import tensorflow_datasets as tfds
import keras_core as kc
import keras_core.layers as kcl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
# Out:
# Using TensorFlow backend

# %%
# Random Configuration - All
RND = True
if not RND:
  SEED = 76998669
  os.environ['PYTHONHASHSEED'] = str(SEED)
  tf.compat.v1.set_random_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rnd.seed(SEED)

# OS Configuration
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

# Warning Congiguration
wr.simplefilter(action='ignore', category=FutureWarning)
wr.simplefilter(action='ignore', category=Warning)

# TensorFlow Configuration
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
# Plotting Functions
def plot_losses(history, figsize, name_jpg):
  best_epoch = np.argmax(history['val_accuracy'])
  fig, axes = plt.subplots(2,1, figsize=figsize, dpi=200)

  axes[0].plot(history['loss'], label='Training Loss', color='#9859C5', alpha=.8)
  axes[0].plot(history['val_loss'], label='Validation Loss', color='#4D61E2', alpha=.8)
  axes[0].set_title('Loss')
  axes[0].legend()
  axes[0].grid(alpha=.3)

  axes[1].plot(history['accuracy'], label='Training Accuracy', color='#9859C5', alpha=.8)
  axes[1].plot(history['val_accuracy'], label='Validation Accuracy', color='#4D61E2', alpha=.8)
  axes[1].plot(best_epoch, history['val_accuracy'][best_epoch], marker='d', alpha=0.8, markersize=10, color='#4D61E2')
  axes[1].set_title('Accuracy')
  axes[1].legend()
  axes[1].grid(alpha=.3)

  plt.savefig(name_jpg)
  plt.show()

def plot_images(images, labels, index=0, rows=1, cols=1, normalized=False):
  data_rescaling = tkl.Rescaling(scale=1./255)
  if normalized==False:
    IMGS_= data_rescaling(images)
  size = rows*cols
  diff = len(images)-(size+index)
  if diff <= 0:
    size = len(images)-index
    plt.figure(figsize=(cols,rows), dpi=200)
    for i in range(size):
      ax = plt.subplot(rows, cols, i + 1)
      plt.imshow(IMGS_[index + i])
      plt.title(labels[i], fontdict={"fontsize":5}, pad=2)
      plt.axis("off")

# %%
# !wget https://storage.googleapis.com/storage.barbiero.dev/public_data_clean_balanced_splitted.npz
# Out:
# --2023-11-10 22:34:16--  https://storage.googleapis.com/storage.barbiero.dev/public_data_clean_balanced_splitted.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.251.2.207, 2607:f8b0:4023:c06::cf, 2607:f8b0:4023:c0d::cf
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.251.2.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 229962973 (219M) [application/octet-stream]
# Saving to: ‘public_data_clean_balanced_splitted.npz’
#
# public_data_clean_b 100%[===================>] 219.31M  23.0MB/s    in 10s
#
# 2023-11-10 22:34:28 (21.2 MB/s) - ‘public_data_clean_balanced_splitted.npz’ saved [229962973/229962973]

# %%
X_train_val, y_train_val, X_test, y_test = np.load('public_data_clean_balanced_splitted.npz', allow_pickle=True).values()

# Further split the combined training and validation set into a training set and a validation set
X_train, X_val, y_train, y_val = train_test_split(
    X_train_val,
    y_train_val,
    test_size = 0.15,
    **({"random_state":SEED} if not RND else {}),
    stratify = y_train_val
)

y_train = kc.utils.to_categorical(y_train,len(np.unique(y_train)))
y_val = kc.utils.to_categorical(y_val,len(np.unique(y_val)))
y_test = kc.utils.to_categorical(y_test,len(np.unique(y_test)))

# %%
batch_size = 32
image_size = 96
AUTOTUNE = tf.data.AUTOTUNE
tfds.disable_progress_bar()

# Get the Shape of IN OUT
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1]

train_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val))

train_ds = train_ds.ragged_batch(batch_size)
val_ds = val_ds.ragged_batch(batch_size)

# %%
batch = next(iter(train_ds.take(1)))
image_batch = batch[0]
label_batch = batch[1]

kcv.visualization.plot_image_gallery(
    image_batch,
    rows=3,
    cols=3,
    value_range=(0, 255),
    show=True,
)

# %%
augmix = kcv.layers.AugMix([0, 255])
augmenters = [augmix]

image_batch = augmix(image_batch)
kcv.visualization.plot_image_gallery(
    image_batch,
    rows=3,
    cols=3,
    value_range=(0, 255),
    show=True,
)

# %%
mix_up = kcv.layers.MixUp()
# MixUp needs to modify both images and labels
inputs = {"images": image_batch, "labels": label_batch}

kcv.visualization.plot_image_gallery(
    mix_up(inputs)["images"],
    rows=3,
    cols=3,
    value_range=(0, 255),
    show=True,
)

#cut_mix_or_mix_up = kcv.layers.RandomChoice([cut_mix, mix_up], batchwise=True)
#augmenters += [cut_mix_or_mix_up]

# %%
from keras_core.applications.convnext import preprocess_input

def apple_elixir_model(input_shape, output_shape):

  # TO CHANGE - res of the Model
  backbone = kc.applications.ConvNeXtBase(
    input_shape=input_shape,
    include_top=False,
    weights="imagenet",
    classes=2,
    classifier_activation='softmax'
  )

  backbone.trainable = False

  input_layer = kcl.Input(input_shape, name="AE_input_layer")

  x = preprocess_input(input_layer)
  x = backbone(x)
  x = kcl.GlobalAveragePooling2D(name="AE_global_average_pooling2d")(x)
  x = kcl.Dense(units=128,activation=kcl.LeakyReLU(alpha=0.1), name="AE_dense")(x)
  x = kcl.Dropout(0.6, name="AE_dropout")(x)
  output_layer = kcl.Dense(units=output_shape,activation='softmax', name="AE_output_layer")(x)


  model = kc.Model(input_layer, output_layer)

  # Compile the model
  model.compile(
      loss=kc.losses.CategoricalCrossentropy(),
      optimizer=kc.optimizers.Nadam(learning_rate=0.0001, weight_decay=0.001),
      metrics=['accuracy']
  )

  return model

model = apple_elixir_model(input_shape,output_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
EPOCHS = 200

# Train the model
early_stopping = kc.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    mode='max',
    restore_best_weights=True)

lr_scheduler = kc.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',                         # Metric to monitor (validation mean squared error in this case)
    patience=5,                                     # Number of epochs with no improvement after which learning rate will be reduced
    factor=0.85,                                    # Factor by which the learning rate will be reduced (0.999 in this case)
    mode='max',                                     # Mode to decide when to reduce learning rate ('min' means reduce when metric stops decreasing)
    min_lr=1e-7                                     # Minimum learning rate
)

callbacks = [early_stopping,lr_scheduler]

history = model.fit(
    train_ds,
    epochs = EPOCHS,
    validation_data = val_ds,
    callbacks = callbacks
).history
# Out:
# Epoch 1/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 64s 928ms/step - accuracy: 0.5089 - loss: 0.9792 - val_accuracy: 0.5736 - val_loss: 0.6972 - learning_rate: 1.0000e-04
# Epoch 2/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 41s 166ms/step - accuracy: 0.5510 - loss: 0.8482 - val_accuracy: 0.6466 - val_loss: 0.6249 - learning_rate: 1.0000e-04
# Epoch 3/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 122ms/step - accuracy: 0.6158 - loss: 0.6941 - val_accuracy: 0.7452 - val_loss: 0.5657 - learning_rate: 1.0000e-04
# Epoch 4/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 162ms/step - accuracy: 0.6342 - loss: 0.6441 - val_accuracy: 0.7567 - val_loss: 0.5371 - learning_rate: 1.0000e-04
# Epoch 5/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.6702 - loss: 0.6099 - val_accuracy: 0.7900 - val_loss: 0.5081 - learning_rate: 1.0000e-04
# Epoch 6/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.7047 - loss: 0.5681 - val_accuracy: 0.8003 - val_loss: 0.4881 - learning_rate: 1.0000e-04
# Epoch 7/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.7508 - loss: 0.5350 - val_accuracy: 0.8041 - val_loss: 0.4731 - learning_rate: 1.0000e-04
# Epoch 8/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.7696 - loss: 0.4857 - val_accuracy: 0.8118 - val_loss: 0.4595 - learning_rate: 1.0000e-04
# Epoch 9/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.7705 - loss: 0.4752 - val_accuracy: 0.8169 - val_loss: 0.4442 - learning_rate: 1.0000e-04
# Epoch 10/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.8044 - loss: 0.4525 - val_accuracy: 0.8220 - val_loss: 0.4333 - learning_rate: 1.0000e-04
# Epoch 11/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.7860 - loss: 0.4558 - val_accuracy: 0.8271 - val_loss: 0.4246 - learning_rate: 1.0000e-04
# Epoch 12/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.8004 - loss: 0.4304 - val_accuracy: 0.8271 - val_loss: 0.4164 - learning_rate: 1.0000e-04
# Epoch 13/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.8033 - loss: 0.4291 - val_accuracy: 0.8348 - val_loss: 0.4052 - learning_rate: 1.0000e-04
# Epoch 14/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 126ms/step - accuracy: 0.8271 - loss: 0.3851 - val_accuracy: 0.8387 - val_loss: 0.3977 - learning_rate: 1.0000e-04
# Epoch 15/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 129ms/step - accuracy: 0.8474 - loss: 0.3795 - val_accuracy: 0.8412 - val_loss: 0.3900 - learning_rate: 1.0000e-04
# Epoch 16/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.8208 - loss: 0.3971 - val_accuracy: 0.8438 - val_loss: 0.3847 - learning_rate: 1.0000e-04
# Epoch 17/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 134ms/step - accuracy: 0.8468 - loss: 0.3765 - val_accuracy: 0.8387 - val_loss: 0.3805 - learning_rate: 1.0000e-04
# Epoch 18/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.8233 - loss: 0.3801 - val_accuracy: 0.8476 - val_loss: 0.3727 - learning_rate: 1.0000e-04
# Epoch 19/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 128ms/step - accuracy: 0.8375 - loss: 0.3697 - val_accuracy: 0.8540 - val_loss: 0.3672 - learning_rate: 1.0000e-04
# Epoch 20/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.8676 - loss: 0.3376 - val_accuracy: 0.8502 - val_loss: 0.3644 - learning_rate: 1.0000e-04
# Epoch 21/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 168ms/step - accuracy: 0.8581 - loss: 0.3298 - val_accuracy: 0.8566 - val_loss: 0.3610 - learning_rate: 1.0000e-04
# Epoch 22/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 156ms/step - accuracy: 0.8306 - loss: 0.3417 - val_accuracy: 0.8553 - val_loss: 0.3566 - learning_rate: 1.0000e-04
# Epoch 23/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.8642 - loss: 0.3242 - val_accuracy: 0.8592 - val_loss: 0.3540 - learning_rate: 1.0000e-04
# Epoch 24/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8830 - loss: 0.3113 - val_accuracy: 0.8592 - val_loss: 0.3519 - learning_rate: 1.0000e-04
# Epoch 25/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 127ms/step - accuracy: 0.8669 - loss: 0.3126 - val_accuracy: 0.8604 - val_loss: 0.3489 - learning_rate: 1.0000e-04
# Epoch 26/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.8750 - loss: 0.3123 - val_accuracy: 0.8681 - val_loss: 0.3476 - learning_rate: 1.0000e-04
# Epoch 27/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.8860 - loss: 0.2979 - val_accuracy: 0.8617 - val_loss: 0.3444 - learning_rate: 1.0000e-04
# Epoch 28/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.8674 - loss: 0.2926 - val_accuracy: 0.8668 - val_loss: 0.3415 - learning_rate: 1.0000e-04
# Epoch 29/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 0.8590 - loss: 0.2989 - val_accuracy: 0.8681 - val_loss: 0.3405 - learning_rate: 1.0000e-04
# Epoch 30/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.8861 - loss: 0.2756 - val_accuracy: 0.8656 - val_loss: 0.3412 - learning_rate: 1.0000e-04
# Epoch 31/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.8770 - loss: 0.2896 - val_accuracy: 0.8656 - val_loss: 0.3369 - learning_rate: 1.0000e-04
# Epoch 32/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 127ms/step - accuracy: 0.8956 - loss: 0.2646 - val_accuracy: 0.8720 - val_loss: 0.3335 - learning_rate: 8.5000e-05
# Epoch 33/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 123ms/step - accuracy: 0.8902 - loss: 0.2627 - val_accuracy: 0.8681 - val_loss: 0.3342 - learning_rate: 8.5000e-05
# Epoch 34/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 129ms/step - accuracy: 0.9052 - loss: 0.2594 - val_accuracy: 0.8732 - val_loss: 0.3322 - learning_rate: 8.5000e-05
# Epoch 35/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.8898 - loss: 0.2644 - val_accuracy: 0.8694 - val_loss: 0.3307 - learning_rate: 8.5000e-05
# Epoch 36/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 125ms/step - accuracy: 0.8926 - loss: 0.2780 - val_accuracy: 0.8707 - val_loss: 0.3301 - learning_rate: 8.5000e-05
# Epoch 37/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 6s 160ms/step - accuracy: 0.9221 - loss: 0.2334 - val_accuracy: 0.8694 - val_loss: 0.3283 - learning_rate: 8.5000e-05
# Epoch 38/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step - accuracy: 0.8853 - loss: 0.2693 - val_accuracy: 0.8732 - val_loss: 0.3298 - learning_rate: 8.5000e-05
# Epoch 39/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9074 - loss: 0.2499 - val_accuracy: 0.8681 - val_loss: 0.3281 - learning_rate: 8.5000e-05
# Epoch 40/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - accuracy: 0.9058 - loss: 0.2448 - val_accuracy: 0.8809 - val_loss: 0.3274 - learning_rate: 7.2250e-05
# Epoch 41/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.8998 - loss: 0.2366 - val_accuracy: 0.8758 - val_loss: 0.3283 - learning_rate: 7.2250e-05
# Epoch 42/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9164 - loss: 0.2269 - val_accuracy: 0.8707 - val_loss: 0.3284 - learning_rate: 7.2250e-05
# Epoch 43/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 158ms/step - accuracy: 0.9193 - loss: 0.2227 - val_accuracy: 0.8720 - val_loss: 0.3267 - learning_rate: 7.2250e-05
# Epoch 44/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9150 - loss: 0.2401 - val_accuracy: 0.8707 - val_loss: 0.3286 - learning_rate: 7.2250e-05
# Epoch 45/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.9264 - loss: 0.2191 - val_accuracy: 0.8771 - val_loss: 0.3253 - learning_rate: 7.2250e-05
# Epoch 46/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9198 - loss: 0.2172 - val_accuracy: 0.8732 - val_loss: 0.3246 - learning_rate: 6.1412e-05
# Epoch 47/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9266 - loss: 0.2115 - val_accuracy: 0.8745 - val_loss: 0.3243 - learning_rate: 6.1412e-05
# Epoch 48/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9339 - loss: 0.2005 - val_accuracy: 0.8796 - val_loss: 0.3227 - learning_rate: 6.1412e-05
# Epoch 49/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9190 - loss: 0.2207 - val_accuracy: 0.8745 - val_loss: 0.3225 - learning_rate: 6.1412e-05
# Epoch 50/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9248 - loss: 0.2104 - val_accuracy: 0.8720 - val_loss: 0.3238 - learning_rate: 6.1412e-05
# Epoch 51/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - accuracy: 0.9287 - loss: 0.1963 - val_accuracy: 0.8720 - val_loss: 0.3258 - learning_rate: 5.2201e-05
# Epoch 52/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9433 - loss: 0.1966 - val_accuracy: 0.8745 - val_loss: 0.3217 - learning_rate: 5.2201e-05
# Epoch 53/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - accuracy: 0.9230 - loss: 0.2168 - val_accuracy: 0.8694 - val_loss: 0.3215 - learning_rate: 5.2201e-05
# Epoch 54/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.9339 - loss: 0.1923 - val_accuracy: 0.8745 - val_loss: 0.3209 - learning_rate: 5.2201e-05
# Epoch 55/200
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 171ms/step - accuracy: 0.9277 - loss: 0.2089 - val_accuracy: 0.8745 - val_loss: 0.3206 - learning_rate: 5.2201e-05

# %%
NAME_MODEL = "ConvNeXtCV_001"
NAME_PLOT = NAME_MODEL + "_plot"

# %%
plot_losses(history, (20,5), NAME_PLOT)

test_predictions = model.predict(X_test, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)
test_gt = np.argmax(y_test, axis=-1)
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
print()
# Out:
# Accuracy Score over the Test Set: 0.939

# %%
# Compute the confusion matrix
test_predictions = model.predict(X_test, verbose=0)
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(test_predictions, axis=-1))

# Compute classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(test_predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(test_predictions, axis=-1), average='macro')

# Display the computed metrics
print('Accuracy:', accuracy.round(4))
print('Precision:', precision.round(4))
print('Recall:', recall.round(4))
print('F1:', f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(5, 4), dpi=200)
sns.heatmap(cm.T, annot=True, cmap='Blues')
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.939
# Precision: 0.9391
# Recall: 0.939
# F1: 0.939

# %%
for i, layer in enumerate(model.layers):
  print(i, layer.name)
# Out:
# 0 AE_input_layer
# 1 convnext_base
# 2 AE_global_average_pooling2d
# 3 AE_dense
# 4 AE_dropout
# 5 AE_output_layer

# %%
for i, weight in enumerate(model.weights):
  model.weights[i].name += f'_{i}'

# %%
for i, weight in enumerate(model.weights):
  print(i, weight.name)
# Out:
# 0 kernel_0
# 1 bias_1
# 2 gamma_2
# 3 beta_3
# 4 kernel_4
# 5 bias_5
# 6 gamma_6
# 7 beta_7
# 8 kernel_8
# 9 bias_9
# 10 kernel_10
# 11 bias_11
# 12 variable_12
# 13 kernel_13
# 14 bias_14
# 15 gamma_15
# 16 beta_16
# 17 kernel_17
# 18 bias_18
# 19 kernel_19
# 20 bias_20
# 21 variable_1_21
# 22 kernel_22
# 23 bias_23
# 24 gamma_24
# 25 beta_25
# 26 kernel_26
# 27 bias_27
# 28 kernel_28
# 29 bias_29
# 30 variable_2_30
# 31 gamma_31
# 32 beta_32
# 33 kernel_33
# 34 bias_34
# 35 kernel_35
# 36 bias_36
# 37 gamma_37
# 38 beta_38
# 39 kernel_39
# 40 bias_40
# 41 kernel_41
# 42 bias_42
# 43 variable_3_43
# 44 kernel_44
# 45 bias_45
# 46 gamma_46
# 47 beta_47
# 48 kernel_48
# 49 bias_49
# 50 kernel_50
# 51 bias_51
# 52 variable_4_52
# 53 kernel_53
# 54 bias_54
# 55 gamma_55
# 56 beta_56
# 57 kernel_57
# 58 bias_58
# 59 kernel_59
# 60 bias_60
# 61 variable_5_61
# 62 gamma_62
# 63 beta_63
# 64 kernel_64
# 65 bias_65
# 66 kernel_66
# 67 bias_67
# 68 gamma_68
# 69 beta_69
# 70 kernel_70
# 71 bias_71
# 72 kernel_72
# 73 bias_73
# 74 variable_6_74
# 75 kernel_75
# 76 bias_76
# 77 gamma_77
# 78 beta_78
# 79 kernel_79
# 80 bias_80
# 81 kernel_81
# 82 bias_82
# 83 variable_7_83
# 84 kernel_84
# 85 bias_85
# 86 gamma_86
# 87 beta_87
# 88 kernel_88
# 89 bias_89
# 90 kernel_90
# 91 bias_91
# 92 variable_8_92
# 93 kernel_93
# 94 bias_94
# 95 gamma_95
# 96 beta_96
# 97 kernel_97
# 98 bias_98
# 99 kernel_99
# 100 bias_100
# 101 variable_9_101
# 102 kernel_102
# 103 bias_103
# 104 gamma_104
# 105 beta_105
# 106 kernel_106
# 107 bias_107
# 108 kernel_108
# 109 bias_109
# 110 variable_10_110
# 111 kernel_111
# 112 bias_112
# 113 gamma_113
# 114 beta_114
# 115 kernel_115
# 116 bias_116
# 117 kernel_117
# 118 bias_118
# 119 variable_11_119
# 120 kernel_120
# 121 bias_121
# 122 gamma_122
# 123 beta_123
# 124 kernel_124
# 125 bias_125
# 126 kernel_126
# 127 bias_127
# 128 variable_12_128
# 129 kernel_129
# 130 bias_130
# 131 gamma_131
# 132 beta_132
# 133 kernel_133
# 134 bias_134
# 135 kernel_135
# 136 bias_136
# 137 variable_13_137
# 138 kernel_138
# 139 bias_139
# 140 gamma_140
# 141 beta_141
# 142 kernel_142
# 143 bias_143
# 144 kernel_144
# 145 bias_145
# 146 variable_14_146
# 147 kernel_147
# 148 bias_148
# 149 gamma_149
# 150 beta_150
# 151 kernel_151
# 152 bias_152
# 153 kernel_153
# 154 bias_154
# 155 variable_15_155
# 156 kernel_156
# 157 bias_157
# 158 gamma_158
# 159 beta_159
# 160 kernel_160
# 161 bias_161
# 162 kernel_162
# 163 bias_163
# 164 variable_16_164
# 165 kernel_165
# 166 bias_166
# 167 gamma_167
# 168 beta_168
# 169 kernel_169
# 170 bias_170
# 171 kernel_171
# 172 bias_172
# 173 variable_17_173
# 174 kernel_174
# 175 bias_175
# 176 gamma_176
# 177 beta_177
# 178 kernel_178
# 179 bias_179
# 180 kernel_180
# 181 bias_181
# 182 variable_18_182
# 183 kernel_183
# 184 bias_184
# 185 gamma_185
# 186 beta_186
# 187 kernel_187
# 188 bias_188
# 189 kernel_189
# 190 bias_190
# 191 variable_19_191
# 192 kernel_192
# 193 bias_193
# 194 gamma_194
# 195 beta_195
# 196 kernel_196
# 197 bias_197
# 198 kernel_198
# 199 bias_199
# 200 variable_20_200
# 201 kernel_201
# 202 bias_202
# 203 gamma_203
# 204 beta_204
# 205 kernel_205
# 206 bias_206
# 207 kernel_207
# 208 bias_208
# 209 variable_21_209
# 210 kernel_210
# 211 bias_211
# 212 gamma_212
# 213 beta_213
# 214 kernel_214
# 215 bias_215
# 216 kernel_216
# 217 bias_217
# 218 variable_22_218
# 219 kernel_219
# 220 bias_220
# 221 gamma_221
# 222 beta_222
# 223 kernel_223
# 224 bias_224
# 225 kernel_225
# 226 bias_226
# 227 variable_23_227
# 228 kernel_228
# 229 bias_229
# 230 gamma_230
# 231 beta_231
# 232 kernel_232
# 233 bias_233
# 234 kernel_234
# 235 bias_235
# 236 variable_24_236
# 237 kernel_237
# 238 bias_238
# 239 gamma_239
# 240 beta_240
# 241 kernel_241
# 242 bias_242
# 243 kernel_243
# 244 bias_244
# 245 variable_25_245
# 246 kernel_246
# 247 bias_247
# 248 gamma_248
# 249 beta_249
# 250 kernel_250
# 251 bias_251
# 252 kernel_252
# 253 bias_253
# 254 variable_26_254
# 255 kernel_255
# 256 bias_256
# 257 gamma_257
# 258 beta_258
# 259 kernel_259
# 260 bias_260
# 261 kernel_261
# 262 bias_262
# 263 variable_27_263
# 264 kernel_264
# 265 bias_265
# 266 gamma_266
# 267 beta_267
# 268 kernel_268
# 269 bias_269
# 270 kernel_270
# 271 bias_271
# 272 variable_28_272
# 273 kernel_273
# 274 bias_274
# 275 gamma_275
# 276 beta_276
# 277 kernel_277
# 278 bias_278
# 279 kernel_279
# 280 bias_280
# 281 variable_29_281
# 282 kernel_282
# 283 bias_283
# 284 gamma_284
# 285 beta_285
# 286 kernel_286
# 287 bias_287
# 288 kernel_288
# 289 bias_289
# 290 variable_30_290
# 291 kernel_291
# 292 bias_292
# 293 gamma_293
# 294 beta_294
# 295 kernel_295
# 296 bias_296
# 297 kernel_297
# 298 bias_298
# 299 variable_31_299
# 300 kernel_300
# 301 bias_301
# 302 gamma_302
# 303 beta_303
# 304 kernel_304
# 305 bias_305
# 306 kernel_306
# 307 bias_307
# 308 variable_32_308
# 309 gamma_309
# 310 beta_310
# 311 kernel_311
# 312 bias_312
# 313 kernel_313
# 314 bias_314
# 315 gamma_315
# 316 beta_316
# 317 kernel_317
# 318 bias_318
# 319 kernel_319
# 320 bias_320
# 321 variable_33_321
# 322 kernel_322
# 323 bias_323
# 324 gamma_324
# 325 beta_325
# 326 kernel_326
# 327 bias_327
# 328 kernel_328
# 329 bias_329
# 330 variable_34_330
# 331 kernel_331
# 332 bias_332
# 333 gamma_333
# 334 beta_334
# 335 kernel_335
# 336 bias_336
# 337 kernel_337
# 338 bias_338
# 339 variable_35_339
# 340 gamma_340
# 341 beta_341
# 342 kernel_342
# 343 bias_343
# 344 kernel_344
# 345 bias_345

# %%
model.layers[0].name = "AE_input_layer"
model.layers[2].name = "AE_global_average_pooling2d"
model.layers[3].name = "AE_dense"
model.layers[4].name = "AE_dropout"
model.layers[5].name = "AE_output_layer"

# %%
model.save(NAME_MODEL + '.h5')

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! cp ConvNeXtCV_001.zip gdrive/MyDrive/

# %%
# !zip -r {NAME_MODEL}.zip {NAME_MODEL + '.tf'} {NAME_PLOT}.png
# Out:
#   adding: ConvNeXtCV_001.tf/ (stored 0%)
#   adding: ConvNeXtCV_001.tf/variables/ (stored 0%)
#   adding: ConvNeXtCV_001.tf/variables/variables.index (deflated 79%)
#   adding: ConvNeXtCV_001.tf/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXtCV_001.tf/saved_model.pb (deflated 93%)
#   adding: ConvNeXtCV_001.tf/fingerprint.pb (stored 0%)
#   adding: ConvNeXtCV_001.tf/assets/ (stored 0%)
#   adding: ConvNeXtCV_001_plot.png (deflated 14%)

# %%
del ft_model

# %%
ft_model = kc.models.load_model(NAME_MODEL + '.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-80330d6bdc81> in <cell line: 1>()
# ----> 1 ft_model = kc.models.load_model(NAME_MODEL + '.h5')
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     182         )
#     183     if str(filepath).endswith((".h5", ".hdf5")):
# --> 184         return legacy_h5_format.load_model_from_hdf5(filepath)
#     185     elif str(filepath).endswith(".keras"):
#     186         raise ValueError(
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/legacy_h5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     131
#     132         with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133             model = saving_utils.model_from_config(
#     134                 model_config, custom_objects=custom_objects
#     135             )
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/saving_utils.py in model_from_config(config, custom_objects)
#      83     config = _find_replace_nested_dict(config, "keras.", "keras_core.")
#      84
# ---> 85     return serialization.deserialize_keras_object(
#      86         config,
#      87         module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/serialization.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     492
#     493             if "custom_objects" in arg_spec.args:
# --> 494                 deserialized_obj = cls.from_config(
#     495                     cls_config,
#     496                     custom_objects={
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/models/model.py in from_config(cls, config, custom_objects)
#     543             from keras_core.src.models.functional import functional_from_config
#     544
# --> 545             return functional_from_config(
#     546                 cls, config, custom_objects=custom_objects
#     547             )
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/models/functional.py in functional_from_config(cls, config, custom_objects)
#     503     # First, we create all layers and enqueue nodes to be processed
#     504     for layer_data in config["layers"]:
# --> 505         process_layer(layer_data)
#     506
#     507     # Then we process nodes in order of layer depth.
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/models/functional.py in process_layer(layer_data)
#     483             # Legacy format deserialization (no "module" key)
#     484             # used for H5 and SavedModel formats
# --> 485             layer = saving_utils.model_from_config(
#     486                 layer_data, custom_objects=custom_objects
#     487             )
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/saving_utils.py in model_from_config(config, custom_objects)
#      83     config = _find_replace_nested_dict(config, "keras.", "keras_core.")
#      84
# ---> 85     return serialization.deserialize_keras_object(
#      86         config,
#      87         module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/serialization.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     492
#     493             if "custom_objects" in arg_spec.args:
# --> 494                 deserialized_obj = cls.from_config(
#     495                     cls_config,
#     496                     custom_objects={
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/models/model.py in from_config(cls, config, custom_objects)
#     543             from keras_core.src.models.functional import functional_from_config
#     544
# --> 545             return functional_from_config(
#     546                 cls, config, custom_objects=custom_objects
#     547             )
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/models/functional.py in functional_from_config(cls, config, custom_objects)
#     503     # First, we create all layers and enqueue nodes to be processed
#     504     for layer_data in config["layers"]:
# --> 505         process_layer(layer_data)
#     506
#     507     # Then we process nodes in order of layer depth.
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/models/functional.py in process_layer(layer_data)
#     483             # Legacy format deserialization (no "module" key)
#     484             # used for H5 and SavedModel formats
# --> 485             layer = saving_utils.model_from_config(
#     486                 layer_data, custom_objects=custom_objects
#     487             )
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/saving_utils.py in model_from_config(config, custom_objects)
#      83     config = _find_replace_nested_dict(config, "keras.", "keras_core.")
#      84
# ---> 85     return serialization.deserialize_keras_object(
#      86         config,
#      87         module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/serialization.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     470         # In this case we are dealing with a Keras config dictionary.
#     471         config = identifier
# --> 472         (cls, cls_config) = class_and_config_for_serialized_keras_object(
#     473             config, module_objects, custom_objects, printable_module_name
#     474         )
#
# /usr/local/lib/python3.10/dist-packages/keras_core/src/legacy/saving/serialization.py in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     351     )
#     352     if cls is None:
# --> 353         raise ValueError(
#     354             f"Unknown {printable_module_name}: '{class_name}'. "
#     355             "Please ensure you are using a `keras.utils.custom_object_scope` "
#
# ValueError: Unknown layer: 'LayerScale'. Please ensure you are using a `keras.utils.custom_object_scope` and that this object is included in the scope. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.

# %%
ft_model.get_layer('convnext_base').trainable = True
c = 0
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers):
   c += 1

print(c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-83739d9c056b> in <cell line: 1>()
# ----> 1 ft_model.get_layer('convnext_base').trainable = True
#       2 c = 0
#       3 for i, layer in enumerate(ft_model.get_layer('convnext_base').layers):
#       4    c += 1
#       5
#
# AttributeError: '_UserObject' object has no attribute 'get_layer'
