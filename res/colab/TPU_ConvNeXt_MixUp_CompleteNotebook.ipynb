# %% [markdown]
# # AN2DL - Apple Elixir
#
# This notebook contains code of a neural network used in a competition. The goal of the competition was to classify plants into two classes (healthy and unhealthy).
# The model used in this notebook derived from a well known architecture, ConvNeXt, and uses an advanced augmentation technique called MixUp combined with more traditional augmentation techniques

# %% [markdown]
# # Import and configs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install --upgrade tensorflow -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 51.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 40.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 60.1 MB/s eta 0:00:00

# %%
# !pip install --upgrade keras-cv -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.1/803.1 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 9.8 MB/s eta 0:00:00

# %% [markdown]
# **Imports**

# %%
# Default Imports
import os
import logging
import functools
import warnings as wr
import numpy as np
import random as rnd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras_cv as kcv
from tensorflow import keras as tfk
from keras import layers as tkl
from keras import models as tkm
from keras.preprocessing.image import ImageDataGenerator, random_shear, random_shift
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
# Out:
# Using TensorFlow backend

# %% [markdown]
# **import of the dataset**
#
# this dataset, as presented in the report, is derved from the original one by oversampling the elements in the less represented class

# %%
# !wget -q https://storage.googleapis.com/storage.barbiero.dev/public_data_clean_balanced.npz

# %% [markdown]
# **Randomnes and Configurations**

# %%
# Random Configuration - All
RND = True
if not RND:
  SEED = 76998669
  os.environ['PYTHONHASHSEED'] = str(SEED)
  tf.compat.v1.set_random_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rnd.seed(SEED)

# OS Configuration
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

# Warning Congiguration
wr.simplefilter(action='ignore', category=FutureWarning)
wr.simplefilter(action='ignore', category=Warning)

# TensorFlow Configuration
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# **TPU Setup**

# %%
use_tpu = True  #set this paerameter to FALSE if the tpu is not used

if 'COLAB_TPU_ADDR' in os.environ and use_tpu:
  TF_MASTER = 'grpc://{}'.format(os.environ['COLAB_TPU_ADDR'])
  use_tpu = True
else : use_tpu = False

if use_tpu:
  tpu_address = TF_MASTER
  resolver = tf.distribute.cluster_resolver.TPUClusterResolver(TF_MASTER)
  tf.config.experimental_connect_to_cluster(resolver)
  tf.tpu.experimental.initialize_tpu_system(resolver)
  strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# **Defining Functions**

# %%
# Plotting Functions
# Function used for plotting the loss
def plot_losses(history, figsize, name_jpg):
  best_epoch = np.argmax(history['val_accuracy'])
  fig, axes = plt.subplots(2,1, figsize=figsize, dpi=200)

  axes[0].plot(history['loss'], label='Training Loss', color='#9859C5', alpha=.8)
  axes[0].plot(history['val_loss'], label='Validation Loss', color='#4D61E2', alpha=.8)
  axes[0].set_title('Loss')
  axes[0].legend()
  axes[0].grid(alpha=.3)

  axes[1].plot(history['accuracy'], label='Training Accuracy', color='#9859C5', alpha=.8)
  axes[1].plot(history['val_accuracy'], label='Validation Accuracy', color='#4D61E2', alpha=.8)
  axes[1].plot(best_epoch, history['val_accuracy'][best_epoch], marker='d', alpha=0.8, markersize=10, color='#4D61E2')
  axes[1].set_title('Accuracy')
  axes[1].legend()
  axes[1].grid(alpha=.3)

  plt.savefig(name_jpg)
  plt.show()

# Function used for compute the confusion Matrix
def plot_confusion_matrix(model, test, figsize, name_jpg):
  # Compute the confusion matrix
  y_pred = model.predict(test, verbose=0, steps=(len(X_val) // BATCH_SIZE))
  y_pred = np.argmax(y_pred, axis=-1)
  true_categories = tf.concat([np.argmax(y, axis=-1) for x, y in test], axis=0)
  cm = confusion_matrix(true_categories, y_pred)

  # Compute classification metrics
  accuracy = accuracy_score(true_categories, y_pred)
  precision = precision_score(true_categories, y_pred, average='macro')
  recall = recall_score(true_categories, y_pred, average='macro')
  f1 = f1_score(true_categories, y_pred, average='macro')

  # Display the computed metrics
  print('Accuracy:\t', accuracy.round(4))
  print('Precision:\t', precision.round(4))
  print('Recall:\t\t', recall.round(4))
  print('F1:\t\t', f1.round(4))

  # Plot the confusion matrix
  plt.figure(figsize=figsize, dpi=200)
  sns.heatmap(cm.T, annot=True, cmap='Blues')
  plt.xlabel('True labels')
  plt.ylabel('Predicted labels')
  plt.savefig(name_jpg)
  plt.show()

# Function used for printig a set of images and their corresponding labels
def plot_images(images, labels, index=0, rows=1, cols=1, normalized=False):
  data_rescaling = tkl.Rescaling(scale=1./255)
  if normalized==False:
    IMGS_= data_rescaling(images)
  size = rows*cols
  diff = len(images)-(size+index)
  if diff <= 0:
    size = len(images)-index
    plt.figure(figsize=(cols,rows), dpi=200)
    for i in range(size):
      ax = plt.subplot(rows, cols, i + 1)
      plt.imshow(IMGS_[index + i])
      plt.title(labels[i], fontdict={"fontsize":5}, pad=2)
      plt.axis("off")


# Function used to make predictions
def test_prediction(model, test):
  y_pred = model.predict(test, verbose=0, steps=(len(X_val) // BATCH_SIZE))
  y_pred = np.argmax(y_pred, axis=-1)
  true_categories = tf.concat([np.argmax(y, axis=-1) for x, y in test], axis=0)
  test_accuracy = accuracy_score(true_categories, y_pred)
  print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
  print()

# Function used to plot 9 images belonging to the dataset
def visualize_dataset(dataset, title):
    plt.figure(figsize=(6, 6)).suptitle(title, fontsize=18)
    for i, samples in enumerate(iter(dataset.take(9))):
        images = samples["images"]
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[0].numpy().astype("uint8"))
        plt.axis("off")
    plt.show()

# %% [markdown]
# # Data Initizialization

# %% [markdown]
# **load the dataset**

# %%
# Initializate
images, labels = np.load('public_data_clean_balanced.npz', allow_pickle=True).values()

print('Images shape: ', images.shape)
print('Labels shape: ', labels.shape)


# Map the categorical attributes into numbers
labels_map = {0: "healthy", 1: "unhealthy"}
labels_rev_map = {"healthy": 0, "unhealthy": 1}
labels = np.array([labels_rev_map[label] for label in labels])
# Out:
# Images shape:  (6120, 96, 96, 3)
# Labels shape:  (6120,)

# %% [markdown]
# **Split the dataset**

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size = 0.15,
    stratify = labels,
    random_state = 1234
)

# Conver the categorical attributes in one-hot encoding
y_train = tfk.utils.to_categorical(y_train, 2)
y_val = tfk.utils.to_categorical(y_val, 2)

# Get the Shape of IN OUT
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1]                                                        # Enable for MultiClass Problem

print(f'Input shape of the Network: {input_shape}')
print(f'Output shape of the Network: {output_shape}')
print()
# Out:
# Input shape of the Network: (96, 96, 3)
# Output shape of the Network: 2

# %% [markdown]
# **convert the dataset into a TensorFlow Dataset**

# %%
# create a dataset object for each set
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))

# %% [markdown]
# **Preprocess the data**

# %%
# Assign the batch size, note that in case of tpu the batch must be bigger if we want to exploit its performance
if use_tpu:
  BATCH_SIZE = 128
else:
  BATCH_SIZE = 32

AUTOTUNE = tf.data.AUTOTUNE
IMAGE_SIZE = (96, 96)

# This function create a dictionary composed of images and labels
def to_dict(image, label):
    image = tf.image.resize(image, IMAGE_SIZE)
    image = tf.cast(image, tf.float32)
    return {"images": image, "labels": label}


def prepare_trainset(dataset):
    return (
            dataset
            .cache()
            .shuffle(1000, reshuffle_each_iteration=True)
            .map(to_dict, num_parallel_calls=AUTOTUNE)
            .repeat()
            .batch(BATCH_SIZE, drop_remainder=True)
        )

def prepare_valset(dataset):
    return (
            dataset
            .cache()
            .batch(BATCH_SIZE, drop_remainder=True)
        )

# Preprocess the train and validation set
train_dataset = prepare_trainset(train_dataset)
val_dataset = prepare_valset(val_dataset)

# %% [markdown]
# ## *Augmentation*

# %% [markdown]
# **Define the MixUp function**

# %%
mix_up = kcv.layers.MixUp()

def apply_mix_up(inputs):
    inputs = mix_up(inputs, training = True)
    return inputs

# %% [markdown]
# **Define other augmentation layers**

# %%
post_aug = tfk.Sequential([
      tkl.RandomTranslation(height_factor=(-0.5,0.5),width_factor=(-0.5,0.5)),
      tkl.RandomZoom(height_factor=(-0.3,0.3),width_factor=(-0.3,0.3)),
      tkl.RandomFlip(),
      tkl.RandomRotation(factor=0.5)
    ]
  )

def apply_post_aug(inputs):
    inputs["images"] = post_aug(inputs["images"])
    return inputs

# %% [markdown]
# **Apply the augmentation functions to our dataset**

# %%
def preprocess_for_model(inputs):
    images, labels = inputs["images"], inputs["labels"]
    images = tf.cast(images, tf.float32)
    return images, labels

train_dataset_1 = (
    train_dataset
    .map(apply_mix_up, num_parallel_calls=AUTOTUNE)
    .map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
)

train_dataset = train_dataset.prefetch(AUTOTUNE)
val_dataset = val_dataset.prefetch(AUTOTUNE)

# %% [markdown]
# # Define the Model

# %%
from keras.applications.convnext import preprocess_input

def apple_elixir_model(input_shape, output_shape):

  # From Keras.application import ConvNeXt Base
  res = tfk.applications.ConvNeXtBase(
    input_shape=input_shape,
    include_top=False,
    weights="imagenet",
    classes=2,
    classifier_activation='softmax'
  )

  # Set convNeXt as not trainable
  res.trainable = False
  input_layer = tkl.Input(input_shape)  # input layer

  x = preprocess_input(input_layer)   # preprocessing
  x = res(x)
  x = tkl.GlobalAveragePooling2D()(x)   # GAP
  x = tkl.Dense(units=128,activation=tkl.LeakyReLU(alpha=0.3))(x)     # A dense layer
  x = tkl.Dropout(0.7)(x)

  output_layer = tkl.Dense(units=output_shape,activation='softmax')(x)  # output layer
  model = tfk.Model(input_layer, output_layer)

  # Compile the model
  model.compile(
      loss=tfk.losses.CategoricalCrossentropy(),
      optimizer=tfk.optimizers.Nadam(learning_rate=0.001, weight_decay=0.001),
      metrics=['accuracy']
  )

  return model

if use_tpu:
  with strategy.scope():
    model = apple_elixir_model(input_shape,output_shape)
else:
  model = apple_elixir_model(input_shape,output_shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/convnext/convnext_base_notop.h5
# 350926856/350926856 [==============================] - 2s 0us/step

# %% [markdown]
# # Training

# %% [markdown]
# **CallBacks**

# %%
# Early stopping
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=40,
    mode='max',
    restore_best_weights=True)

# Reduce LR on plateau
lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.85,
    mode='max',
    min_lr=1e-7
)

callbacks = [early_stopping, lr_scheduler]

# %% [markdown]
# **Fit the model**

# %%
history = model.fit(
    train_dataset_1,
    epochs = 300,
    steps_per_epoch = len(X_train) // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = len(X_val) // BATCH_SIZE,
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 40/40 [==============================] - 45s 449ms/step - loss: 0.7542 - accuracy: 0.6545 - val_loss: 0.4201 - val_accuracy: 0.8225 - lr: 0.0010
# Epoch 2/300
# 40/40 [==============================] - 4s 108ms/step - loss: 0.5565 - accuracy: 0.7453 - val_loss: 0.3861 - val_accuracy: 0.8237 - lr: 0.0010
# Epoch 3/300
# 40/40 [==============================] - 7s 183ms/step - loss: 0.5052 - accuracy: 0.7805 - val_loss: 0.3620 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 4/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.4680 - accuracy: 0.7990 - val_loss: 0.3498 - val_accuracy: 0.8482 - lr: 0.0010
# Epoch 5/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.4736 - accuracy: 0.8055 - val_loss: 0.3425 - val_accuracy: 0.8527 - lr: 0.0010
# Epoch 6/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.4476 - accuracy: 0.8178 - val_loss: 0.3324 - val_accuracy: 0.8661 - lr: 0.0010
# Epoch 7/300
# 40/40 [==============================] - 3s 73ms/step - loss: 0.4398 - accuracy: 0.8207 - val_loss: 0.3322 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 8/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.4304 - accuracy: 0.8252 - val_loss: 0.3294 - val_accuracy: 0.8627 - lr: 0.0010
# Epoch 9/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4266 - accuracy: 0.8313 - val_loss: 0.3290 - val_accuracy: 0.8594 - lr: 0.0010
# Epoch 10/300
# 40/40 [==============================] - 5s 116ms/step - loss: 0.4115 - accuracy: 0.8398 - val_loss: 0.3168 - val_accuracy: 0.8717 - lr: 0.0010
# Epoch 11/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.4203 - accuracy: 0.8334 - val_loss: 0.3267 - val_accuracy: 0.8616 - lr: 0.0010
# Epoch 12/300
# 40/40 [==============================] - 3s 65ms/step - loss: 0.4187 - accuracy: 0.8369 - val_loss: 0.3143 - val_accuracy: 0.8650 - lr: 0.0010
# Epoch 13/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.4043 - accuracy: 0.8404 - val_loss: 0.3249 - val_accuracy: 0.8683 - lr: 0.0010
# Epoch 14/300
# 40/40 [==============================] - 3s 78ms/step - loss: 0.4102 - accuracy: 0.8449 - val_loss: 0.3119 - val_accuracy: 0.8705 - lr: 0.0010
# Epoch 15/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3922 - accuracy: 0.8566 - val_loss: 0.3174 - val_accuracy: 0.8627 - lr: 0.0010
# Epoch 16/300
# 40/40 [==============================] - 5s 120ms/step - loss: 0.3985 - accuracy: 0.8473 - val_loss: 0.3015 - val_accuracy: 0.8750 - lr: 8.5000e-04
# Epoch 17/300
# 40/40 [==============================] - 3s 63ms/step - loss: 0.3870 - accuracy: 0.8543 - val_loss: 0.3062 - val_accuracy: 0.8739 - lr: 8.5000e-04
# Epoch 18/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3898 - accuracy: 0.8504 - val_loss: 0.3045 - val_accuracy: 0.8728 - lr: 8.5000e-04
# Epoch 19/300
# 40/40 [==============================] - 3s 65ms/step - loss: 0.3759 - accuracy: 0.8564 - val_loss: 0.3030 - val_accuracy: 0.8739 - lr: 8.5000e-04
# Epoch 20/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3770 - accuracy: 0.8582 - val_loss: 0.2976 - val_accuracy: 0.8739 - lr: 8.5000e-04
# Epoch 21/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3806 - accuracy: 0.8576 - val_loss: 0.3047 - val_accuracy: 0.8627 - lr: 8.5000e-04
# Epoch 22/300
# 40/40 [==============================] - 4s 112ms/step - loss: 0.3809 - accuracy: 0.8596 - val_loss: 0.3071 - val_accuracy: 0.8705 - lr: 7.2250e-04
# Epoch 23/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.3715 - accuracy: 0.8668 - val_loss: 0.2934 - val_accuracy: 0.8817 - lr: 7.2250e-04
# Epoch 24/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3770 - accuracy: 0.8611 - val_loss: 0.2965 - val_accuracy: 0.8772 - lr: 7.2250e-04
# Epoch 25/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3835 - accuracy: 0.8551 - val_loss: 0.2934 - val_accuracy: 0.8772 - lr: 7.2250e-04
# Epoch 26/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3810 - accuracy: 0.8619 - val_loss: 0.2956 - val_accuracy: 0.8750 - lr: 7.2250e-04
# Epoch 27/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3735 - accuracy: 0.8633 - val_loss: 0.2960 - val_accuracy: 0.8717 - lr: 7.2250e-04
# Epoch 28/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3601 - accuracy: 0.8711 - val_loss: 0.2893 - val_accuracy: 0.8761 - lr: 7.2250e-04
# Epoch 29/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3649 - accuracy: 0.8672 - val_loss: 0.2862 - val_accuracy: 0.8728 - lr: 6.1413e-04
# Epoch 30/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3595 - accuracy: 0.8717 - val_loss: 0.2868 - val_accuracy: 0.8739 - lr: 6.1413e-04
# Epoch 31/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3559 - accuracy: 0.8717 - val_loss: 0.2845 - val_accuracy: 0.8728 - lr: 6.1413e-04
# Epoch 32/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3584 - accuracy: 0.8678 - val_loss: 0.2850 - val_accuracy: 0.8739 - lr: 6.1413e-04
# Epoch 33/300
# 40/40 [==============================] - 3s 76ms/step - loss: 0.3507 - accuracy: 0.8760 - val_loss: 0.2871 - val_accuracy: 0.8739 - lr: 6.1413e-04
# Epoch 34/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3639 - accuracy: 0.8686 - val_loss: 0.2905 - val_accuracy: 0.8705 - lr: 5.2201e-04
# Epoch 35/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3506 - accuracy: 0.8793 - val_loss: 0.3000 - val_accuracy: 0.8650 - lr: 5.2201e-04
# Epoch 36/300
# 40/40 [==============================] - 3s 76ms/step - loss: 0.3635 - accuracy: 0.8674 - val_loss: 0.2856 - val_accuracy: 0.8795 - lr: 5.2201e-04
# Epoch 37/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3464 - accuracy: 0.8826 - val_loss: 0.2835 - val_accuracy: 0.8739 - lr: 5.2201e-04
# Epoch 38/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3501 - accuracy: 0.8779 - val_loss: 0.2867 - val_accuracy: 0.8750 - lr: 5.2201e-04
# Epoch 39/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3503 - accuracy: 0.8746 - val_loss: 0.2770 - val_accuracy: 0.8683 - lr: 4.4371e-04
# Epoch 40/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3514 - accuracy: 0.8793 - val_loss: 0.2782 - val_accuracy: 0.8772 - lr: 4.4371e-04
# Epoch 41/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3494 - accuracy: 0.8795 - val_loss: 0.2785 - val_accuracy: 0.8728 - lr: 4.4371e-04
# Epoch 42/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3392 - accuracy: 0.8801 - val_loss: 0.2731 - val_accuracy: 0.8761 - lr: 4.4371e-04
# Epoch 43/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3379 - accuracy: 0.8932 - val_loss: 0.2719 - val_accuracy: 0.8817 - lr: 4.4371e-04
# Epoch 44/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.3501 - accuracy: 0.8789 - val_loss: 0.2798 - val_accuracy: 0.8750 - lr: 3.7715e-04
# Epoch 45/300
# 40/40 [==============================] - 4s 108ms/step - loss: 0.3381 - accuracy: 0.8791 - val_loss: 0.2702 - val_accuracy: 0.8850 - lr: 3.7715e-04
# Epoch 46/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3500 - accuracy: 0.8805 - val_loss: 0.2718 - val_accuracy: 0.8761 - lr: 3.7715e-04
# Epoch 47/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3414 - accuracy: 0.8820 - val_loss: 0.2772 - val_accuracy: 0.8806 - lr: 3.7715e-04
# Epoch 48/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3385 - accuracy: 0.8867 - val_loss: 0.2690 - val_accuracy: 0.8795 - lr: 3.7715e-04
# Epoch 49/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3306 - accuracy: 0.8900 - val_loss: 0.2711 - val_accuracy: 0.8772 - lr: 3.7715e-04
# Epoch 50/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3453 - accuracy: 0.8777 - val_loss: 0.2744 - val_accuracy: 0.8772 - lr: 3.7715e-04
# Epoch 51/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3415 - accuracy: 0.8867 - val_loss: 0.2739 - val_accuracy: 0.8795 - lr: 3.2058e-04
# Epoch 52/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3440 - accuracy: 0.8783 - val_loss: 0.2723 - val_accuracy: 0.8817 - lr: 3.2058e-04
# Epoch 53/300
# 40/40 [==============================] - 3s 75ms/step - loss: 0.3399 - accuracy: 0.8777 - val_loss: 0.2711 - val_accuracy: 0.8772 - lr: 3.2058e-04
# Epoch 54/300
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3297 - accuracy: 0.8895 - val_loss: 0.2677 - val_accuracy: 0.8772 - lr: 3.2058e-04
# Epoch 55/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3348 - accuracy: 0.8881 - val_loss: 0.2678 - val_accuracy: 0.8795 - lr: 3.2058e-04
# Epoch 56/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3266 - accuracy: 0.8908 - val_loss: 0.2708 - val_accuracy: 0.8828 - lr: 2.7249e-04
# Epoch 57/300
# 40/40 [==============================] - 3s 65ms/step - loss: 0.3362 - accuracy: 0.8902 - val_loss: 0.2713 - val_accuracy: 0.8761 - lr: 2.7249e-04
# Epoch 58/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3303 - accuracy: 0.8877 - val_loss: 0.2661 - val_accuracy: 0.8772 - lr: 2.7249e-04
# Epoch 59/300
# 40/40 [==============================] - 3s 65ms/step - loss: 0.3167 - accuracy: 0.9002 - val_loss: 0.2691 - val_accuracy: 0.8828 - lr: 2.7249e-04
# Epoch 60/300
# 40/40 [==============================] - 3s 76ms/step - loss: 0.3267 - accuracy: 0.8951 - val_loss: 0.2663 - val_accuracy: 0.8839 - lr: 2.7249e-04
# Epoch 61/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3319 - accuracy: 0.8910 - val_loss: 0.2670 - val_accuracy: 0.8806 - lr: 2.3162e-04
# Epoch 62/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3273 - accuracy: 0.8908 - val_loss: 0.2635 - val_accuracy: 0.8739 - lr: 2.3162e-04
# Epoch 63/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.3206 - accuracy: 0.8951 - val_loss: 0.2652 - val_accuracy: 0.8873 - lr: 2.3162e-04
# Epoch 64/300
# 40/40 [==============================] - 5s 132ms/step - loss: 0.3288 - accuracy: 0.8973 - val_loss: 0.2670 - val_accuracy: 0.8884 - lr: 2.3162e-04
# Epoch 65/300
# 40/40 [==============================] - 3s 75ms/step - loss: 0.3249 - accuracy: 0.8975 - val_loss: 0.2649 - val_accuracy: 0.8817 - lr: 2.3162e-04
# Epoch 66/300
# 40/40 [==============================] - 5s 126ms/step - loss: 0.3228 - accuracy: 0.8986 - val_loss: 0.2634 - val_accuracy: 0.8917 - lr: 2.3162e-04
# Epoch 67/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3315 - accuracy: 0.8902 - val_loss: 0.2641 - val_accuracy: 0.8917 - lr: 2.3162e-04
# Epoch 68/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3272 - accuracy: 0.8893 - val_loss: 0.2667 - val_accuracy: 0.8761 - lr: 2.3162e-04
# Epoch 69/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3257 - accuracy: 0.9006 - val_loss: 0.2654 - val_accuracy: 0.8761 - lr: 2.3162e-04
# Epoch 70/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3206 - accuracy: 0.8969 - val_loss: 0.2647 - val_accuracy: 0.8806 - lr: 2.3162e-04
# Epoch 71/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3248 - accuracy: 0.8904 - val_loss: 0.2643 - val_accuracy: 0.8850 - lr: 2.3162e-04
# Epoch 72/300
# 40/40 [==============================] - 3s 76ms/step - loss: 0.3268 - accuracy: 0.8928 - val_loss: 0.2621 - val_accuracy: 0.8873 - lr: 1.9687e-04
# Epoch 73/300
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3315 - accuracy: 0.8918 - val_loss: 0.2633 - val_accuracy: 0.8839 - lr: 1.9687e-04
# Epoch 74/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3187 - accuracy: 0.8902 - val_loss: 0.2683 - val_accuracy: 0.8862 - lr: 1.9687e-04
# Epoch 75/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3261 - accuracy: 0.8895 - val_loss: 0.2639 - val_accuracy: 0.8839 - lr: 1.9687e-04
# Epoch 76/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3215 - accuracy: 0.8896 - val_loss: 0.2621 - val_accuracy: 0.8806 - lr: 1.9687e-04
# Epoch 77/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3169 - accuracy: 0.9000 - val_loss: 0.2590 - val_accuracy: 0.8873 - lr: 1.6734e-04
# Epoch 78/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3115 - accuracy: 0.8994 - val_loss: 0.2596 - val_accuracy: 0.8895 - lr: 1.6734e-04
# Epoch 79/300
# 40/40 [==============================] - 5s 125ms/step - loss: 0.3171 - accuracy: 0.9037 - val_loss: 0.2593 - val_accuracy: 0.8940 - lr: 1.6734e-04
# Epoch 80/300
# 40/40 [==============================] - 3s 83ms/step - loss: 0.3222 - accuracy: 0.8973 - val_loss: 0.2612 - val_accuracy: 0.8862 - lr: 1.6734e-04
# Epoch 81/300
# 40/40 [==============================] - 3s 76ms/step - loss: 0.3282 - accuracy: 0.8896 - val_loss: 0.2611 - val_accuracy: 0.8895 - lr: 1.6734e-04
# Epoch 82/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3228 - accuracy: 0.8998 - val_loss: 0.2585 - val_accuracy: 0.8895 - lr: 1.6734e-04
# Epoch 83/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3257 - accuracy: 0.8918 - val_loss: 0.2628 - val_accuracy: 0.8917 - lr: 1.6734e-04
# Epoch 84/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3220 - accuracy: 0.8986 - val_loss: 0.2569 - val_accuracy: 0.8873 - lr: 1.6734e-04
# Epoch 85/300
# 40/40 [==============================] - 3s 75ms/step - loss: 0.3220 - accuracy: 0.9000 - val_loss: 0.2605 - val_accuracy: 0.8850 - lr: 1.4224e-04
# Epoch 86/300
# 40/40 [==============================] - 4s 112ms/step - loss: 0.3229 - accuracy: 0.8943 - val_loss: 0.2609 - val_accuracy: 0.8828 - lr: 1.4224e-04
# Epoch 87/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3042 - accuracy: 0.9016 - val_loss: 0.2572 - val_accuracy: 0.8929 - lr: 1.4224e-04
# Epoch 88/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3137 - accuracy: 0.9012 - val_loss: 0.2583 - val_accuracy: 0.8873 - lr: 1.4224e-04
# Epoch 89/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3153 - accuracy: 0.9041 - val_loss: 0.2593 - val_accuracy: 0.8906 - lr: 1.4224e-04
# Epoch 90/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3054 - accuracy: 0.9094 - val_loss: 0.2576 - val_accuracy: 0.8839 - lr: 1.2091e-04
# Epoch 91/300
# 40/40 [==============================] - 3s 72ms/step - loss: 0.3031 - accuracy: 0.9092 - val_loss: 0.2610 - val_accuracy: 0.8795 - lr: 1.2091e-04
# Epoch 92/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3156 - accuracy: 0.9008 - val_loss: 0.2574 - val_accuracy: 0.8884 - lr: 1.2091e-04
# Epoch 93/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3160 - accuracy: 0.8984 - val_loss: 0.2585 - val_accuracy: 0.8862 - lr: 1.2091e-04
# Epoch 94/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3055 - accuracy: 0.9111 - val_loss: 0.2584 - val_accuracy: 0.8884 - lr: 1.2091e-04
# Epoch 95/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3098 - accuracy: 0.9023 - val_loss: 0.2575 - val_accuracy: 0.8884 - lr: 1.0277e-04
# Epoch 96/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3121 - accuracy: 0.9010 - val_loss: 0.2574 - val_accuracy: 0.8884 - lr: 1.0277e-04
# Epoch 97/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3117 - accuracy: 0.9021 - val_loss: 0.2584 - val_accuracy: 0.8873 - lr: 1.0277e-04
# Epoch 98/300
# 40/40 [==============================] - 3s 72ms/step - loss: 0.3123 - accuracy: 0.9021 - val_loss: 0.2580 - val_accuracy: 0.8862 - lr: 1.0277e-04
# Epoch 99/300
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3144 - accuracy: 0.8996 - val_loss: 0.2564 - val_accuracy: 0.8873 - lr: 1.0277e-04
# Epoch 100/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3189 - accuracy: 0.9066 - val_loss: 0.2570 - val_accuracy: 0.8862 - lr: 8.7354e-05
# Epoch 101/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3090 - accuracy: 0.9006 - val_loss: 0.2564 - val_accuracy: 0.8873 - lr: 8.7354e-05
# Epoch 102/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3076 - accuracy: 0.9033 - val_loss: 0.2587 - val_accuracy: 0.8839 - lr: 8.7354e-05
# Epoch 103/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3031 - accuracy: 0.9102 - val_loss: 0.2565 - val_accuracy: 0.8873 - lr: 8.7354e-05
# Epoch 104/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3084 - accuracy: 0.9062 - val_loss: 0.2585 - val_accuracy: 0.8839 - lr: 8.7354e-05
# Epoch 105/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.3103 - accuracy: 0.9033 - val_loss: 0.2553 - val_accuracy: 0.8862 - lr: 7.4251e-05
# Epoch 106/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3089 - accuracy: 0.9037 - val_loss: 0.2566 - val_accuracy: 0.8839 - lr: 7.4251e-05
# Epoch 107/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3116 - accuracy: 0.9074 - val_loss: 0.2550 - val_accuracy: 0.8906 - lr: 7.4251e-05
# Epoch 108/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3039 - accuracy: 0.9086 - val_loss: 0.2558 - val_accuracy: 0.8895 - lr: 7.4251e-05
# Epoch 109/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3108 - accuracy: 0.9020 - val_loss: 0.2555 - val_accuracy: 0.8862 - lr: 7.4251e-05
# Epoch 110/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3056 - accuracy: 0.9047 - val_loss: 0.2557 - val_accuracy: 0.8862 - lr: 6.3113e-05
# Epoch 111/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3044 - accuracy: 0.9029 - val_loss: 0.2543 - val_accuracy: 0.8895 - lr: 6.3113e-05
# Epoch 112/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3139 - accuracy: 0.9039 - val_loss: 0.2559 - val_accuracy: 0.8895 - lr: 6.3113e-05
# Epoch 113/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3083 - accuracy: 0.9082 - val_loss: 0.2574 - val_accuracy: 0.8906 - lr: 6.3113e-05
# Epoch 114/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3073 - accuracy: 0.9102 - val_loss: 0.2555 - val_accuracy: 0.8895 - lr: 6.3113e-05
# Epoch 115/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3075 - accuracy: 0.9062 - val_loss: 0.2561 - val_accuracy: 0.8884 - lr: 5.3646e-05
# Epoch 116/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3205 - accuracy: 0.9012 - val_loss: 0.2558 - val_accuracy: 0.8862 - lr: 5.3646e-05
# Epoch 117/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3045 - accuracy: 0.9059 - val_loss: 0.2557 - val_accuracy: 0.8873 - lr: 5.3646e-05
# Epoch 118/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3043 - accuracy: 0.9107 - val_loss: 0.2560 - val_accuracy: 0.8895 - lr: 5.3646e-05
# Epoch 119/300
# 40/40 [==============================] - 29s 730ms/step - loss: 0.3108 - accuracy: 0.9076 - val_loss: 0.2565 - val_accuracy: 0.8884 - lr: 5.3646e-05

# %% [markdown]
# ### Saving and Plotting

# %%
NAME_MODEL = "ConvNeXt_MixUp"
NAME_PLOT = NAME_MODEL + "_plot"
NAME_CMATRIX = NAME_MODEL + "_cmatrix"

# %% [markdown]
# **Plots Loss**

# %%
plot_losses(history, (20,5), NAME_PLOT)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(model, val_dataset, (5,4), NAME_CMATRIX)
# Out:
# Exception ignored in: <function Executor.__del__ at 0x7eb09eabe7a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 46, in __del__
#     self.wait()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 65, in wait
#     pywrap_tfe.TFE_ExecutorWaitForAllPendingNodes(self._handle)
# tensorflow.python.framework.errors_impl.OutOfRangeError: End of sequence
# Accuracy:	 0.894
# Precision:	 0.8945
# Recall:		 0.8941
# F1:		 0.894

# %% [markdown]
# **Save the Model**

# %%
if use_tpu:
  # save model locally from tpu using Tensorflow's "SavedModel" format
  save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
  model.save(NAME_MODEL, options=save_locally)
else:
  model.save(NAME_MODEL)

# %% [markdown]
# **Delete the Model**

# %%
del model, history

# %% [markdown]
# # Fine Tuning

# %% [markdown]
# **Load the Model**

# %%
if use_tpu:
  with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    ft_model = tf.keras.models.load_model(NAME_MODEL, options=load_locally)
else:
  ft_model = tfk.models.load_model(NAME_MODEL)

# %% [markdown]
# **Train only the Last Layers**

# %%
ft_model.get_layer('convnext_base').trainable = True

for i, layer in enumerate(ft_model.get_layer('convnext_base').layers[:200]):
  layer.trainable=False

ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Nadam(learning_rate=0.001, weight_decay=0.001), metrics=['accuracy'])

# %% [markdown]
# **Augment the dataset**
#
# Here we are applying new augmentation techniques for the fine tuning

# %%
train_dataset = (
    train_dataset
    .map(apply_post_aug, num_parallel_calls=AUTOTUNE)
    .map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
)

# %% [markdown]
# **Train the Tuning Model**

# %%
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=25,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.80,
    mode='max',
    min_lr=1e-7
)

callbacks = [early_stopping, lr_scheduler]

history = ft_model.fit(
    train_dataset,
    epochs = 300,
    steps_per_epoch = len(X_train) // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = len(X_val) // BATCH_SIZE,
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 40/40 [==============================] - 95s 477ms/step - loss: 0.9944 - accuracy: 0.7033 - val_loss: 0.6020 - val_accuracy: 0.7366 - lr: 0.0010
# Epoch 2/300
# 40/40 [==============================] - 5s 138ms/step - loss: 0.4573 - accuracy: 0.7908 - val_loss: 0.3236 - val_accuracy: 0.8705 - lr: 0.0010
# Epoch 3/300
# 40/40 [==============================] - 6s 156ms/step - loss: 0.4278 - accuracy: 0.8084 - val_loss: 0.2972 - val_accuracy: 0.8884 - lr: 0.0010
# Epoch 4/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.3833 - accuracy: 0.8326 - val_loss: 0.3632 - val_accuracy: 0.8304 - lr: 0.0010
# Epoch 5/300
# 40/40 [==============================] - 5s 134ms/step - loss: 0.3528 - accuracy: 0.8395 - val_loss: 0.2883 - val_accuracy: 0.8895 - lr: 0.0010
# Epoch 6/300
# 40/40 [==============================] - 5s 137ms/step - loss: 0.3381 - accuracy: 0.8521 - val_loss: 0.2614 - val_accuracy: 0.8962 - lr: 0.0010
# Epoch 7/300
# 40/40 [==============================] - 6s 154ms/step - loss: 0.3145 - accuracy: 0.8668 - val_loss: 0.2339 - val_accuracy: 0.8996 - lr: 0.0010
# Epoch 8/300
# 40/40 [==============================] - 6s 145ms/step - loss: 0.2983 - accuracy: 0.8662 - val_loss: 0.2287 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 9/300
# 40/40 [==============================] - 5s 135ms/step - loss: 0.2862 - accuracy: 0.8805 - val_loss: 0.2242 - val_accuracy: 0.9051 - lr: 0.0010
# Epoch 10/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.2694 - accuracy: 0.8844 - val_loss: 0.2243 - val_accuracy: 0.9040 - lr: 0.0010
# Epoch 11/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.2635 - accuracy: 0.8920 - val_loss: 0.2477 - val_accuracy: 0.8895 - lr: 0.0010
# Epoch 12/300
# 40/40 [==============================] - 4s 102ms/step - loss: 0.2538 - accuracy: 0.8941 - val_loss: 0.2660 - val_accuracy: 0.9007 - lr: 0.0010
# Epoch 13/300
# 40/40 [==============================] - 5s 132ms/step - loss: 0.2391 - accuracy: 0.9014 - val_loss: 0.2472 - val_accuracy: 0.9085 - lr: 0.0010
# Epoch 14/300
# 40/40 [==============================] - 6s 141ms/step - loss: 0.2318 - accuracy: 0.9027 - val_loss: 0.1789 - val_accuracy: 0.9263 - lr: 0.0010
# Epoch 15/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.2250 - accuracy: 0.9082 - val_loss: 0.2571 - val_accuracy: 0.9129 - lr: 0.0010
# Epoch 16/300
# 40/40 [==============================] - 4s 106ms/step - loss: 0.2183 - accuracy: 0.9107 - val_loss: 0.2228 - val_accuracy: 0.9141 - lr: 0.0010
# Epoch 17/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.2230 - accuracy: 0.9066 - val_loss: 0.2190 - val_accuracy: 0.9174 - lr: 0.0010
# Epoch 18/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.2053 - accuracy: 0.9125 - val_loss: 0.2068 - val_accuracy: 0.9208 - lr: 0.0010
# Epoch 19/300
# 40/40 [==============================] - 4s 100ms/step - loss: 0.2000 - accuracy: 0.9176 - val_loss: 0.2194 - val_accuracy: 0.9129 - lr: 0.0010
# Epoch 20/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.2075 - accuracy: 0.9148 - val_loss: 0.2183 - val_accuracy: 0.9096 - lr: 8.0000e-04
# Epoch 21/300
# 40/40 [==============================] - 6s 149ms/step - loss: 0.1840 - accuracy: 0.9221 - val_loss: 0.1728 - val_accuracy: 0.9330 - lr: 8.0000e-04
# Epoch 22/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.1748 - accuracy: 0.9277 - val_loss: 0.2422 - val_accuracy: 0.9152 - lr: 8.0000e-04
# Epoch 23/300
# 40/40 [==============================] - 5s 139ms/step - loss: 0.1743 - accuracy: 0.9336 - val_loss: 0.1676 - val_accuracy: 0.9397 - lr: 8.0000e-04
# Epoch 24/300
# 40/40 [==============================] - 4s 108ms/step - loss: 0.1671 - accuracy: 0.9340 - val_loss: 0.1738 - val_accuracy: 0.9353 - lr: 8.0000e-04
# Epoch 25/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.1732 - accuracy: 0.9324 - val_loss: 0.1889 - val_accuracy: 0.9230 - lr: 8.0000e-04
# Epoch 26/300
# 40/40 [==============================] - 7s 181ms/step - loss: 0.1797 - accuracy: 0.9279 - val_loss: 0.1627 - val_accuracy: 0.9431 - lr: 8.0000e-04
# Epoch 27/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.1636 - accuracy: 0.9338 - val_loss: 0.1773 - val_accuracy: 0.9319 - lr: 8.0000e-04
# Epoch 28/300
# 40/40 [==============================] - 5s 114ms/step - loss: 0.1613 - accuracy: 0.9398 - val_loss: 0.1736 - val_accuracy: 0.9420 - lr: 8.0000e-04
# Epoch 29/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.1681 - accuracy: 0.9338 - val_loss: 0.1792 - val_accuracy: 0.9319 - lr: 8.0000e-04
# Epoch 30/300
# 40/40 [==============================] - 4s 97ms/step - loss: 0.1602 - accuracy: 0.9387 - val_loss: 0.1691 - val_accuracy: 0.9286 - lr: 8.0000e-04
# Epoch 31/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.1457 - accuracy: 0.9408 - val_loss: 0.1579 - val_accuracy: 0.9375 - lr: 8.0000e-04
# Epoch 32/300
# 40/40 [==============================] - 4s 102ms/step - loss: 0.1514 - accuracy: 0.9371 - val_loss: 0.2182 - val_accuracy: 0.9129 - lr: 6.4000e-04
# Epoch 33/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.1426 - accuracy: 0.9443 - val_loss: 0.2190 - val_accuracy: 0.9174 - lr: 6.4000e-04
# Epoch 34/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.1298 - accuracy: 0.9467 - val_loss: 0.2184 - val_accuracy: 0.9208 - lr: 6.4000e-04
# Epoch 35/300
# 40/40 [==============================] - 4s 91ms/step - loss: 0.1248 - accuracy: 0.9496 - val_loss: 0.1903 - val_accuracy: 0.9263 - lr: 6.4000e-04
# Epoch 36/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.1290 - accuracy: 0.9510 - val_loss: 0.2028 - val_accuracy: 0.9330 - lr: 6.4000e-04
# Epoch 37/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.1296 - accuracy: 0.9510 - val_loss: 0.1756 - val_accuracy: 0.9408 - lr: 5.1200e-04
# Epoch 38/300
# 40/40 [==============================] - 4s 112ms/step - loss: 0.1243 - accuracy: 0.9521 - val_loss: 0.1881 - val_accuracy: 0.9297 - lr: 5.1200e-04
# Epoch 39/300
# 40/40 [==============================] - 4s 100ms/step - loss: 0.1139 - accuracy: 0.9531 - val_loss: 0.1979 - val_accuracy: 0.9308 - lr: 5.1200e-04
# Epoch 40/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.1113 - accuracy: 0.9580 - val_loss: 0.1752 - val_accuracy: 0.9275 - lr: 5.1200e-04
# Epoch 41/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.1070 - accuracy: 0.9590 - val_loss: 0.1729 - val_accuracy: 0.9364 - lr: 5.1200e-04
# Epoch 42/300
# 40/40 [==============================] - 4s 100ms/step - loss: 0.1057 - accuracy: 0.9578 - val_loss: 0.1609 - val_accuracy: 0.9397 - lr: 4.0960e-04
# Epoch 43/300
# 40/40 [==============================] - 6s 153ms/step - loss: 0.0970 - accuracy: 0.9645 - val_loss: 0.1527 - val_accuracy: 0.9453 - lr: 4.0960e-04
# Epoch 44/300
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0980 - accuracy: 0.9664 - val_loss: 0.1790 - val_accuracy: 0.9442 - lr: 4.0960e-04
# Epoch 45/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.1002 - accuracy: 0.9619 - val_loss: 0.1557 - val_accuracy: 0.9442 - lr: 4.0960e-04
# Epoch 46/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0947 - accuracy: 0.9623 - val_loss: 0.1532 - val_accuracy: 0.9431 - lr: 4.0960e-04
# Epoch 47/300
# 40/40 [==============================] - 4s 106ms/step - loss: 0.0855 - accuracy: 0.9662 - val_loss: 0.2059 - val_accuracy: 0.9286 - lr: 4.0960e-04
# Epoch 48/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0945 - accuracy: 0.9648 - val_loss: 0.1859 - val_accuracy: 0.9330 - lr: 4.0960e-04
# Epoch 49/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0912 - accuracy: 0.9662 - val_loss: 0.1531 - val_accuracy: 0.9420 - lr: 3.2768e-04
# Epoch 50/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.0759 - accuracy: 0.9705 - val_loss: 0.1739 - val_accuracy: 0.9330 - lr: 3.2768e-04
# Epoch 51/300
# 40/40 [==============================] - 4s 90ms/step - loss: 0.0964 - accuracy: 0.9652 - val_loss: 0.1677 - val_accuracy: 0.9397 - lr: 3.2768e-04
# Epoch 52/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0865 - accuracy: 0.9664 - val_loss: 0.1611 - val_accuracy: 0.9397 - lr: 3.2768e-04
# Epoch 53/300
# 40/40 [==============================] - 6s 153ms/step - loss: 0.0820 - accuracy: 0.9695 - val_loss: 0.1627 - val_accuracy: 0.9475 - lr: 3.2768e-04
# Epoch 54/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0839 - accuracy: 0.9672 - val_loss: 0.1686 - val_accuracy: 0.9397 - lr: 3.2768e-04
# Epoch 55/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0829 - accuracy: 0.9672 - val_loss: 0.1778 - val_accuracy: 0.9464 - lr: 3.2768e-04
# Epoch 56/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0876 - accuracy: 0.9645 - val_loss: 0.1518 - val_accuracy: 0.9475 - lr: 3.2768e-04
# Epoch 57/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0835 - accuracy: 0.9678 - val_loss: 0.1618 - val_accuracy: 0.9386 - lr: 3.2768e-04
# Epoch 58/300
# 40/40 [==============================] - 4s 107ms/step - loss: 0.0768 - accuracy: 0.9713 - val_loss: 0.1910 - val_accuracy: 0.9375 - lr: 3.2768e-04
# Epoch 59/300
# 40/40 [==============================] - 6s 140ms/step - loss: 0.0646 - accuracy: 0.9764 - val_loss: 0.1843 - val_accuracy: 0.9442 - lr: 2.6214e-04
# Epoch 60/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0753 - accuracy: 0.9695 - val_loss: 0.1751 - val_accuracy: 0.9364 - lr: 2.6214e-04
# Epoch 61/300
# 40/40 [==============================] - 4s 112ms/step - loss: 0.0674 - accuracy: 0.9727 - val_loss: 0.2027 - val_accuracy: 0.9375 - lr: 2.6214e-04
# Epoch 62/300
# 40/40 [==============================] - 4s 111ms/step - loss: 0.0731 - accuracy: 0.9738 - val_loss: 0.1940 - val_accuracy: 0.9342 - lr: 2.6214e-04
# Epoch 63/300
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0776 - accuracy: 0.9684 - val_loss: 0.2064 - val_accuracy: 0.9263 - lr: 2.6214e-04
# Epoch 64/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0793 - accuracy: 0.9697 - val_loss: 0.1644 - val_accuracy: 0.9420 - lr: 2.0972e-04
# Epoch 65/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0607 - accuracy: 0.9785 - val_loss: 0.1847 - val_accuracy: 0.9397 - lr: 2.0972e-04
# Epoch 66/300
# 40/40 [==============================] - 4s 106ms/step - loss: 0.0689 - accuracy: 0.9789 - val_loss: 0.1626 - val_accuracy: 0.9420 - lr: 2.0972e-04
# Epoch 67/300
# 40/40 [==============================] - 4s 112ms/step - loss: 0.0688 - accuracy: 0.9742 - val_loss: 0.1559 - val_accuracy: 0.9431 - lr: 2.0972e-04
# Epoch 68/300
# 40/40 [==============================] - 5s 136ms/step - loss: 0.0622 - accuracy: 0.9764 - val_loss: 0.1677 - val_accuracy: 0.9487 - lr: 2.0972e-04
# Epoch 69/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0533 - accuracy: 0.9801 - val_loss: 0.1967 - val_accuracy: 0.9453 - lr: 2.0972e-04
# Epoch 70/300
# 40/40 [==============================] - 6s 147ms/step - loss: 0.0606 - accuracy: 0.9768 - val_loss: 0.1674 - val_accuracy: 0.9498 - lr: 2.0972e-04
# Epoch 71/300
# 40/40 [==============================] - 4s 113ms/step - loss: 0.0558 - accuracy: 0.9809 - val_loss: 0.1997 - val_accuracy: 0.9364 - lr: 2.0972e-04
# Epoch 72/300
# 40/40 [==============================] - 4s 100ms/step - loss: 0.0704 - accuracy: 0.9744 - val_loss: 0.1752 - val_accuracy: 0.9364 - lr: 2.0972e-04
# Epoch 73/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0569 - accuracy: 0.9793 - val_loss: 0.1852 - val_accuracy: 0.9386 - lr: 2.0972e-04
# Epoch 74/300
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0580 - accuracy: 0.9789 - val_loss: 0.1996 - val_accuracy: 0.9442 - lr: 2.0972e-04
# Epoch 75/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0576 - accuracy: 0.9791 - val_loss: 0.2017 - val_accuracy: 0.9408 - lr: 2.0972e-04
# Epoch 76/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.0571 - accuracy: 0.9797 - val_loss: 0.1642 - val_accuracy: 0.9420 - lr: 1.6777e-04
# Epoch 77/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0575 - accuracy: 0.9783 - val_loss: 0.1790 - val_accuracy: 0.9431 - lr: 1.6777e-04
# Epoch 78/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0720 - accuracy: 0.9748 - val_loss: 0.1648 - val_accuracy: 0.9475 - lr: 1.6777e-04
# Epoch 79/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0524 - accuracy: 0.9793 - val_loss: 0.1897 - val_accuracy: 0.9420 - lr: 1.6777e-04
# Epoch 80/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0481 - accuracy: 0.9826 - val_loss: 0.1940 - val_accuracy: 0.9420 - lr: 1.6777e-04
# Epoch 81/300
# 40/40 [==============================] - 6s 156ms/step - loss: 0.0469 - accuracy: 0.9834 - val_loss: 0.1722 - val_accuracy: 0.9520 - lr: 1.3422e-04
# Epoch 82/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0510 - accuracy: 0.9812 - val_loss: 0.1913 - val_accuracy: 0.9420 - lr: 1.3422e-04
# Epoch 83/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0495 - accuracy: 0.9811 - val_loss: 0.1732 - val_accuracy: 0.9442 - lr: 1.3422e-04
# Epoch 84/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0472 - accuracy: 0.9822 - val_loss: 0.1823 - val_accuracy: 0.9453 - lr: 1.3422e-04
# Epoch 85/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.0405 - accuracy: 0.9848 - val_loss: 0.1857 - val_accuracy: 0.9498 - lr: 1.3422e-04
# Epoch 86/300
# 40/40 [==============================] - 4s 108ms/step - loss: 0.0420 - accuracy: 0.9852 - val_loss: 0.2054 - val_accuracy: 0.9464 - lr: 1.3422e-04
# Epoch 87/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0503 - accuracy: 0.9826 - val_loss: 0.1895 - val_accuracy: 0.9475 - lr: 1.0737e-04
# Epoch 88/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.0465 - accuracy: 0.9822 - val_loss: 0.1695 - val_accuracy: 0.9520 - lr: 1.0737e-04
# Epoch 89/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0438 - accuracy: 0.9836 - val_loss: 0.1689 - val_accuracy: 0.9498 - lr: 1.0737e-04
# Epoch 90/300
# 40/40 [==============================] - 4s 106ms/step - loss: 0.0482 - accuracy: 0.9846 - val_loss: 0.1562 - val_accuracy: 0.9509 - lr: 1.0737e-04
# Epoch 91/300
# 40/40 [==============================] - 6s 158ms/step - loss: 0.0441 - accuracy: 0.9836 - val_loss: 0.1628 - val_accuracy: 0.9520 - lr: 1.0737e-04
# Epoch 92/300
# 40/40 [==============================] - 4s 97ms/step - loss: 0.0551 - accuracy: 0.9809 - val_loss: 0.1682 - val_accuracy: 0.9509 - lr: 8.5899e-05
# Epoch 93/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0523 - accuracy: 0.9820 - val_loss: 0.1555 - val_accuracy: 0.9520 - lr: 8.5899e-05
# Epoch 94/300
# 40/40 [==============================] - 6s 153ms/step - loss: 0.0494 - accuracy: 0.9824 - val_loss: 0.1592 - val_accuracy: 0.9542 - lr: 8.5899e-05
# Epoch 95/300
# 40/40 [==============================] - 6s 154ms/step - loss: 0.0473 - accuracy: 0.9814 - val_loss: 0.1576 - val_accuracy: 0.9565 - lr: 8.5899e-05
# Epoch 96/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0459 - accuracy: 0.9828 - val_loss: 0.1706 - val_accuracy: 0.9565 - lr: 8.5899e-05
# Epoch 97/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0408 - accuracy: 0.9846 - val_loss: 0.1725 - val_accuracy: 0.9475 - lr: 8.5899e-05
# Epoch 98/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0430 - accuracy: 0.9838 - val_loss: 0.1643 - val_accuracy: 0.9531 - lr: 8.5899e-05
# Epoch 99/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0420 - accuracy: 0.9852 - val_loss: 0.1809 - val_accuracy: 0.9442 - lr: 8.5899e-05
# Epoch 100/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0435 - accuracy: 0.9850 - val_loss: 0.1828 - val_accuracy: 0.9420 - lr: 8.5899e-05
# Epoch 101/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.0387 - accuracy: 0.9855 - val_loss: 0.1919 - val_accuracy: 0.9487 - lr: 6.8719e-05
# Epoch 102/300
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0441 - accuracy: 0.9848 - val_loss: 0.1816 - val_accuracy: 0.9498 - lr: 6.8719e-05
# Epoch 103/300
# 40/40 [==============================] - 4s 101ms/step - loss: 0.0412 - accuracy: 0.9848 - val_loss: 0.1646 - val_accuracy: 0.9531 - lr: 6.8719e-05
# Epoch 104/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0404 - accuracy: 0.9863 - val_loss: 0.1562 - val_accuracy: 0.9542 - lr: 6.8719e-05
# Epoch 105/300
# 40/40 [==============================] - 4s 102ms/step - loss: 0.0421 - accuracy: 0.9846 - val_loss: 0.1489 - val_accuracy: 0.9509 - lr: 6.8719e-05
# Epoch 106/300
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0432 - accuracy: 0.9844 - val_loss: 0.1498 - val_accuracy: 0.9542 - lr: 5.4976e-05
# Epoch 107/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.0346 - accuracy: 0.9873 - val_loss: 0.1626 - val_accuracy: 0.9565 - lr: 5.4976e-05
# Epoch 108/300
# 40/40 [==============================] - 6s 151ms/step - loss: 0.0409 - accuracy: 0.9859 - val_loss: 0.1637 - val_accuracy: 0.9576 - lr: 5.4976e-05
# Epoch 109/300
# 40/40 [==============================] - 7s 179ms/step - loss: 0.0404 - accuracy: 0.9854 - val_loss: 0.1725 - val_accuracy: 0.9554 - lr: 5.4976e-05
# Epoch 110/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0370 - accuracy: 0.9865 - val_loss: 0.1705 - val_accuracy: 0.9554 - lr: 5.4976e-05
# Epoch 111/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0350 - accuracy: 0.9861 - val_loss: 0.1943 - val_accuracy: 0.9509 - lr: 5.4976e-05
# Epoch 112/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0307 - accuracy: 0.9908 - val_loss: 0.1953 - val_accuracy: 0.9509 - lr: 5.4976e-05
# Epoch 113/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0359 - accuracy: 0.9859 - val_loss: 0.1836 - val_accuracy: 0.9542 - lr: 5.4976e-05
# Epoch 114/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0377 - accuracy: 0.9859 - val_loss: 0.1787 - val_accuracy: 0.9554 - lr: 4.3980e-05
# Epoch 115/300
# 40/40 [==============================] - 4s 98ms/step - loss: 0.0409 - accuracy: 0.9854 - val_loss: 0.1793 - val_accuracy: 0.9565 - lr: 4.3980e-05
# Epoch 116/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0331 - accuracy: 0.9867 - val_loss: 0.1809 - val_accuracy: 0.9576 - lr: 4.3980e-05
# Epoch 117/300
# 40/40 [==============================] - 5s 139ms/step - loss: 0.0318 - accuracy: 0.9896 - val_loss: 0.1762 - val_accuracy: 0.9598 - lr: 4.3980e-05
# Epoch 118/300
# 40/40 [==============================] - 4s 112ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.1797 - val_accuracy: 0.9576 - lr: 4.3980e-05
# Epoch 119/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0387 - accuracy: 0.9867 - val_loss: 0.1797 - val_accuracy: 0.9554 - lr: 4.3980e-05
# Epoch 120/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0355 - accuracy: 0.9879 - val_loss: 0.1786 - val_accuracy: 0.9542 - lr: 4.3980e-05
# Epoch 121/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0352 - accuracy: 0.9867 - val_loss: 0.1715 - val_accuracy: 0.9520 - lr: 4.3980e-05
# Epoch 122/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0411 - accuracy: 0.9844 - val_loss: 0.1728 - val_accuracy: 0.9520 - lr: 4.3980e-05
# Epoch 123/300
# 40/40 [==============================] - 6s 165ms/step - loss: 0.0297 - accuracy: 0.9893 - val_loss: 0.1825 - val_accuracy: 0.9520 - lr: 3.5184e-05
# Epoch 124/300
# 40/40 [==============================] - 4s 112ms/step - loss: 0.0356 - accuracy: 0.9877 - val_loss: 0.1714 - val_accuracy: 0.9531 - lr: 3.5184e-05
# Epoch 125/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0354 - accuracy: 0.9873 - val_loss: 0.1696 - val_accuracy: 0.9542 - lr: 3.5184e-05
# Epoch 126/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.0391 - accuracy: 0.9859 - val_loss: 0.1728 - val_accuracy: 0.9509 - lr: 3.5184e-05
# Epoch 127/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0302 - accuracy: 0.9893 - val_loss: 0.1688 - val_accuracy: 0.9531 - lr: 3.5184e-05
# Epoch 128/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0369 - accuracy: 0.9879 - val_loss: 0.1742 - val_accuracy: 0.9509 - lr: 2.8147e-05
# Epoch 129/300
# 40/40 [==============================] - 4s 104ms/step - loss: 0.0343 - accuracy: 0.9869 - val_loss: 0.1747 - val_accuracy: 0.9520 - lr: 2.8147e-05
# Epoch 130/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0373 - accuracy: 0.9855 - val_loss: 0.1810 - val_accuracy: 0.9509 - lr: 2.8147e-05
# Epoch 131/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.0315 - accuracy: 0.9879 - val_loss: 0.1835 - val_accuracy: 0.9509 - lr: 2.8147e-05
# Epoch 132/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.0331 - accuracy: 0.9883 - val_loss: 0.1785 - val_accuracy: 0.9509 - lr: 2.8147e-05
# Epoch 133/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0330 - accuracy: 0.9877 - val_loss: 0.1743 - val_accuracy: 0.9554 - lr: 2.2518e-05
# Epoch 134/300
# 40/40 [==============================] - 4s 102ms/step - loss: 0.0324 - accuracy: 0.9889 - val_loss: 0.1733 - val_accuracy: 0.9542 - lr: 2.2518e-05
# Epoch 135/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.0311 - accuracy: 0.9887 - val_loss: 0.1762 - val_accuracy: 0.9520 - lr: 2.2518e-05
# Epoch 136/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.0316 - accuracy: 0.9895 - val_loss: 0.1785 - val_accuracy: 0.9487 - lr: 2.2518e-05
# Epoch 137/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.0332 - accuracy: 0.9887 - val_loss: 0.1794 - val_accuracy: 0.9498 - lr: 2.2518e-05
# Epoch 138/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.0273 - accuracy: 0.9920 - val_loss: 0.1793 - val_accuracy: 0.9498 - lr: 1.8014e-05
# Epoch 139/300
# 40/40 [==============================] - 4s 99ms/step - loss: 0.0348 - accuracy: 0.9854 - val_loss: 0.1820 - val_accuracy: 0.9487 - lr: 1.8014e-05
# Epoch 140/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.0264 - accuracy: 0.9885 - val_loss: 0.1831 - val_accuracy: 0.9464 - lr: 1.8014e-05
# Epoch 141/300
# 40/40 [==============================] - 4s 91ms/step - loss: 0.0351 - accuracy: 0.9865 - val_loss: 0.1817 - val_accuracy: 0.9498 - lr: 1.8014e-05
# Epoch 142/300
# 40/40 [==============================] - 29s 736ms/step - loss: 0.0299 - accuracy: 0.9908 - val_loss: 0.1824 - val_accuracy: 0.9498 - lr: 1.8014e-05

# %% [markdown]
# ### Saving and Plotting

# %%
FT_NAME = NAME_MODEL+"_Tuning"
FT_PLOT = NAME_PLOT+"_Tuning"
FT_CMATRIX = NAME_CMATRIX+"_Tuning"

# %% [markdown]
# **Plot Loss**

# %%
plot_losses(history, (20,5), FT_PLOT)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(ft_model, val_dataset, (5,4), FT_CMATRIX)
# Out:
# Exception ignored in: <function Executor.__del__ at 0x7eb09eabe7a0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 46, in __del__
#     self.wait()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 65, in wait
#     pywrap_tfe.TFE_ExecutorWaitForAllPendingNodes(self._handle)
# tensorflow.python.framework.errors_impl.OutOfRangeError: End of sequence
# Accuracy:	 0.9598
# Precision:	 0.9599
# Recall:		 0.9598
# F1:		 0.9598

# %% [markdown]
# **Save the Model**

# %%
if use_tpu:
  # save model locally from tpu using Tensorflow's "SavedModel" format
  save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
  ft_model.save(FT_NAME, options=save_locally)
else:
  ft_model.save(FT_NAME)

# %% [markdown]
# # Zip the Model and the Plots

# %%
# !zip -r {FT_NAME}.zip {FT_NAME} {FT_PLOT}.png {FT_CMATRIX}.png
# !cp {FT_NAME}.zip drive/MyDrive/

# %% [markdown]
# # Notes
# We would like to thank the team of the 2023/2024 AN2DL course taught at Politecnico di Milano
#
# More code available at this link: https://github.com/GioBar00/AN2DL_23-24_Apple_Elixir
#
# Credits:
# >*Andrea Alari*   https://github.com/andrea-alari
#
# >*Giovanni Barbiero* https://github.com/GioBar00
#
# >*Alexandro Sas*  https://github.com/AlexandroSas
