# %% [markdown]
# # AN2DL - Apple Elixir
#
# This notebook contains code of a neural network used in a competition. The goal of the competition was to classify plants into two classes (healthy and unhealthy).
# The model used in this notebook derived from a well known architecture, ConvNeXt, and uses an advanced augmentation technique called MixUp.

# %% [markdown]
# ### Imports and Configs

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install --upgrade tensorflow -q

# %%
# !pip install --upgrade keras-cv -q

# %% [markdown]
# **Imports**

# %%
# Default Imports
import os
import logging
import functools
import warnings as wr
import numpy as np
import random as rnd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
import keras_cv as kcv
from tensorflow import keras as tfk
from keras import layers as tkl
from keras import models as tkm
from keras.preprocessing.image import ImageDataGenerator, random_shear, random_shift
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
# Out:
# Using TensorFlow backend

# %% [markdown]
# **import of the dataset**
#
# this dataset, as presented in the report, is derved from the original one by oversampling the elements in the less represented class

# %%
# !wget -q https://storage.googleapis.com/storage.barbiero.dev/public_data_clean_balanced.npz

# %% [markdown]
# **Randomnes and Configurations**

# %%
# Random Configuration - All
RND = True
if not RND:
  SEED = 76998669
  os.environ['PYTHONHASHSEED'] = str(SEED)
  tf.compat.v1.set_random_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rnd.seed(SEED)

# OS Configuration
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

# Warning Congiguration
wr.simplefilter(action='ignore', category=FutureWarning)
wr.simplefilter(action='ignore', category=Warning)

# TensorFlow Configuration
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# **TPU Setup**

# %%
use_tpu = True  #set this parameter to FALSE if the tpu is not used

if 'COLAB_TPU_ADDR' in os.environ and use_tpu:
  TF_MASTER = 'grpc://{}'.format(os.environ['COLAB_TPU_ADDR'])
  use_tpu = True
else : use_tpu = False

if use_tpu:
  tpu_address = TF_MASTER
  resolver = tf.distribute.cluster_resolver.TPUClusterResolver(TF_MASTER)
  tf.config.experimental_connect_to_cluster(resolver)
  tf.tpu.experimental.initialize_tpu_system(resolver)
  strategy = tf.distribute.TPUStrategy(resolver)

# %% [markdown]
# **Defining Functions**

# %%
# Plotting Functions
# Function used for plotting the loss
def plot_losses(history, figsize, name_jpg):
  best_epoch = np.argmax(history['val_accuracy'])
  fig, axes = plt.subplots(2,1, figsize=figsize, dpi=200)

  axes[0].plot(history['loss'], label='Training Loss', color='#9859C5', alpha=.8)
  axes[0].plot(history['val_loss'], label='Validation Loss', color='#4D61E2', alpha=.8)
  axes[0].set_title('Loss')
  axes[0].legend()
  axes[0].grid(alpha=.3)

  axes[1].plot(history['accuracy'], label='Training Accuracy', color='#9859C5', alpha=.8)
  axes[1].plot(history['val_accuracy'], label='Validation Accuracy', color='#4D61E2', alpha=.8)
  axes[1].plot(best_epoch, history['val_accuracy'][best_epoch], marker='d', alpha=0.8, markersize=10, color='#4D61E2')
  axes[1].set_title('Accuracy')
  axes[1].legend()
  axes[1].grid(alpha=.3)

  plt.savefig(name_jpg)
  plt.show()

# Function used for compute the confusion Matrix
def plot_confusion_matrix(model, test, figsize, name_jpg):
  # Compute the confusion matrix
  y_pred = model.predict(test, verbose=0, steps=(len(X_val) // BATCH_SIZE))
  y_pred = np.argmax(y_pred, axis=-1)
  true_categories = tf.concat([np.argmax(y, axis=-1) for x, y in test], axis=0)
  cm = confusion_matrix(true_categories, y_pred)

  # Compute classification metrics
  accuracy = accuracy_score(true_categories, y_pred)
  precision = precision_score(true_categories, y_pred, average='macro')
  recall = recall_score(true_categories, y_pred, average='macro')
  f1 = f1_score(true_categories, y_pred, average='macro')

  # Display the computed metrics
  print('Accuracy:\t', accuracy.round(4))
  print('Precision:\t', precision.round(4))
  print('Recall:\t\t', recall.round(4))
  print('F1:\t\t', f1.round(4))

  # Plot the confusion matrix
  plt.figure(figsize=figsize, dpi=200)
  sns.heatmap(cm.T, annot=True, cmap='Blues')
  plt.xlabel('True labels')
  plt.ylabel('Predicted labels')
  plt.savefig(name_jpg)
  plt.show()

# Function used for printig a set of images and their corresponding labels
def plot_images(images, labels, index=0, rows=1, cols=1, normalized=False):
  data_rescaling = tkl.Rescaling(scale=1./255)
  if normalized==False:
    IMGS_= data_rescaling(images)
  size = rows*cols
  diff = len(images)-(size+index)
  if diff <= 0:
    size = len(images)-index
    plt.figure(figsize=(cols,rows), dpi=200)
    for i in range(size):
      ax = plt.subplot(rows, cols, i + 1)
      plt.imshow(IMGS_[index + i])
      plt.title(labels[i], fontdict={"fontsize":5}, pad=2)
      plt.axis("off")


# Function used to make predictions
def test_prediction(model, test):
  y_pred = model.predict(test, verbose=0, steps=(len(X_val) // BATCH_SIZE))
  y_pred = np.argmax(y_pred, axis=-1)
  true_categories = tf.concat([np.argmax(y, axis=-1) for x, y in test], axis=0)
  test_accuracy = accuracy_score(true_categories, y_pred)
  print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
  print()

# Function used to plot 9 images belonging to the dataset
def visualize_dataset(dataset, title):
    plt.figure(figsize=(6, 6)).suptitle(title, fontsize=18)
    for i, samples in enumerate(iter(dataset.take(9))):
        images = samples["images"]
        plt.subplot(3, 3, i + 1)
        plt.imshow(images[0].numpy().astype("uint8"))
        plt.axis("off")
    plt.show()

# %% [markdown]
# ### Data Initizialization

# %% [markdown]
# **load the dataset**

# %%
# Initializate
images, labels = np.load('public_data_clean_balanced.npz', allow_pickle=True).values()

print('Images shape: ', images.shape)
print('Labels shape: ', labels.shape)

# Map the categorical attributes into numbers
labels_map = {0: "healthy", 1: "unhealthy"}
labels_rev_map = {"healthy": 0, "unhealthy": 1}
labels = np.array([labels_rev_map[label] for label in labels])
# Out:
# Images shape:  (6120, 96, 96, 3)
# Labels shape:  (6120,)

# %% [markdown]
# **Split the dataset**

# %%
# Split the dataset into a combined training and validation set, and a separate test set
X_train, X_val, y_train, y_val = train_test_split(
    images,
    labels,
    test_size = 0.15,
    stratify = labels,
    random_state = 1234
)

# Conver the categorical attributes in one-hot encoding
y_train = tfk.utils.to_categorical(y_train, 2)
y_val = tfk.utils.to_categorical(y_val, 2)

# Get the Shape of IN OUT
input_shape = X_train.shape[1:]
output_shape = y_train.shape[1]

print(f'Input shape of the Network: {input_shape}')
print(f'Output shape of the Network: {output_shape}')
print()
# Out:
# Input shape of the Network: (96, 96, 3)
# Output shape of the Network: 2

# %% [markdown]
# **Convert the dataset into a TensorFlow Dataset**

# %%
# create a dataset object for each set
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
val_dataset = tf.data.Dataset.from_tensor_slices((X_val, y_val))

# %% [markdown]
# **Preprocess the data**

# %%
# Assign the batch size, note that in case of tpu the batch must be bigger if we want to exploit its performance
if use_tpu:
  BATCH_SIZE = 128
else:
  BATCH_SIZE = 32
AUTOTUNE = tf.data.AUTOTUNE
IMAGE_SIZE = (96, 96)

# This function create a dictionary composed of images and labels
def to_dict(image, label):
    image = tf.image.resize(image, IMAGE_SIZE)
    image = tf.cast(image, tf.float32)
    return {"images": image, "labels": label}


def prepare_trainset(dataset):
    return (
            dataset
            .cache()
            .shuffle(1000, reshuffle_each_iteration=True)
            .map(to_dict, num_parallel_calls=AUTOTUNE)
            .repeat()
            .batch(BATCH_SIZE, drop_remainder=True)
        )

def prepare_valset(dataset):
    return (
            dataset
            .cache()
            .batch(BATCH_SIZE, drop_remainder=True)
        )

# Preprocess the train and validation set
train_dataset = prepare_trainset(train_dataset)
val_dataset = prepare_valset(val_dataset)

# %% [markdown]
# ## *Augmentation*

# %% [markdown]
# **Define the MixUp function**

# %%
mix_up = kcv.layers.MixUp()

def apply_mix_up(inputs):
    inputs = mix_up(inputs, training = True)
    return inputs

# %% [markdown]
# **Define other augmentation layers**

# %%
post_aug = tfk.Sequential([
      tkl.RandomTranslation(height_factor=(-0.5,0.5),width_factor=(-0.5,0.5)),
      tkl.RandomZoom(height_factor=(-0.3,0.3),width_factor=(-0.3,0.3)),
      tkl.RandomFlip(),
      tkl.RandomRotation(factor=0.5)
    ]
  )

def apply_post_aug(inputs):
    inputs["images"] = post_aug(inputs["images"])
    return inputs

# %% [markdown]
# **Apply the augmentation functions to our dataset**

# %%
def preprocess_for_model(inputs):
    images, labels = inputs["images"], inputs["labels"]
    images = tf.cast(images, tf.float32)
    return images, labels

train_dataset = (
    train_dataset
    .map(apply_mix_up, num_parallel_calls=AUTOTUNE)
    .map(preprocess_for_model, num_parallel_calls=AUTOTUNE)
)

train_dataset = train_dataset.prefetch(AUTOTUNE)
val_dataset = val_dataset.prefetch(AUTOTUNE)

# %% [markdown]
# #Define the Model

# %%
from keras.applications.convnext import preprocess_input

def apple_elixir_model(input_shape, output_shape):

  # From Keras.application import ConvNeXt Base
  res = tfk.applications.ConvNeXtBase(
    input_shape=input_shape,
    include_top=False,
    weights="imagenet",
    classes=2,
    classifier_activation='softmax'
  )

  # Set convNeXt as not trainable
  res.trainable = False
  input_layer = tkl.Input(input_shape)   # input layer

  x = preprocess_input(input_layer) # preprocessing
  x = res(x)
  x = tkl.GlobalAveragePooling2D()(x) # GAP
  x = tkl.Dense(units=128,activation=tkl.LeakyReLU(alpha=0.3))(x)     # A dense layer
  x = tkl.Dropout(0.7)(x)

  output_layer = tkl.Dense(units=output_shape,activation='softmax')(x)  # output layer
  model = tfk.Model(input_layer, output_layer)

  # Compile the model
  model.compile(
      loss=tfk.losses.CategoricalCrossentropy(),
      optimizer=tfk.optimizers.Nadam(learning_rate=0.001, weight_decay=0.001),
      metrics=['accuracy']
  )

  return model

if use_tpu:
  with strategy.scope():
    model = apple_elixir_model(input_shape,output_shape)
else:
  model = apple_elixir_model(input_shape,output_shape)

# %% [markdown]
# ### Training

# %% [markdown]
# **CallBacks**

# %%
# Early stopping
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=40,
    mode='max',
    restore_best_weights=True)

# Reduce LR on plateau
lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.85,
    mode='max',
    min_lr=1e-7
)

callbacks = [early_stopping, lr_scheduler]

# %% [markdown]
# **Fit the model**

# %%
history = model.fit(
    train_dataset,
    epochs = 300,
    steps_per_epoch = len(X_train) // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = len(X_val) // BATCH_SIZE,
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 40/40 [==============================] - 28s 237ms/step - loss: 0.7545 - accuracy: 0.6559 - val_loss: 0.4330 - val_accuracy: 0.8013 - lr: 0.0010
# Epoch 2/300
# 40/40 [==============================] - 6s 158ms/step - loss: 0.5592 - accuracy: 0.7527 - val_loss: 0.3954 - val_accuracy: 0.8449 - lr: 0.0010
# Epoch 3/300
# 40/40 [==============================] - 4s 103ms/step - loss: 0.4900 - accuracy: 0.7840 - val_loss: 0.3769 - val_accuracy: 0.8348 - lr: 0.0010
# Epoch 4/300
# 40/40 [==============================] - 4s 113ms/step - loss: 0.4824 - accuracy: 0.7893 - val_loss: 0.3718 - val_accuracy: 0.8516 - lr: 0.0010
# Epoch 5/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.4695 - accuracy: 0.7971 - val_loss: 0.3664 - val_accuracy: 0.8460 - lr: 0.0010
# Epoch 6/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.4613 - accuracy: 0.8084 - val_loss: 0.3457 - val_accuracy: 0.8705 - lr: 0.0010
# Epoch 7/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4468 - accuracy: 0.8174 - val_loss: 0.3396 - val_accuracy: 0.8616 - lr: 0.0010
# Epoch 8/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4359 - accuracy: 0.8287 - val_loss: 0.3341 - val_accuracy: 0.8538 - lr: 0.0010
# Epoch 9/300
# 40/40 [==============================] - 9s 234ms/step - loss: 0.4275 - accuracy: 0.8260 - val_loss: 0.3254 - val_accuracy: 0.8571 - lr: 0.0010
# Epoch 10/300
# 40/40 [==============================] - 5s 114ms/step - loss: 0.4251 - accuracy: 0.8354 - val_loss: 0.3250 - val_accuracy: 0.8717 - lr: 0.0010
# Epoch 11/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.4139 - accuracy: 0.8324 - val_loss: 0.3312 - val_accuracy: 0.8638 - lr: 0.0010
# Epoch 12/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.4148 - accuracy: 0.8363 - val_loss: 0.3489 - val_accuracy: 0.8393 - lr: 0.0010
# Epoch 13/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.4148 - accuracy: 0.8377 - val_loss: 0.3317 - val_accuracy: 0.8527 - lr: 0.0010
# Epoch 14/300
# 40/40 [==============================] - 3s 83ms/step - loss: 0.4155 - accuracy: 0.8418 - val_loss: 0.3242 - val_accuracy: 0.8616 - lr: 0.0010
# Epoch 15/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.4126 - accuracy: 0.8436 - val_loss: 0.3203 - val_accuracy: 0.8560 - lr: 0.0010
# Epoch 16/300
# 40/40 [==============================] - 4s 110ms/step - loss: 0.3884 - accuracy: 0.8496 - val_loss: 0.3139 - val_accuracy: 0.8739 - lr: 8.5000e-04
# Epoch 17/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3904 - accuracy: 0.8562 - val_loss: 0.3128 - val_accuracy: 0.8683 - lr: 8.5000e-04
# Epoch 18/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3846 - accuracy: 0.8562 - val_loss: 0.3134 - val_accuracy: 0.8717 - lr: 8.5000e-04
# Epoch 19/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3878 - accuracy: 0.8520 - val_loss: 0.3036 - val_accuracy: 0.8672 - lr: 8.5000e-04
# Epoch 20/300
# 40/40 [==============================] - 5s 129ms/step - loss: 0.3830 - accuracy: 0.8629 - val_loss: 0.3068 - val_accuracy: 0.8772 - lr: 8.5000e-04
# Epoch 21/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3819 - accuracy: 0.8629 - val_loss: 0.2999 - val_accuracy: 0.8683 - lr: 8.5000e-04
# Epoch 22/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3908 - accuracy: 0.8514 - val_loss: 0.3018 - val_accuracy: 0.8694 - lr: 8.5000e-04
# Epoch 23/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3785 - accuracy: 0.8592 - val_loss: 0.2996 - val_accuracy: 0.8772 - lr: 8.5000e-04
# Epoch 24/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.3677 - accuracy: 0.8693 - val_loss: 0.2934 - val_accuracy: 0.8772 - lr: 8.5000e-04
# Epoch 25/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3713 - accuracy: 0.8664 - val_loss: 0.2916 - val_accuracy: 0.8750 - lr: 8.5000e-04
# Epoch 26/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3803 - accuracy: 0.8545 - val_loss: 0.2972 - val_accuracy: 0.8750 - lr: 7.2250e-04
# Epoch 27/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3673 - accuracy: 0.8711 - val_loss: 0.2925 - val_accuracy: 0.8705 - lr: 7.2250e-04
# Epoch 28/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3770 - accuracy: 0.8668 - val_loss: 0.2918 - val_accuracy: 0.8717 - lr: 7.2250e-04
# Epoch 29/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.3734 - accuracy: 0.8682 - val_loss: 0.2842 - val_accuracy: 0.8806 - lr: 7.2250e-04
# Epoch 30/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.3752 - accuracy: 0.8613 - val_loss: 0.2918 - val_accuracy: 0.8783 - lr: 7.2250e-04
# Epoch 31/300
# 40/40 [==============================] - 6s 161ms/step - loss: 0.3693 - accuracy: 0.8664 - val_loss: 0.2911 - val_accuracy: 0.8828 - lr: 7.2250e-04
# Epoch 32/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3684 - accuracy: 0.8707 - val_loss: 0.2868 - val_accuracy: 0.8783 - lr: 7.2250e-04
# Epoch 33/300
# 40/40 [==============================] - 4s 91ms/step - loss: 0.3586 - accuracy: 0.8707 - val_loss: 0.2964 - val_accuracy: 0.8761 - lr: 7.2250e-04
# Epoch 34/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3457 - accuracy: 0.8826 - val_loss: 0.2817 - val_accuracy: 0.8728 - lr: 7.2250e-04
# Epoch 35/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3555 - accuracy: 0.8744 - val_loss: 0.2865 - val_accuracy: 0.8750 - lr: 7.2250e-04
# Epoch 36/300
# 40/40 [==============================] - 3s 72ms/step - loss: 0.3551 - accuracy: 0.8725 - val_loss: 0.2840 - val_accuracy: 0.8717 - lr: 7.2250e-04
# Epoch 37/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3512 - accuracy: 0.8773 - val_loss: 0.2860 - val_accuracy: 0.8783 - lr: 6.1413e-04
# Epoch 38/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3616 - accuracy: 0.8680 - val_loss: 0.2846 - val_accuracy: 0.8750 - lr: 6.1413e-04
# Epoch 39/300
# 40/40 [==============================] - 3s 83ms/step - loss: 0.3594 - accuracy: 0.8766 - val_loss: 0.2819 - val_accuracy: 0.8772 - lr: 6.1413e-04
# Epoch 40/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3576 - accuracy: 0.8797 - val_loss: 0.2816 - val_accuracy: 0.8828 - lr: 6.1413e-04
# Epoch 41/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3514 - accuracy: 0.8811 - val_loss: 0.2868 - val_accuracy: 0.8772 - lr: 6.1413e-04
# Epoch 42/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3455 - accuracy: 0.8768 - val_loss: 0.2843 - val_accuracy: 0.8694 - lr: 5.2201e-04
# Epoch 43/300
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3550 - accuracy: 0.8732 - val_loss: 0.2767 - val_accuracy: 0.8750 - lr: 5.2201e-04
# Epoch 44/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.3434 - accuracy: 0.8824 - val_loss: 0.2755 - val_accuracy: 0.8817 - lr: 5.2201e-04
# Epoch 45/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3383 - accuracy: 0.8795 - val_loss: 0.2726 - val_accuracy: 0.8795 - lr: 5.2201e-04
# Epoch 46/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3504 - accuracy: 0.8746 - val_loss: 0.2746 - val_accuracy: 0.8761 - lr: 5.2201e-04
# Epoch 47/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3318 - accuracy: 0.8869 - val_loss: 0.2784 - val_accuracy: 0.8772 - lr: 4.4371e-04
# Epoch 48/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3393 - accuracy: 0.8816 - val_loss: 0.2744 - val_accuracy: 0.8795 - lr: 4.4371e-04
# Epoch 49/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3466 - accuracy: 0.8799 - val_loss: 0.2721 - val_accuracy: 0.8783 - lr: 4.4371e-04
# Epoch 50/300
# 40/40 [==============================] - 5s 124ms/step - loss: 0.3369 - accuracy: 0.8848 - val_loss: 0.2712 - val_accuracy: 0.8839 - lr: 4.4371e-04
# Epoch 51/300
# 40/40 [==============================] - 5s 128ms/step - loss: 0.3444 - accuracy: 0.8830 - val_loss: 0.2688 - val_accuracy: 0.8873 - lr: 4.4371e-04
# Epoch 52/300
# 40/40 [==============================] - 3s 72ms/step - loss: 0.3362 - accuracy: 0.8834 - val_loss: 0.2765 - val_accuracy: 0.8839 - lr: 4.4371e-04
# Epoch 53/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3324 - accuracy: 0.8873 - val_loss: 0.2740 - val_accuracy: 0.8817 - lr: 4.4371e-04
# Epoch 54/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3333 - accuracy: 0.8877 - val_loss: 0.2736 - val_accuracy: 0.8761 - lr: 4.4371e-04
# Epoch 55/300
# 40/40 [==============================] - 3s 73ms/step - loss: 0.3409 - accuracy: 0.8795 - val_loss: 0.2827 - val_accuracy: 0.8672 - lr: 4.4371e-04
# Epoch 56/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3398 - accuracy: 0.8883 - val_loss: 0.2723 - val_accuracy: 0.8761 - lr: 4.4371e-04
# Epoch 57/300
# 40/40 [==============================] - 3s 83ms/step - loss: 0.3297 - accuracy: 0.8869 - val_loss: 0.2729 - val_accuracy: 0.8795 - lr: 3.7715e-04
# Epoch 58/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3301 - accuracy: 0.8924 - val_loss: 0.2648 - val_accuracy: 0.8828 - lr: 3.7715e-04
# Epoch 59/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3266 - accuracy: 0.8898 - val_loss: 0.2654 - val_accuracy: 0.8817 - lr: 3.7715e-04
# Epoch 60/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3275 - accuracy: 0.8855 - val_loss: 0.2648 - val_accuracy: 0.8795 - lr: 3.7715e-04
# Epoch 61/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3319 - accuracy: 0.8904 - val_loss: 0.2717 - val_accuracy: 0.8850 - lr: 3.7715e-04
# Epoch 62/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3305 - accuracy: 0.8941 - val_loss: 0.2646 - val_accuracy: 0.8817 - lr: 3.2058e-04
# Epoch 63/300
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3280 - accuracy: 0.8945 - val_loss: 0.2656 - val_accuracy: 0.8761 - lr: 3.2058e-04
# Epoch 64/300
# 40/40 [==============================] - 4s 113ms/step - loss: 0.3229 - accuracy: 0.8902 - val_loss: 0.2620 - val_accuracy: 0.8839 - lr: 3.2058e-04
# Epoch 65/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3235 - accuracy: 0.8961 - val_loss: 0.2657 - val_accuracy: 0.8839 - lr: 3.2058e-04
# Epoch 66/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3251 - accuracy: 0.8928 - val_loss: 0.2642 - val_accuracy: 0.8839 - lr: 3.2058e-04
# Epoch 67/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3277 - accuracy: 0.8924 - val_loss: 0.2645 - val_accuracy: 0.8873 - lr: 2.7249e-04
# Epoch 68/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3271 - accuracy: 0.8902 - val_loss: 0.2617 - val_accuracy: 0.8839 - lr: 2.7249e-04
# Epoch 69/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3198 - accuracy: 0.8955 - val_loss: 0.2639 - val_accuracy: 0.8817 - lr: 2.7249e-04
# Epoch 70/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3306 - accuracy: 0.8879 - val_loss: 0.2621 - val_accuracy: 0.8839 - lr: 2.7249e-04
# Epoch 71/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.3253 - accuracy: 0.8945 - val_loss: 0.2655 - val_accuracy: 0.8839 - lr: 2.7249e-04
# Epoch 72/300
# 40/40 [==============================] - 4s 89ms/step - loss: 0.3159 - accuracy: 0.8996 - val_loss: 0.2620 - val_accuracy: 0.8839 - lr: 2.3162e-04
# Epoch 73/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3196 - accuracy: 0.8949 - val_loss: 0.2613 - val_accuracy: 0.8873 - lr: 2.3162e-04
# Epoch 74/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3249 - accuracy: 0.8941 - val_loss: 0.2655 - val_accuracy: 0.8839 - lr: 2.3162e-04
# Epoch 75/300
# 40/40 [==============================] - 3s 77ms/step - loss: 0.3156 - accuracy: 0.8992 - val_loss: 0.2640 - val_accuracy: 0.8839 - lr: 2.3162e-04
# Epoch 76/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3196 - accuracy: 0.8980 - val_loss: 0.2612 - val_accuracy: 0.8850 - lr: 2.3162e-04
# Epoch 77/300
# 40/40 [==============================] - 3s 83ms/step - loss: 0.3167 - accuracy: 0.8977 - val_loss: 0.2612 - val_accuracy: 0.8862 - lr: 1.9687e-04
# Epoch 78/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3238 - accuracy: 0.9014 - val_loss: 0.2594 - val_accuracy: 0.8817 - lr: 1.9687e-04
# Epoch 79/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3228 - accuracy: 0.8947 - val_loss: 0.2606 - val_accuracy: 0.8828 - lr: 1.9687e-04
# Epoch 80/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3052 - accuracy: 0.9043 - val_loss: 0.2589 - val_accuracy: 0.8828 - lr: 1.9687e-04
# Epoch 81/300
# 40/40 [==============================] - 3s 69ms/step - loss: 0.3177 - accuracy: 0.9002 - val_loss: 0.2592 - val_accuracy: 0.8828 - lr: 1.9687e-04
# Epoch 82/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3042 - accuracy: 0.9062 - val_loss: 0.2564 - val_accuracy: 0.8850 - lr: 1.6734e-04
# Epoch 83/300
# 40/40 [==============================] - 3s 84ms/step - loss: 0.3199 - accuracy: 0.8961 - val_loss: 0.2583 - val_accuracy: 0.8817 - lr: 1.6734e-04
# Epoch 84/300
# 40/40 [==============================] - 4s 113ms/step - loss: 0.3127 - accuracy: 0.9035 - val_loss: 0.2559 - val_accuracy: 0.8850 - lr: 1.6734e-04
# Epoch 85/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.3116 - accuracy: 0.9051 - val_loss: 0.2586 - val_accuracy: 0.8917 - lr: 1.6734e-04
# Epoch 86/300
# 40/40 [==============================] - 3s 70ms/step - loss: 0.3191 - accuracy: 0.8969 - val_loss: 0.2612 - val_accuracy: 0.8806 - lr: 1.6734e-04
# Epoch 87/300
# 40/40 [==============================] - 3s 72ms/step - loss: 0.3136 - accuracy: 0.8961 - val_loss: 0.2605 - val_accuracy: 0.8873 - lr: 1.6734e-04
# Epoch 88/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3132 - accuracy: 0.9008 - val_loss: 0.2589 - val_accuracy: 0.8873 - lr: 1.6734e-04
# Epoch 89/300
# 40/40 [==============================] - 3s 83ms/step - loss: 0.3215 - accuracy: 0.8973 - val_loss: 0.2601 - val_accuracy: 0.8828 - lr: 1.6734e-04
# Epoch 90/300
# 40/40 [==============================] - 3s 81ms/step - loss: 0.3126 - accuracy: 0.9006 - val_loss: 0.2577 - val_accuracy: 0.8884 - lr: 1.6734e-04
# Epoch 91/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3095 - accuracy: 0.9066 - val_loss: 0.2570 - val_accuracy: 0.8850 - lr: 1.4224e-04
# Epoch 92/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3122 - accuracy: 0.8986 - val_loss: 0.2571 - val_accuracy: 0.8873 - lr: 1.4224e-04
# Epoch 93/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3081 - accuracy: 0.9076 - val_loss: 0.2598 - val_accuracy: 0.8817 - lr: 1.4224e-04
# Epoch 94/300
# 40/40 [==============================] - 3s 75ms/step - loss: 0.3164 - accuracy: 0.9020 - val_loss: 0.2590 - val_accuracy: 0.8850 - lr: 1.4224e-04
# Epoch 95/300
# 40/40 [==============================] - 3s 80ms/step - loss: 0.3177 - accuracy: 0.9041 - val_loss: 0.2557 - val_accuracy: 0.8884 - lr: 1.4224e-04
# Epoch 96/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3157 - accuracy: 0.8998 - val_loss: 0.2595 - val_accuracy: 0.8862 - lr: 1.2091e-04
# Epoch 97/300
# 40/40 [==============================] - 3s 75ms/step - loss: 0.3140 - accuracy: 0.9016 - val_loss: 0.2582 - val_accuracy: 0.8862 - lr: 1.2091e-04
# Epoch 98/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3154 - accuracy: 0.9045 - val_loss: 0.2593 - val_accuracy: 0.8850 - lr: 1.2091e-04
# Epoch 99/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3076 - accuracy: 0.9057 - val_loss: 0.2575 - val_accuracy: 0.8895 - lr: 1.2091e-04
# Epoch 100/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3066 - accuracy: 0.9035 - val_loss: 0.2579 - val_accuracy: 0.8884 - lr: 1.2091e-04
# Epoch 101/300
# 40/40 [==============================] - 3s 75ms/step - loss: 0.3060 - accuracy: 0.9043 - val_loss: 0.2556 - val_accuracy: 0.8884 - lr: 1.0277e-04
# Epoch 102/300
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3027 - accuracy: 0.9105 - val_loss: 0.2587 - val_accuracy: 0.8839 - lr: 1.0277e-04
# Epoch 103/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3071 - accuracy: 0.9055 - val_loss: 0.2568 - val_accuracy: 0.8839 - lr: 1.0277e-04
# Epoch 104/300
# 40/40 [==============================] - 4s 98ms/step - loss: 0.3136 - accuracy: 0.8965 - val_loss: 0.2535 - val_accuracy: 0.8873 - lr: 1.0277e-04
# Epoch 105/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3077 - accuracy: 0.9070 - val_loss: 0.2537 - val_accuracy: 0.8850 - lr: 1.0277e-04
# Epoch 106/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3083 - accuracy: 0.9041 - val_loss: 0.2547 - val_accuracy: 0.8862 - lr: 8.7354e-05
# Epoch 107/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3029 - accuracy: 0.9092 - val_loss: 0.2535 - val_accuracy: 0.8850 - lr: 8.7354e-05
# Epoch 108/300
# 40/40 [==============================] - 3s 79ms/step - loss: 0.3099 - accuracy: 0.9035 - val_loss: 0.2547 - val_accuracy: 0.8862 - lr: 8.7354e-05
# Epoch 109/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3119 - accuracy: 0.9039 - val_loss: 0.2570 - val_accuracy: 0.8862 - lr: 8.7354e-05
# Epoch 110/300
# 40/40 [==============================] - 3s 86ms/step - loss: 0.3054 - accuracy: 0.8928 - val_loss: 0.2560 - val_accuracy: 0.8873 - lr: 8.7354e-05
# Epoch 111/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.3074 - accuracy: 0.9057 - val_loss: 0.2559 - val_accuracy: 0.8862 - lr: 7.4251e-05
# Epoch 112/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3033 - accuracy: 0.9072 - val_loss: 0.2571 - val_accuracy: 0.8850 - lr: 7.4251e-05
# Epoch 113/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3063 - accuracy: 0.9029 - val_loss: 0.2559 - val_accuracy: 0.8839 - lr: 7.4251e-05
# Epoch 114/300
# 40/40 [==============================] - 3s 71ms/step - loss: 0.2981 - accuracy: 0.9080 - val_loss: 0.2545 - val_accuracy: 0.8862 - lr: 7.4251e-05
# Epoch 115/300
# 40/40 [==============================] - 3s 78ms/step - loss: 0.3117 - accuracy: 0.9020 - val_loss: 0.2545 - val_accuracy: 0.8884 - lr: 7.4251e-05
# Epoch 116/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.3035 - accuracy: 0.9006 - val_loss: 0.2517 - val_accuracy: 0.8862 - lr: 6.3113e-05
# Epoch 117/300
# 40/40 [==============================] - 3s 74ms/step - loss: 0.3083 - accuracy: 0.9094 - val_loss: 0.2566 - val_accuracy: 0.8862 - lr: 6.3113e-05
# Epoch 118/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3054 - accuracy: 0.9109 - val_loss: 0.2539 - val_accuracy: 0.8862 - lr: 6.3113e-05
# Epoch 119/300
# 40/40 [==============================] - 3s 67ms/step - loss: 0.3000 - accuracy: 0.9150 - val_loss: 0.2536 - val_accuracy: 0.8850 - lr: 6.3113e-05
# Epoch 120/300
# 40/40 [==============================] - 3s 66ms/step - loss: 0.3087 - accuracy: 0.9102 - val_loss: 0.2528 - val_accuracy: 0.8873 - lr: 6.3113e-05
# Epoch 121/300
# 40/40 [==============================] - 3s 76ms/step - loss: 0.2996 - accuracy: 0.9111 - val_loss: 0.2528 - val_accuracy: 0.8895 - lr: 5.3646e-05
# Epoch 122/300
# 40/40 [==============================] - 3s 82ms/step - loss: 0.3069 - accuracy: 0.9164 - val_loss: 0.2525 - val_accuracy: 0.8862 - lr: 5.3646e-05
# Epoch 123/300
# 40/40 [==============================] - 5s 115ms/step - loss: 0.3070 - accuracy: 0.9049 - val_loss: 0.2555 - val_accuracy: 0.8884 - lr: 5.3646e-05
# Epoch 124/300
# 40/40 [==============================] - 3s 68ms/step - loss: 0.3062 - accuracy: 0.9025 - val_loss: 0.2535 - val_accuracy: 0.8873 - lr: 5.3646e-05
# Epoch 125/300
# 40/40 [==============================] - 27s 691ms/step - loss: 0.3129 - accuracy: 0.8979 - val_loss: 0.2533 - val_accuracy: 0.8862 - lr: 5.3646e-05

# %% [markdown]
# ### Saving and Plotting

# %%
NAME_MODEL = "ConvNeXt_Only_MixUp"
NAME_PLOT = NAME_MODEL + "_plot"
NAME_CMATRIX = NAME_MODEL + "_cmatrix"

# %% [markdown]
# **Plots Loss**

# %%
plot_losses(history, (20,5), NAME_PLOT)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(model, val_dataset, (5,4), NAME_CMATRIX)
# Out:
# Exception ignored in: <function Executor.__del__ at 0x7db54606ac20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 46, in __del__
#     self.wait()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 65, in wait
#     pywrap_tfe.TFE_ExecutorWaitForAllPendingNodes(self._handle)
# tensorflow.python.framework.errors_impl.OutOfRangeError: End of sequence
# Accuracy:	 0.8917
# Precision:	 0.8935
# Recall:		 0.8919
# F1:		 0.8916

# %% [markdown]
# **Save the Model**

# %%
if use_tpu:
  # save model locally from tpu using Tensorflow's "SavedModel" format
  save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
  model.save(NAME_MODEL, options=save_locally)
else:
  model.save(NAME_MODEL)

# %% [markdown]
# **Delete the Model**

# %%
del model, history

# %% [markdown]
# ## Fine Tuning

# %% [markdown]
# **Load the Model**

# %%
if use_tpu:
  with strategy.scope():
    load_locally = tf.saved_model.LoadOptions(experimental_io_device='/job:localhost')
    ft_model = tf.keras.models.load_model(NAME_MODEL, options=load_locally)
else:
  ft_model = tfk.models.load_model(NAME_MODEL)

# %% [markdown]
# **Train only the Last Layers**

# %%
ft_model.get_layer('convnext_base').trainable = True

for i, layer in enumerate(ft_model.get_layer('convnext_base').layers[:200]):
  layer.trainable=False

ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Nadam(learning_rate=0.001, weight_decay=0.001), metrics=['accuracy'])

# %% [markdown]
# **Train the Tuning Model**

# %%
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=25,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',
    patience=5,
    factor=0.80,
    mode='max',
    min_lr=1e-7
)

callbacks = [early_stopping, lr_scheduler]

history = ft_model.fit(
    train_dataset,
    epochs = 300,
    steps_per_epoch = len(X_train) // BATCH_SIZE,
    validation_data = val_dataset,
    validation_steps = len(X_val) // BATCH_SIZE,
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 40/40 [==============================] - 99s 496ms/step - loss: 1.1120 - accuracy: 0.7707 - val_loss: 0.3597 - val_accuracy: 0.8460 - lr: 0.0010
# Epoch 2/300
# 40/40 [==============================] - 6s 157ms/step - loss: 0.3226 - accuracy: 0.9006 - val_loss: 0.2106 - val_accuracy: 0.9107 - lr: 0.0010
# Epoch 3/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.2543 - accuracy: 0.9324 - val_loss: 0.2899 - val_accuracy: 0.8850 - lr: 0.0010
# Epoch 4/300
# 40/40 [==============================] - 7s 181ms/step - loss: 0.2407 - accuracy: 0.9449 - val_loss: 0.1853 - val_accuracy: 0.9308 - lr: 0.0010
# Epoch 5/300
# 40/40 [==============================] - 6s 142ms/step - loss: 0.2078 - accuracy: 0.9611 - val_loss: 0.1801 - val_accuracy: 0.9308 - lr: 0.0010
# Epoch 6/300
# 40/40 [==============================] - 7s 187ms/step - loss: 0.1959 - accuracy: 0.9631 - val_loss: 0.1862 - val_accuracy: 0.9442 - lr: 0.0010
# Epoch 7/300
# 40/40 [==============================] - 4s 98ms/step - loss: 0.1920 - accuracy: 0.9635 - val_loss: 0.1746 - val_accuracy: 0.9308 - lr: 0.0010
# Epoch 8/300
# 40/40 [==============================] - 4s 98ms/step - loss: 0.1892 - accuracy: 0.9701 - val_loss: 0.2055 - val_accuracy: 0.9252 - lr: 0.0010
# Epoch 9/300
# 40/40 [==============================] - 4s 108ms/step - loss: 0.1809 - accuracy: 0.9734 - val_loss: 0.1797 - val_accuracy: 0.9308 - lr: 0.0010
# Epoch 10/300
# 40/40 [==============================] - 4s 111ms/step - loss: 0.1864 - accuracy: 0.9719 - val_loss: 0.1787 - val_accuracy: 0.9297 - lr: 0.0010
# Epoch 11/300
# 40/40 [==============================] - 4s 98ms/step - loss: 0.1774 - accuracy: 0.9732 - val_loss: 0.1917 - val_accuracy: 0.9252 - lr: 0.0010
# Epoch 12/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.1801 - accuracy: 0.9736 - val_loss: 0.1747 - val_accuracy: 0.9353 - lr: 8.0000e-04
# Epoch 13/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.1758 - accuracy: 0.9754 - val_loss: 0.1883 - val_accuracy: 0.9330 - lr: 8.0000e-04
# Epoch 14/300
# 40/40 [==============================] - 4s 108ms/step - loss: 0.1759 - accuracy: 0.9719 - val_loss: 0.1741 - val_accuracy: 0.9375 - lr: 8.0000e-04
# Epoch 15/300
# 40/40 [==============================] - 4s 109ms/step - loss: 0.1737 - accuracy: 0.9758 - val_loss: 0.1777 - val_accuracy: 0.9364 - lr: 8.0000e-04
# Epoch 16/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.1706 - accuracy: 0.9803 - val_loss: 0.2032 - val_accuracy: 0.9297 - lr: 8.0000e-04
# Epoch 17/300
# 40/40 [==============================] - 4s 93ms/step - loss: 0.1748 - accuracy: 0.9738 - val_loss: 0.1634 - val_accuracy: 0.9408 - lr: 6.4000e-04
# Epoch 18/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.1715 - accuracy: 0.9797 - val_loss: 0.1727 - val_accuracy: 0.9386 - lr: 6.4000e-04
# Epoch 19/300
# 40/40 [==============================] - 4s 105ms/step - loss: 0.1702 - accuracy: 0.9764 - val_loss: 0.1642 - val_accuracy: 0.9397 - lr: 6.4000e-04
# Epoch 20/300
# 40/40 [==============================] - 4s 106ms/step - loss: 0.1746 - accuracy: 0.9777 - val_loss: 0.1779 - val_accuracy: 0.9386 - lr: 6.4000e-04
# Epoch 21/300
# 40/40 [==============================] - 4s 95ms/step - loss: 0.1655 - accuracy: 0.9795 - val_loss: 0.1798 - val_accuracy: 0.9330 - lr: 6.4000e-04
# Epoch 22/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.1714 - accuracy: 0.9793 - val_loss: 0.1802 - val_accuracy: 0.9364 - lr: 5.1200e-04
# Epoch 23/300
# 40/40 [==============================] - 4s 94ms/step - loss: 0.1680 - accuracy: 0.9732 - val_loss: 0.1717 - val_accuracy: 0.9397 - lr: 5.1200e-04
# Epoch 24/300
# 40/40 [==============================] - 4s 106ms/step - loss: 0.1693 - accuracy: 0.9809 - val_loss: 0.1613 - val_accuracy: 0.9431 - lr: 5.1200e-04
# Epoch 25/300
# 40/40 [==============================] - 4s 107ms/step - loss: 0.1711 - accuracy: 0.9789 - val_loss: 0.1744 - val_accuracy: 0.9386 - lr: 5.1200e-04
# Epoch 26/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1631 - accuracy: 0.9824 - val_loss: 0.1694 - val_accuracy: 0.9386 - lr: 5.1200e-04
# Epoch 27/300
# 40/40 [==============================] - 4s 96ms/step - loss: 0.1661 - accuracy: 0.9783 - val_loss: 0.1727 - val_accuracy: 0.9408 - lr: 4.0960e-04
# Epoch 28/300
# 40/40 [==============================] - 4s 92ms/step - loss: 0.1629 - accuracy: 0.9803 - val_loss: 0.2002 - val_accuracy: 0.9230 - lr: 4.0960e-04
# Epoch 29/300
# 40/40 [==============================] - 4s 106ms/step - loss: 0.1664 - accuracy: 0.9771 - val_loss: 0.1781 - val_accuracy: 0.9364 - lr: 4.0960e-04
# Epoch 30/300
# 40/40 [==============================] - 4s 108ms/step - loss: 0.1637 - accuracy: 0.9799 - val_loss: 0.1801 - val_accuracy: 0.9342 - lr: 4.0960e-04
# Epoch 31/300
# 40/40 [==============================] - 28s 721ms/step - loss: 0.1647 - accuracy: 0.9826 - val_loss: 0.1751 - val_accuracy: 0.9386 - lr: 4.0960e-04

# %% [markdown]
# ### Saving and Plotting

# %%
FT_NAME = NAME_MODEL+"_Tuning"
FT_PLOT = NAME_PLOT+"_Tuning"
FT_CMATRIX = NAME_CMATRIX+"_Tuning"

# %% [markdown]
# **Plot Loss**

# %%
plot_losses(history, (20,5), FT_PLOT)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(ft_model, val_dataset, (5,4), FT_CMATRIX)
# Out:
# Exception ignored in: <function Executor.__del__ at 0x7db54606ac20>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 46, in __del__
#     self.wait()
#   File "/usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/executor.py", line 65, in wait
#     pywrap_tfe.TFE_ExecutorWaitForAllPendingNodes(self._handle)
# tensorflow.python.framework.errors_impl.OutOfRangeError: End of sequence
# Accuracy:	 0.9442
# Precision:	 0.9446
# Recall:		 0.9443
# F1:		 0.9442

# %% [markdown]
# **Save the Model**

# %%
if use_tpu:
  # save model locally from tpu using Tensorflow's "SavedModel" format
  save_locally = tf.saved_model.SaveOptions(experimental_io_device='/job:localhost')
  ft_model.save(FT_NAME, options=save_locally)
else:
  ft_model.save(FT_NAME)

# %% [markdown]
# # Zip the Model and the Plots

# %%
# !zip -r {FT_NAME}.zip {FT_NAME} {FT_PLOT}.png {FT_CMATRIX}.png
# !cp {FT_NAME}.zip drive/MyDrive/
# Out:
#   adding: ConvNeXt_Only_MixUp_Tuning/ (stored 0%)
#   adding: ConvNeXt_Only_MixUp_Tuning/saved_model.pb (deflated 92%)
#   adding: ConvNeXt_Only_MixUp_Tuning/variables/ (stored 0%)
#   adding: ConvNeXt_Only_MixUp_Tuning/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXt_Only_MixUp_Tuning/variables/variables.index (deflated 78%)
#   adding: ConvNeXt_Only_MixUp_Tuning/assets/ (stored 0%)
#   adding: ConvNeXt_Only_MixUp_Tuning/keras_metadata.pb (deflated 96%)
#   adding: ConvNeXt_Only_MixUp_Tuning/fingerprint.pb (stored 0%)
#   adding: ConvNeXt_Only_MixUp_plot_Tuning.png (deflated 16%)
#   adding: ConvNeXt_Only_MixUp_cmatrix_Tuning.png (deflated 16%)

# %% [markdown]
# # Notes
# We would like to thank the team of the 2023/2024 AN2DL course taught at Politecnico di Milano
#
# More code available at this link: https://github.com/GioBar00/AN2DL_23-24_Apple_Elixir
#
# Credits:
# >*Andrea Alari*   https://github.com/andrea-alari
#
# >*Giovanni Barbiero* https://github.com/GioBar00
#
# >*Alexandro Sas*  https://github.com/AlexandroSas
