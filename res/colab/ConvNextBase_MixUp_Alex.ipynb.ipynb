# %% [markdown]
# **Mount the Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Imports and Configs

# %% [markdown]
# **Imports**

# %%
# Deafault Imports
import os
import logging
import functools
import warnings as wr
import numpy as np
import random as rnd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras as tfk
from keras import layers as tkl
from keras import models as tkm
from keras.preprocessing.image import ImageDataGenerator, random_shear, random_shift
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix

# !wget https://storage.googleapis.com/storage.barbiero.dev/public_data_clean.npz
# Out:
# --2023-11-12 18:59:19--  https://storage.googleapis.com/storage.barbiero.dev/public_data_clean.npz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.130.207, 74.125.68.207, 64.233.170.207, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.130.207|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 536546306 (512M) [application/octet-stream]
# Saving to: ‘public_data_clean.npz’
#
# public_data_clean.n 100%[===================>] 511.69M  12.0MB/s    in 43s
#
# 2023-11-12 19:00:04 (11.8 MB/s) - ‘public_data_clean.npz’ saved [536546306/536546306]

# %% [markdown]
# **Randomnes and Configurations**

# %%
# Names
NAME_MODEL = "ConvNeXt_8k"
NAME_PLOT = NAME_MODEL + "_plot"
NAME_CMATRIX = NAME_MODEL + "_cmatrix"

# Random Configuration - All
RND = True
if not RND:
  SEED = 76998669
  os.environ['PYTHONHASHSEED'] = str(SEED)
  tf.compat.v1.set_random_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rnd.seed(SEED)

# OS Configuration
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

# Warning Congiguration
wr.simplefilter(action='ignore', category=FutureWarning)
wr.simplefilter(action='ignore', category=Warning)

# TensorFlow Configuration
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# **Defining Functions**

# %%
# Plotting Functions
def plot_losses(history, figsize, name_jpg):
  best_epoch = np.argmax(history['val_accuracy'])
  fig, axes = plt.subplots(2,1, figsize=figsize, dpi=200)

  axes[0].plot(history['loss'], label='Training Loss', color='#9859C5', alpha=.8)
  axes[0].plot(history['val_loss'], label='Validation Loss', color='#4D61E2', alpha=.8)
  axes[0].set_title('Loss')
  axes[0].legend()
  axes[0].grid(alpha=.3)

  axes[1].plot(history['accuracy'], label='Training Accuracy', color='#9859C5', alpha=.8)
  axes[1].plot(history['val_accuracy'], label='Validation Accuracy', color='#4D61E2', alpha=.8)
  axes[1].plot(best_epoch, history['val_accuracy'][best_epoch], marker='d', alpha=0.8, markersize=10, color='#4D61E2')
  axes[1].set_title('Accuracy')
  axes[1].legend()
  axes[1].grid(alpha=.3)

  plt.savefig(name_jpg)
  plt.show()
def plot_confusion_matrix(model, test, test_lbls, figsize, name_jpg):
  # Compute the confusion matrix
  tp = model.predict(test, verbose=0)
  cm = confusion_matrix(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1))

  # Compute classification metrics
  accuracy = accuracy_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1))
  precision = precision_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1), average='macro')
  recall = recall_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1), average='macro')
  f1 = f1_score(np.argmax(test_lbls, axis=-1), np.argmax(tp, axis=-1), average='macro')

  # Display the computed metrics
  print('Accuracy:\t', accuracy.round(4))
  print('Precision:\t', precision.round(4))
  print('Recall:\t\t', recall.round(4))
  print('F1:\t\t', f1.round(4))

  # Plot the confusion matrix
  lbls = ["Unhealthy", "Healthy"]
  plt.figure(figsize=figsize, dpi=200)
  sns.heatmap(cm.T, annot=True, cmap='Blues', xticklabels=lbls, yticklabels=lbls)
  plt.xlabel('Labels', fontsize=6)
  plt.xticks(fontsize=8)
  plt.ylabel('Predicted Labels', fontsize=6)
  plt.yticks(fontsize=8)
  plt.savefig(name_jpg)
  plt.show()
def plot_images(images, labels, index=0, rows=1, cols=1, normalized=False):
  data_rescaling = tkl.Rescaling(scale=1./255)
  if normalized==False:
    IMGS_= data_rescaling(images)
  size = rows*cols
  diff = len(images)-(size+index)
  if diff <= 0:
    size = len(images)-index
    plt.figure(figsize=(cols,rows), dpi=200)
    for i in range(size):
      ax = plt.subplot(rows, cols, i + 1)
      plt.imshow(IMGS_[index + i])
      plt.title(labels[i], fontdict={"fontsize":5}, pad=2)
      plt.axis("off")

# Data Agumentation Functions
def pick_random_label(i, lbls, lbl):
  if lbls[i] == lbl:
    return True
  else:
    return False
def manual_augmentation(imgs, lbls, string_lbls):
  cardinality = pd.DataFrame(string_lbls, columns=['class'])['class'].value_counts()       # Store the Cardinality of the SETS "healthy", "unhealthy"
  ch = cardinality['healthy']
  cu = cardinality['unhealthy']
  diff = ch-cu
  print(cardinality)

  i_arr = []
  ROWS = 2
  COLS = 4
  augm = []
  augm_lbl = []

  if diff > 0:
    print("Augment the Unhealthy with ", diff, "new images")
    for z in range(int(diff/7)):
      index = rnd.randint(0, len(lbls)-1)
      while not pick_random_label(index, string_lbls, "unhealthy") or index in i_arr:
        i_arr.append(index)
        index = rnd.randint(0, len(lbls)-1)

      if string_lbls[index] == "unhealthy":
        i_arr.append(index)
        img = imgs[index]
        for row in range(ROWS):
            for col in range(COLS):
                img = np.rot90(img)
                if row==0 and col==3:
                    continue
                augm.append(img)
                augm_lbl.append(lbls[index])
            if row == 0:
                img = np.flipud(img)
  else:
    print("Augment the Healthy with ", diff, "new images")
    for z in range(int(-diff/7)):
      index = rnd.randint(0, len(lbls)-1)
      while not pick_random_label(index, string_lbls, "unhealthy") or index in i_arr:
        i_arr.append(index)
        index = rnd.randint(0, len(lbls)-1)

      if string_lbls[index] == "unhealthy":
        i_arr.append(index)
        img = imgs[index]
        for row in range(ROWS):
            for col in range(COLS):
                img = np.rot90(img)
                if row==0 and col==3:
                    continue
                augm.append(img)
                augm_lbl.append(lbls[index])
            if row == 0:
                img = np.flipud(img)

  # augm_lbl = list(map(lambda x: 0 if x == "healthy" else 1, augm_lbl))
  # augm_lbl = tfk.utils.to_categorical(augm_lbl, len(np.unique(LBLS)))

  augm = np.array(augm)
  augm_lbl = np.array(augm_lbl)

  imgs = np.concatenate((imgs, augm), axis=0)
  lbls = np.concatenate((lbls, augm_lbl), axis=0)
  print()

  return imgs, lbls

def mixup(img_a, img_b, lbl_a, lbl_b, alpha=0.5):
  lmb = rnd.uniform(0.1, 0.25) if rnd.choice([True, False]) else rnd.uniform(0.75, 0.9)

  mixed_img = np.uint8(lmb*img_a + (1-lmb)*img_b)
  mixed_lbl = lmb*lbl_a + (1-lmb)*lbl_b

  return mixed_img, mixed_lbl
def increase_volume_mixup(imgs, lbls, size):
  indices = []
  augm_lbls = []
  augm_imgs = []

  for i in range(size):
    index = rnd.randint(0, len(lbls)-1)
    while index in indices:
      index = rnd.randint(0, len(lbls)-1)
    indices.append([index])

    if np.argmax(lbls[index]):
      index_2 = rnd.randint(0, len(lbls)-1)
      while [index, index_2] in indices or  np.argmax(lbls[index_2]):
        index_2 = rnd.randint(0, len(lbls)-1)
      indices[i].append(index_2)
    elif not np.argmax(lbls[index]):
      index_2 = rnd.randint(0, len(lbls)-1)
      while [index, index_2] in indices or not np.argmax(lbls[index_2]):
        index_2 = rnd.randint(0, len(lbls)-1)
      indices[i].append(index_2)

    aug_img, aug_lbl = mixup(imgs[index], imgs[index_2], lbls[index], lbls[index_2])
    augm_imgs.append(aug_img)
    augm_lbls.append(aug_lbl)


  augm_lbls = np.array(augm_lbls)
  augm_imgs = np.array(augm_imgs)

  imgs = np.concatenate((imgs, augm_imgs), axis=0)
  lbls = np.concatenate((lbls, augm_lbls), axis=0)

  return imgs, lbls

# Test
def test_prediction(model, test, test_lbls):
  tp = model.predict(test, verbose=0)
  tp = np.argmax(tp, axis=-1)
  tgt = np.argmax(test_lbls, axis=-1)
  test_accuracy = accuracy_score(tgt, tp)
  print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
  print()

  return tp

# %% [markdown]
# ### Data Initizialization

# %%
# Initializate
DATA = np.load('public_data_clean.npz', allow_pickle=True)
KEYS = list(DATA.keys())

IMGS = np.array(DATA[KEYS[0]])
LIMG = len(IMGS)
LBLS = np.array(DATA[KEYS[1]])
LBLS_ = np.array(DATA[KEYS[1]])
LLBL = len(LBLS)

BATCH = 32
TEST_PERC = 0.15
VALI_PERC = 0.15

MPLBL = {0: "healthy", 1: "unhealthy"}
RMLBL = {"healthy": 0, "unhealthy": 1}
LBLS = np.array([RMLBL[l] for l in LBLS])
LBLS = tfk.utils.to_categorical(LBLS, len(np.unique(LBLS)))

print('Images: ', LIMG)
print('Labels: ', LLBL)
print()
# Out:
# Images:  4850
# Labels:  4850

# %%
IMGS, LBLS = manual_augmentation(IMGS, LBLS, LBLS_)
plot_images(IMGS[-7:], LBLS[-7:],0,1,7)
# Out:
# healthy      3060
# unhealthy    1790
# Name: class, dtype: int64
# Augment the Unhealthy with  1270 new images

# %%
print(len(IMGS))
print()

LBLS_ = list(map(lambda x: "unhealthy" if np.argmax(x) else "healthy", LBLS))
print(pd.DataFrame(LBLS_, columns=['class'])['class'].value_counts() )
# Out:
# 6117
#
# healthy      3060
# unhealthy    3057
# Name: class, dtype: int64

# %%
np.savez_compressed("8k.npz", IMGS, LBLS)

# %%
# plot_images(IMGS[-7:], LBLS[-7:], 0, 1, 7)

# %%
LIMG = len(IMGS)
LLBL = len(LBLS)

# Split the Data Set into Training XT YT, Validation XV YV, Test XTE YTE
Xtrv, XTE, Ytrv, YTE = train_test_split(
    IMGS,
    LBLS,
    test_size=int(TEST_PERC * LIMG),
    **({"random_state":SEED} if not RND else {}),
    stratify=LBLS
)

XT, XV, YT, YV = train_test_split(
    Xtrv,
    Ytrv,
    test_size=int(VALI_PERC*LIMG),
    **({"random_state":SEED} if not RND else {}),
    stratify=Ytrv
)

# Shapes
print('Training Set Shape: ', XT.shape, YT.shape)
print('Validation Set Shape: ', XV.shape, YV.shape)
print('Test Set Shape: ', XTE.shape, YTE.shape)
print()

# Get the Shape of IN OUT
input_shape = XT.shape[1:]
output_shape = YT.shape[1]                                                        # Enable for MultiClass Problem

print(f'Input shape of the Network: {input_shape}')
print(f'Output shape of the Network: {output_shape}')
print()
# Out:
# Training Set Shape:  (4283, 96, 96, 3) (4283, 2)
# Validation Set Shape:  (917, 96, 96, 3) (917, 2)
# Test Set Shape:  (917, 96, 96, 3) (917, 2)
#
# Input shape of the Network: (96, 96, 3)
# Output shape of the Network: 2

# %%
XT, YT = increase_volume_mixup(XT, YT, 2000)

# %%
plot_images(XT[-21:], YT[-21:], 0, 3, 7)

# %%
LBLS_ = list(map(lambda x: "unhealthy" if np.argmax(x)==0 else "healthy", YT))
print(pd.DataFrame(LBLS_, columns=['class'])['class'].value_counts() )
print()

# Shapes
print('Training Set Shape: ', XT.shape, YT.shape)
print('Validation Set Shape: ', XV.shape, YV.shape)
print('Test Set Shape: ', XTE.shape, YTE.shape)
print()
# Out:
# unhealthy    3142
# healthy      3141
# Name: class, dtype: int64
#
# Training Set Shape:  (6283, 96, 96, 3) (6283, 2)
# Validation Set Shape:  (917, 96, 96, 3) (917, 2)
# Test Set Shape:  (917, 96, 96, 3) (917, 2)

# %%
np.savez_compressed("8k.npz", Xtrv, XTE, Ytrv, YTE)

# %% [markdown]
# **Augmentation Layers**

# %%
# Rescaling
data_rescaling = tkl.Rescaling(scale=1./255)                                      # Normalize the Images from 0..255 to 0..1
data_backscaling = tkl.Rescaling(scale=1.*255)                                    # Normalize the Images from 0..1 to 0..255

data_rescaling_c = tkl.Rescaling(scale=1./127.5, offset=-1)                       # Normalize the Images from 0..255 to -1..1
data_backscaling_c = tkl.Rescaling(scale=1.*127.5, offset=1)                      # Normalize the Images from -1..1 to 0..255

# Agumentation
augm_91 = tkm.Sequential([
    tkl.RandomTranslation(height_factor=(-0.3,0.3),width_factor=(-0.3,0.3)),
    tkl.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2)),
    tkl.RandomFlip('horizontal'),
    tkl.RandomRotation(factor=359)
])

# %% [markdown]
# ### Training

# %% [markdown]
# **Define the Model**

# %%
from keras.applications.convnext import preprocess_input

def ae(input_shape, output_shape):

  preprocessing = tfk.Sequential([
      # tkl.RandomContrast(factor=(0,0.3)),
      # tkl.RandomBrightness(factor=(0,0.3)),
      tkl.RandomTranslation(height_factor=(-0.3,0.3),width_factor=(-0.3,0.3)),
      tkl.RandomZoom(height_factor=(-0.2,0.2),width_factor=(-0.2,0.2)),
      tkl.RandomFlip('horizontal'),
      tkl.RandomRotation(factor=359)
    ], name='preprocessing'
  )

  res = tfk.applications.ConvNeXtBase(
    input_shape=input_shape,
    include_top=False,
    weights="imagenet",
    classes=2,
    classifier_activation='softmax'
  )
  res.trainable = False

  input_layer = tkl.Input(input_shape)
  # x = data_rescaling_c(input_layer)
  x = preprocess_input(input_layer)
  x = preprocessing(x)
  # x = augm_91(x)
  x = res(x)
  x = tkl.GlobalAveragePooling2D()(x)
  x = tkl.Dense(units=128,activation=tkl.LeakyReLU(alpha=0.3))(x)                 # maybe we have to use leakyrelu
  # x = tkl.BatchNormalization()(x)
  x = tkl.Dropout(0.7)(x)

  # x = tkl.Dense(units=2048,activation='relu')(x)
  # x = tkl.Dense(units=2048,activation='relu')(x)
  # x = tkl.Dense(units=1024,activation='relu')(x)

  output_layer = tkl.Dense(units=output_shape,activation='softmax')(x)
  model =tfk.Model(input_layer, output_layer)

  # Compile the model
  model.compile(
      loss=tfk.losses.CategoricalCrossentropy(),
      optimizer=tfk.optimizers.Nadam(learning_rate=0.001, weight_decay=0.001),
      metrics=['accuracy']
  )

  return model

# %% [markdown]
# **Train the Model**

# %%
model = ae(input_shape,output_shape)
BATCH = 32
EPOCHS = 300

# Train the model
early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=20,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',                                                       # Metric to monitor (validation mean squared error in this case)
    patience=5,                                                                   # Number of epochs with no improvement after which learning rate will be reduced
    factor=0.65,                                                                  # Factor by which the learning rate will be reduced (0.999 in this case)
    mode='max',                                                                   # Mode to decide when to reduce learning rate ('min' means reduce when metric stops decreasing)
    min_lr=1e-7                                                                   # Minimum learning rate
)

callbacks = [early_stopping, lr_scheduler]

history = model.fit(
    x = XT,
    y = YT,
    batch_size = BATCH,
    epochs = EPOCHS,
    validation_data = (XV, YV),
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 197/197 [==============================] - 60s 205ms/step - loss: 0.7456 - accuracy: 0.6505 - val_loss: 0.5606 - val_accuracy: 0.7067 - lr: 0.0010
# Epoch 2/300
# 197/197 [==============================] - 30s 150ms/step - loss: 0.5942 - accuracy: 0.7205 - val_loss: 0.5217 - val_accuracy: 0.7197 - lr: 0.0010
# Epoch 3/300
# 197/197 [==============================] - 31s 157ms/step - loss: 0.5664 - accuracy: 0.7337 - val_loss: 0.4296 - val_accuracy: 0.7874 - lr: 0.0010
# Epoch 4/300
# 197/197 [==============================] - 31s 157ms/step - loss: 0.5457 - accuracy: 0.7495 - val_loss: 0.4506 - val_accuracy: 0.7895 - lr: 0.0010
# Epoch 5/300
# 197/197 [==============================] - 29s 149ms/step - loss: 0.5408 - accuracy: 0.7570 - val_loss: 0.4185 - val_accuracy: 0.8015 - lr: 0.0010
# Epoch 6/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.5277 - accuracy: 0.7635 - val_loss: 0.4039 - val_accuracy: 0.8004 - lr: 0.0010
# Epoch 7/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.5231 - accuracy: 0.7702 - val_loss: 0.3980 - val_accuracy: 0.8124 - lr: 0.0010
# Epoch 8/300
# 197/197 [==============================] - 31s 157ms/step - loss: 0.5146 - accuracy: 0.7780 - val_loss: 0.4290 - val_accuracy: 0.8048 - lr: 0.0010
# Epoch 9/300
# 197/197 [==============================] - 31s 158ms/step - loss: 0.5201 - accuracy: 0.7724 - val_loss: 0.3883 - val_accuracy: 0.8310 - lr: 0.0010
# Epoch 10/300
# 197/197 [==============================] - 31s 157ms/step - loss: 0.5078 - accuracy: 0.7820 - val_loss: 0.3796 - val_accuracy: 0.8222 - lr: 0.0010
# Epoch 11/300
# 197/197 [==============================] - 31s 158ms/step - loss: 0.5160 - accuracy: 0.7665 - val_loss: 0.3888 - val_accuracy: 0.8168 - lr: 0.0010
# Epoch 12/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.5085 - accuracy: 0.7840 - val_loss: 0.3874 - val_accuracy: 0.8212 - lr: 0.0010
# Epoch 13/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.5157 - accuracy: 0.7781 - val_loss: 0.3714 - val_accuracy: 0.8386 - lr: 0.0010
# Epoch 14/300
# 197/197 [==============================] - 31s 155ms/step - loss: 0.5081 - accuracy: 0.7773 - val_loss: 0.3702 - val_accuracy: 0.8342 - lr: 0.0010
# Epoch 15/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.5051 - accuracy: 0.7850 - val_loss: 0.3731 - val_accuracy: 0.8201 - lr: 0.0010
# Epoch 16/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4996 - accuracy: 0.7866 - val_loss: 0.3769 - val_accuracy: 0.8288 - lr: 0.0010
# Epoch 17/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.5056 - accuracy: 0.7890 - val_loss: 0.4078 - val_accuracy: 0.8059 - lr: 0.0010
# Epoch 18/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.5052 - accuracy: 0.7835 - val_loss: 0.3750 - val_accuracy: 0.8310 - lr: 0.0010
# Epoch 19/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4995 - accuracy: 0.7890 - val_loss: 0.3545 - val_accuracy: 0.8419 - lr: 6.5000e-04
# Epoch 20/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4911 - accuracy: 0.7878 - val_loss: 0.3649 - val_accuracy: 0.8266 - lr: 6.5000e-04
# Epoch 21/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4951 - accuracy: 0.7875 - val_loss: 0.3823 - val_accuracy: 0.8364 - lr: 6.5000e-04
# Epoch 22/300
# 197/197 [==============================] - 31s 155ms/step - loss: 0.4905 - accuracy: 0.7972 - val_loss: 0.3844 - val_accuracy: 0.8092 - lr: 6.5000e-04
# Epoch 23/300
# 197/197 [==============================] - 31s 155ms/step - loss: 0.4977 - accuracy: 0.7934 - val_loss: 0.3976 - val_accuracy: 0.7983 - lr: 6.5000e-04
# Epoch 24/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4907 - accuracy: 0.7915 - val_loss: 0.3535 - val_accuracy: 0.8506 - lr: 6.5000e-04
# Epoch 25/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.4919 - accuracy: 0.7928 - val_loss: 0.3502 - val_accuracy: 0.8364 - lr: 6.5000e-04
# Epoch 26/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.4901 - accuracy: 0.7971 - val_loss: 0.3742 - val_accuracy: 0.8233 - lr: 6.5000e-04
# Epoch 27/300
# 197/197 [==============================] - 31s 155ms/step - loss: 0.4907 - accuracy: 0.8033 - val_loss: 0.3697 - val_accuracy: 0.8288 - lr: 6.5000e-04
# Epoch 28/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4893 - accuracy: 0.7940 - val_loss: 0.3483 - val_accuracy: 0.8364 - lr: 6.5000e-04
# Epoch 29/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4852 - accuracy: 0.7960 - val_loss: 0.3523 - val_accuracy: 0.8462 - lr: 6.5000e-04
# Epoch 30/300
# 197/197 [==============================] - 29s 150ms/step - loss: 0.4841 - accuracy: 0.8012 - val_loss: 0.3352 - val_accuracy: 0.8604 - lr: 4.2250e-04
# Epoch 31/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4830 - accuracy: 0.8006 - val_loss: 0.3409 - val_accuracy: 0.8495 - lr: 4.2250e-04
# Epoch 32/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.4789 - accuracy: 0.8052 - val_loss: 0.3481 - val_accuracy: 0.8397 - lr: 4.2250e-04
# Epoch 33/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4813 - accuracy: 0.7972 - val_loss: 0.3314 - val_accuracy: 0.8724 - lr: 4.2250e-04
# Epoch 34/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4742 - accuracy: 0.8033 - val_loss: 0.3544 - val_accuracy: 0.8342 - lr: 4.2250e-04
# Epoch 35/300
# 197/197 [==============================] - 29s 147ms/step - loss: 0.4750 - accuracy: 0.8092 - val_loss: 0.3443 - val_accuracy: 0.8484 - lr: 4.2250e-04
# Epoch 36/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4791 - accuracy: 0.8125 - val_loss: 0.3416 - val_accuracy: 0.8473 - lr: 4.2250e-04
# Epoch 37/300
# 197/197 [==============================] - 29s 146ms/step - loss: 0.4810 - accuracy: 0.8012 - val_loss: 0.3445 - val_accuracy: 0.8462 - lr: 4.2250e-04
# Epoch 38/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4738 - accuracy: 0.8103 - val_loss: 0.3285 - val_accuracy: 0.8506 - lr: 4.2250e-04
# Epoch 39/300
# 197/197 [==============================] - 30s 150ms/step - loss: 0.4771 - accuracy: 0.8050 - val_loss: 0.3451 - val_accuracy: 0.8473 - lr: 2.7463e-04
# Epoch 40/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4753 - accuracy: 0.8081 - val_loss: 0.3513 - val_accuracy: 0.8397 - lr: 2.7463e-04
# Epoch 41/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4767 - accuracy: 0.8087 - val_loss: 0.3593 - val_accuracy: 0.8222 - lr: 2.7463e-04
# Epoch 42/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4726 - accuracy: 0.8120 - val_loss: 0.3504 - val_accuracy: 0.8430 - lr: 2.7463e-04
# Epoch 43/300
# 197/197 [==============================] - 31s 156ms/step - loss: 0.4736 - accuracy: 0.8095 - val_loss: 0.3407 - val_accuracy: 0.8528 - lr: 2.7463e-04
# Epoch 44/300
# 197/197 [==============================] - 29s 149ms/step - loss: 0.4755 - accuracy: 0.8106 - val_loss: 0.3508 - val_accuracy: 0.8353 - lr: 1.7851e-04
# Epoch 45/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4669 - accuracy: 0.8159 - val_loss: 0.3462 - val_accuracy: 0.8310 - lr: 1.7851e-04
# Epoch 46/300
# 197/197 [==============================] - 31s 158ms/step - loss: 0.4683 - accuracy: 0.8130 - val_loss: 0.3355 - val_accuracy: 0.8495 - lr: 1.7851e-04
# Epoch 47/300
# 197/197 [==============================] - 31s 157ms/step - loss: 0.4645 - accuracy: 0.8168 - val_loss: 0.3447 - val_accuracy: 0.8441 - lr: 1.7851e-04
# Epoch 48/300
# 197/197 [==============================] - 30s 150ms/step - loss: 0.4656 - accuracy: 0.8160 - val_loss: 0.3280 - val_accuracy: 0.8561 - lr: 1.7851e-04
# Epoch 49/300
# 197/197 [==============================] - 31s 157ms/step - loss: 0.4625 - accuracy: 0.8189 - val_loss: 0.3361 - val_accuracy: 0.8506 - lr: 1.1603e-04
# Epoch 50/300
# 197/197 [==============================] - 29s 148ms/step - loss: 0.4664 - accuracy: 0.8211 - val_loss: 0.3284 - val_accuracy: 0.8593 - lr: 1.1603e-04
# Epoch 51/300
# 197/197 [==============================] - 29s 149ms/step - loss: 0.4587 - accuracy: 0.8154 - val_loss: 0.3210 - val_accuracy: 0.8604 - lr: 1.1603e-04
# Epoch 52/300
# 197/197 [==============================] - 30s 153ms/step - loss: 0.4742 - accuracy: 0.8111 - val_loss: 0.3399 - val_accuracy: 0.8528 - lr: 1.1603e-04
# Epoch 53/300
# 197/197 [==============================] - 32s 161ms/step - loss: 0.4700 - accuracy: 0.8144 - val_loss: 0.3283 - val_accuracy: 0.8593 - lr: 1.1603e-04

# %% [markdown]
# ### Saving and Plotting

# %% [markdown]
# **Test Prediction Accuracy**

# %%
test_prediction(model, XTE, YTE)
# Out:
# Accuracy Score over the Test Set: 0.8397

# %% [markdown]
# **Plots Loss**

# %%
plot_losses(history, (20,5), NAME_PLOT)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(model, XTE, YTE, (5,4), NAME_CMATRIX)
# Out:
# Accuracy:	 0.8397
# Precision:	 0.8407
# Recall:		 0.8397
# F1:		 0.8396

# %% [markdown]
# **Save the Model**

# %%
model.save(NAME_MODEL)

# %% [markdown]
# **Zip Model and Plots**

# %%
# !zip -r {NAME_MODEL}.zip {NAME_MODEL} {NAME_PLOT}.png {NAME_CMATRIX}.png
# Out:
#   adding: ConvNeXtV2_t002/ (stored 0%)
#   adding: ConvNeXtV2_t002/variables/ (stored 0%)
#   adding: ConvNeXtV2_t002/variables/variables.index (deflated 77%)
#   adding: ConvNeXtV2_t002/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXtV2_t002/saved_model.pb (deflated 92%)
#   adding: ConvNeXtV2_t002/fingerprint.pb (stored 0%)
#   adding: ConvNeXtV2_t002/keras_metadata.pb (deflated 96%)
#   adding: ConvNeXtV2_t002/assets/ (stored 0%)
#   adding: ConvNeXtV2_t002_plot.png (deflated 11%)
#   adding: ConvNeXtV2_t002_cmatrix.png (deflated 16%)

# %% [markdown]
# **Delete the Model**

# %%
del model

# %% [markdown]
# ## Tuning

# %% [markdown]
# **Load the Model**

# %%
ft_model = tfk.models.load_model(NAME_MODEL)

# %%
ft_model = model

# %% [markdown]
# **Count the Layers**

# %%
ft_model.get_layer('convnext_base').trainable = True
c = 0
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers):
   c += 1

print("Layers: ",c)
print()
# Out:
# Layers:  295

# %% [markdown]
# **Train only the Last Layers**

# %%
for i, layer in enumerate(ft_model.get_layer('convnext_base').layers[:200]):
  layer.trainable=False

ft_model.compile(
  loss=tfk.losses.CategoricalCrossentropy(),
  optimizer=tfk.optimizers.Nadam(learning_rate=0.0001, weight_decay=0.0001),
  metrics=['accuracy']
)

# %% [markdown]
# **Train the Tuning Model**

# %%
BATCH = 32
EPOCHS = 300

early_stopping = tfk.callbacks.EarlyStopping(
    monitor='val_accuracy',
    patience=15,
    mode='max',
    restore_best_weights=True)

lr_scheduler = tfk.callbacks.ReduceLROnPlateau(
    monitor='val_accuracy',                                                       # Metric to monitor (validation mean squared error in this case)
    patience=5,                                                                   # Number of epochs with no improvement after which learning rate will be reduced
    factor=0.80,                                                                  # Factor by which the learning rate will be reduced (0.999 in this case)
    mode='max',                                                                   # Mode to decide when to reduce learning rate ('min' means reduce when metric stops decreasing)
    min_lr=1e-7                                                                   # Minimum learning rate
)

callbacks = [early_stopping,lr_scheduler]

history = ft_model.fit(
    x = XT,                                                                       # We need to apply the preprocessing thought for the MobileNetV2 network
    y = YT,
    batch_size = BATCH,
    epochs = EPOCHS,
    validation_data = (XV, YV),                                                   # We need to apply the preprocessing thought for the MobileNetV2 network
    callbacks = callbacks
).history
# Out:
# Epoch 1/300
# 197/197 [==============================] - 103s 268ms/step - loss: 0.4755 - accuracy: 0.8084 - val_loss: 0.2671 - val_accuracy: 0.8790 - lr: 1.0000e-04
# Epoch 2/300
# 197/197 [==============================] - 48s 241ms/step - loss: 0.4295 - accuracy: 0.8453 - val_loss: 0.2685 - val_accuracy: 0.8779 - lr: 1.0000e-04
# Epoch 3/300
# 197/197 [==============================] - 46s 235ms/step - loss: 0.3992 - accuracy: 0.8762 - val_loss: 0.2664 - val_accuracy: 0.8953 - lr: 1.0000e-04
# Epoch 4/300
# 197/197 [==============================] - 46s 236ms/step - loss: 0.3779 - accuracy: 0.8849 - val_loss: 0.2321 - val_accuracy: 0.9040 - lr: 1.0000e-04
# Epoch 5/300
# 197/197 [==============================] - 48s 244ms/step - loss: 0.3517 - accuracy: 0.8986 - val_loss: 0.2337 - val_accuracy: 0.9106 - lr: 1.0000e-04
# Epoch 6/300
# 197/197 [==============================] - 46s 235ms/step - loss: 0.3397 - accuracy: 0.9051 - val_loss: 0.2149 - val_accuracy: 0.9138 - lr: 1.0000e-04
# Epoch 7/300
# 197/197 [==============================] - 48s 243ms/step - loss: 0.3251 - accuracy: 0.9139 - val_loss: 0.1926 - val_accuracy: 0.9193 - lr: 1.0000e-04
# Epoch 8/300
# 197/197 [==============================] - 48s 244ms/step - loss: 0.3167 - accuracy: 0.9228 - val_loss: 0.2048 - val_accuracy: 0.9215 - lr: 1.0000e-04
# Epoch 9/300
# 197/197 [==============================] - 47s 236ms/step - loss: 0.3070 - accuracy: 0.9254 - val_loss: 0.1796 - val_accuracy: 0.9411 - lr: 1.0000e-04
# Epoch 10/300
# 197/197 [==============================] - 46s 234ms/step - loss: 0.2974 - accuracy: 0.9322 - val_loss: 0.1711 - val_accuracy: 0.9346 - lr: 1.0000e-04
# Epoch 11/300
# 197/197 [==============================] - 46s 234ms/step - loss: 0.2848 - accuracy: 0.9343 - val_loss: 0.1759 - val_accuracy: 0.9335 - lr: 1.0000e-04
# Epoch 12/300
# 197/197 [==============================] - 46s 232ms/step - loss: 0.2827 - accuracy: 0.9429 - val_loss: 0.1987 - val_accuracy: 0.9357 - lr: 1.0000e-04
# Epoch 13/300
# 197/197 [==============================] - 46s 231ms/step - loss: 0.2717 - accuracy: 0.9464 - val_loss: 0.1687 - val_accuracy: 0.9324 - lr: 1.0000e-04
# Epoch 14/300
# 197/197 [==============================] - 47s 240ms/step - loss: 0.2748 - accuracy: 0.9454 - val_loss: 0.1823 - val_accuracy: 0.9368 - lr: 1.0000e-04
# Epoch 15/300
# 197/197 [==============================] - 46s 233ms/step - loss: 0.2563 - accuracy: 0.9538 - val_loss: 0.1648 - val_accuracy: 0.9466 - lr: 8.0000e-05
# Epoch 16/300
# 197/197 [==============================] - 45s 231ms/step - loss: 0.2574 - accuracy: 0.9500 - val_loss: 0.1505 - val_accuracy: 0.9455 - lr: 8.0000e-05
# Epoch 17/300
# 197/197 [==============================] - 46s 232ms/step - loss: 0.2491 - accuracy: 0.9585 - val_loss: 0.1790 - val_accuracy: 0.9389 - lr: 8.0000e-05
# Epoch 18/300
# 197/197 [==============================] - 46s 233ms/step - loss: 0.2467 - accuracy: 0.9542 - val_loss: 0.1560 - val_accuracy: 0.9498 - lr: 8.0000e-05
# Epoch 19/300
# 197/197 [==============================] - 45s 230ms/step - loss: 0.2435 - accuracy: 0.9597 - val_loss: 0.1746 - val_accuracy: 0.9400 - lr: 8.0000e-05
# Epoch 20/300
# 197/197 [==============================] - 47s 240ms/step - loss: 0.2418 - accuracy: 0.9591 - val_loss: 0.1799 - val_accuracy: 0.9444 - lr: 8.0000e-05
# Epoch 21/300
# 197/197 [==============================] - 46s 232ms/step - loss: 0.2433 - accuracy: 0.9604 - val_loss: 0.1717 - val_accuracy: 0.9389 - lr: 8.0000e-05
# Epoch 22/300
# 197/197 [==============================] - 47s 239ms/step - loss: 0.2303 - accuracy: 0.9642 - val_loss: 0.1790 - val_accuracy: 0.9368 - lr: 8.0000e-05
# Epoch 23/300
# 197/197 [==============================] - 47s 240ms/step - loss: 0.2340 - accuracy: 0.9640 - val_loss: 0.1503 - val_accuracy: 0.9477 - lr: 8.0000e-05
# Epoch 24/300
# 197/197 [==============================] - 46s 232ms/step - loss: 0.2249 - accuracy: 0.9677 - val_loss: 0.1988 - val_accuracy: 0.9302 - lr: 6.4000e-05
# Epoch 25/300
# 197/197 [==============================] - 46s 232ms/step - loss: 0.2196 - accuracy: 0.9725 - val_loss: 0.1630 - val_accuracy: 0.9389 - lr: 6.4000e-05
# Epoch 26/300
# 197/197 [==============================] - 47s 240ms/step - loss: 0.2209 - accuracy: 0.9702 - val_loss: 0.1776 - val_accuracy: 0.9400 - lr: 6.4000e-05
# Epoch 27/300
# 197/197 [==============================] - 48s 241ms/step - loss: 0.2236 - accuracy: 0.9699 - val_loss: 0.1725 - val_accuracy: 0.9433 - lr: 6.4000e-05
# Epoch 28/300
# 197/197 [==============================] - 47s 241ms/step - loss: 0.2168 - accuracy: 0.9729 - val_loss: 0.1833 - val_accuracy: 0.9313 - lr: 6.4000e-05
# Epoch 29/300
# 197/197 [==============================] - 47s 241ms/step - loss: 0.2164 - accuracy: 0.9701 - val_loss: 0.1787 - val_accuracy: 0.9389 - lr: 5.1200e-05
# Epoch 30/300
# 197/197 [==============================] - 46s 231ms/step - loss: 0.2036 - accuracy: 0.9817 - val_loss: 0.1756 - val_accuracy: 0.9422 - lr: 5.1200e-05
# Epoch 31/300
# 197/197 [==============================] - 47s 240ms/step - loss: 0.2144 - accuracy: 0.9734 - val_loss: 0.1790 - val_accuracy: 0.9422 - lr: 5.1200e-05
# Epoch 32/300
# 197/197 [==============================] - 47s 240ms/step - loss: 0.2101 - accuracy: 0.9782 - val_loss: 0.1892 - val_accuracy: 0.9422 - lr: 5.1200e-05
# Epoch 33/300
# 197/197 [==============================] - 46s 232ms/step - loss: 0.2076 - accuracy: 0.9760 - val_loss: 0.2070 - val_accuracy: 0.9411 - lr: 5.1200e-05

# %% [markdown]
# ### Saving and Plotting

# %%
FT_NAME = NAME_MODEL+"_Tuning"
FT_PLOT = NAME_PLOT+"_Tuning"
FT_CMATRIX = NAME_CMATRIX+"_Tuning"

# %% [markdown]
# **Test Prediction Accuracy**

# %%
tp = test_prediction(ft_model, XTE, YTE)
# Out:
# Accuracy Score over the Test Set: 0.9346

# %%
print(len(tp))

_ = list(map(lambda x: "unhealthy" if x == 0 else "healthy", tp))
YT_ = list(map(lambda x: "unhealthy" if np.argmax(x) else "healthy", YT))

err = []
err_lbl = []

for i, lbl in enumerate(tp):
  if lbl != YT_[i]:
    err.append(XT[i])
    err_lbl.append(YT_[i])

plot_images(err, err_lbl, 0, 1, 10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9eb335567524> in <cell line: 1>()
# ----> 1 print(len(tp))
#       2
#       3 _ = list(map(lambda x: "unhealthy" if x == 0 else "healthy", tp))
#       4 YT_ = list(map(lambda x: "unhealthy" if np.argmax(x) else "healthy", YT))
#       5
#
# NameError: name 'tp' is not defined

# %% [markdown]
# **Plot Loss**

# %%
plot_losses(history, (20,5), FT_NAME)

# %% [markdown]
# **Plot Confusion Matrix**

# %%
plot_confusion_matrix(ft_model, XTE, YTE, (5,4), NAME_CMATRIX)
# Out:
# Accuracy:	 0.9346
# Precision:	 0.9346
# Recall:		 0.9346
# F1:		 0.9346

# %% [markdown]
# **Save the Model**

# %%
ft_model.save(NAME_MODEL+"_Tuning")

# %% [markdown]
# **Zip the Model and the Plots**

# %%
# !zip -r {FT_NAME}.zip {FT_NAME} {FT_PLOT}.png {FT_CMATRIX}.png
# Out:
# 	zip warning: name not matched: ConvNeXt_8k_plot_Tuning.png
# 	zip warning: name not matched: ConvNeXt_8k_cmatrix_Tuning.png
#   adding: ConvNeXt_8k_Tuning/ (stored 0%)
#   adding: ConvNeXt_8k_Tuning/variables/ (stored 0%)
#   adding: ConvNeXt_8k_Tuning/variables/variables.index (deflated 78%)
#   adding: ConvNeXt_8k_Tuning/variables/variables.data-00000-of-00001 (deflated 7%)
#   adding: ConvNeXt_8k_Tuning/saved_model.pb (deflated 92%)
#   adding: ConvNeXt_8k_Tuning/fingerprint.pb (stored 0%)
#   adding: ConvNeXt_8k_Tuning/keras_metadata.pb (deflated 96%)
#   adding: ConvNeXt_8k_Tuning/assets/ (stored 0%)

# %% [markdown]
# **Plot Test and Error on Test**

# %%
YTE_ = list(map(lambda x: "unhealthy" if x[0]==0. and x[1]==1. else "healthy", YTE))
plot_images(XTE[:25], YTE_[:25], 0, 5, 5)
plot_images(XTE[25:50], YTE_[25:50], 0, 5, 5)

print(len(XTE))
# Out:
# 917
