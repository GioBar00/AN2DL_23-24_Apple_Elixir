# %% [markdown]
# **Add Your Drive to the Folder**

# %%
# Optional
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Imports & Configurations

# %% [markdown]
# **Importing the Libraries**

# %%
# Deafault Imports
import os
import logging
import warnings as wr
import numpy as np
import random as rnd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras as tfk
from keras import layers as tfkl
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Our Imports
# import here your model script or functions

# %% [markdown]
# **Configurations**

# %%
# Random Configuration - All
FLAG_SEED = False
if not FLAG_SEED:
  SEED = 76998669
  tf.compat.v1.set_random_seed(SEED)
  tf.random.set_seed(SEED)
  np.random.seed(SEED)
  rnd.seed(SEED)
  os.environ['PYTHONHASHSEED'] = str(SEED)

# OS Configuration
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['MPLCONFIGDIR'] = os.getcwd()+'/configs/'

# Warning Congiguration
wr.simplefilter(action='ignore', category=FutureWarning)
wr.simplefilter(action='ignore', category=Warning)

# TensorFlow Configuration
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %% [markdown]
# ### Local Functions

# %%
# Plotting Functions

def plot_losses(history, figsize, name_jpg):
  fig, axes = plt.subplots(2,1, figsize=figsize)

  axes[0].plot(history['loss'], label='Training Loss', alpha=.8)
  axes[0].plot(history['val_loss'], label='Validation Loss', alpha=.8)
  axes[0].set_title('Loss')
  axes[0].legend()
  axes[0].grid(alpha=.3)

  axes[1].plot(history['accuracy'], label='Training Accuracy', alpha=.8)
  axes[1].plot(history['val_accuracy'], label='Validation Accuracy', alpha=.8)
  axes[1].set_title('Accuracy')
  axes[1].legend()
  axes[1].grid(alpha=.3)

  plt.savefig(name_jpg)
  plt.show()

def plot_image(img, lbl):
  plt.figure(figsize=(10,10))
  plt.imshow(np.clip(img, 0, 1))
  plt.title(f'{lbl}')
  plt.show()
  print(img)

# %% [markdown]
# ### Load and process the dataset

# %% [markdown]
# **Load the Dataset**

# %%
# Load the Dataset Files from Giovanni's Server
# !rm public_data.npz
# !wget https://apps.barbiero.dev/static/public_data.npz

# !rm public_data_clean.npz
# !wget https://apps.barbiero.dev/static/public_data_clean.npz
# Out:
# --2023-11-06 09:40:49--  https://apps.barbiero.dev/static/public_data_clean.npz
# Resolving apps.barbiero.dev (apps.barbiero.dev)... 104.21.8.111, 172.67.157.85, 2606:4700:3036::6815:86f, ...
# Connecting to apps.barbiero.dev (apps.barbiero.dev)|104.21.8.111|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 536546306 (512M) [application/octet-stream]
# Saving to: ‘public_data_clean.npz’
#
# public_data_clean.n 100%[===================>] 511.69M  15.3MB/s    in 36s
#
# 2023-11-06 09:41:25 (14.2 MB/s) - ‘public_data_clean.npz’ saved [536546306/536546306]

# %% [markdown]
# **Store the Data**

# %%
# Initializate
dataset = np.load('public_data_clean.npz', allow_pickle=True)

# Split into Images and Labels + Normalize the Image Data Set
KEYS = list(dataset.keys())
IMG = np.array(dataset[KEYS[0]])/255
LBL = np.array(dataset[KEYS[1]])
print('Images: ', len(IMG))
print('Labels: ', len(LBL))

LBL = list(map(lambda x: 0 if x == "healthy" else 1, LBL))
LBL = tf.keras.utils.to_categorical(LBL)                                          # Enable for MultiClass Problem

# Split the Data Set into Training XT YT, Validation XV YV, Test XTE YTE
Xtrv, XTE, Ytrv, YTE = train_test_split(IMG, LBL, test_size=500, random_state=SEED, stratify=np.argmax(LBL, axis=1))
XT, XV, YT, YV = train_test_split(Xtrv, Ytrv, test_size=500, random_state=SEED, stratify=np.argmax(Ytrv, axis=1))

print('Training Set Shape: ', XT.shape, YT.shape)
print('Validation Set Shape: ', XV.shape, YV.shape)
print('Test Set Shape: ', XTE.shape, YTE.shape)
print()

# Get the Shape of IN OUT
input_shape = XT.shape[1:]
output_shape = YT.shape[1]                                                        # Enable for MultiClass Problem

print(f'Input shape of the Network: {input_shape}')
print(f'Output shape of the Network: {output_shape}')
print()
# Out:
# Images:  4850
# Labels:  4850
# Training Set Shape:  (3850, 96, 96, 3) (3850, 2)
# Validation Set Shape:  (500, 96, 96, 3) (500, 2)
# Test Set Shape:  (500, 96, 96, 3) (500, 2)
#
# Input shape of the Network: (96, 96, 3)
# Output shape of the Network: 2

# %% [markdown]
# ### Training

# %%
# Model Function
def apple_elixir_model(input_shape, output_shape, seed=SEED):

  tf.random.set_seed(seed)

  # Build the neural network layer by layer
  input_layer = tfkl.Input(shape=input_shape, name='Input')

  x = tfkl.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',name='conv00')(input_layer)
  x = tfkl.Conv2D(filters=32,kernel_size=3,padding='same',activation='relu',name='conv01')(x)
  x = tfkl.MaxPooling2D(name='mp0')(x)

  x = tfkl.Conv2D(filters=64,kernel_size=3,padding='same',activation='relu',name='conv10')(x)
  x = tfkl.Conv2D(filters=64,kernel_size=3,padding='same',activation='relu',name='conv11')(x)
  x = tfkl.MaxPooling2D(name='mp1')(x)

  x = tfkl.Conv2D(filters=128,kernel_size=3,padding='same',activation='relu',name='conv20')(x)
  x = tfkl.Conv2D(filters=128,kernel_size=3,padding='same',activation='relu',name='conv21')(x)
  x = tfkl.MaxPooling2D(name='mp2')(x)

  # x = tfkl.Conv2D(filters=256,kernel_size=3,padding='same',activation='relu',name='conv30')(x)
  # x = tfkl.Conv2D(filters=256,kernel_size=3,padding='same',activation='relu',name='conv31')(x)
  # x = tfkl.GlobalAveragePooling2D(name='gap')(x)

  x = tfkl.Flatten()(x)
  x = tfkl.Dense(units = 30, activation='relu')(x)
  x = tfkl.Dense(units = 20, activation='relu')(x)
  x = tfkl.Dense(units = 10, activation='relu')(x)
  x = tfkl.Dense(units = 30, activation='relu')(x)

  output_layer = tfkl.Dense(units=output_shape ,activation='softmax', name='Output')(x)

  model = tfk.Model(inputs=input_layer, outputs=output_layer, name='Convnet')
  model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(weight_decay=5e-4), metrics=['accuracy'])

  return model

# %% [markdown]
# **SetUp and Train**

# %%
BTC = 64
EPO = 500
NAME_PLOT = "test_push"
NAME_MODEL = "model_push"
CALLBACKS = [
    tfk.callbacks.EarlyStopping(
      monitor='val_accuracy',
      mode='max',
      patience=20,
      restore_best_weights=True
    ),
    tfk.callbacks.ReduceLROnPlateau(
      monitor="val_accuracy",
      factor=0.1,
      patience=20,
      min_lr=1e-5,
      mode='max'
    )
]

# %%
model = apple_elixir_model(input_shape=input_shape, output_shape=output_shape)
model.summary()

history = model.fit(
  x = XT,                                                                         # We need to apply the preprocessing thought for the MobileNetV2 network
  y = YT,
  batch_size = BTC,
  epochs = EPO,
  validation_data = (XV, YV),                                               # We need to apply the preprocessing thought for the MobileNetV2 network
  callbacks = CALLBACKS
).history

plot_losses(history=history, figsize=(20,2), name_jpg=NAME_PLOT)
model.save(NAME_MODEL)
del model
# Out:
# Model: "Convnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  conv00 (Conv2D)             (None, 96, 96, 32)        896
#
#  conv01 (Conv2D)             (None, 96, 96, 32)        9248
#
#  mp0 (MaxPooling2D)          (None, 48, 48, 32)        0
#
#  conv10 (Conv2D)             (None, 48, 48, 64)        18496
#
#  conv11 (Conv2D)             (None, 48, 48, 64)        36928
#
#  mp1 (MaxPooling2D)          (None, 24, 24, 64)        0
#
#  conv20 (Conv2D)             (None, 24, 24, 128)       73856
#
#  conv21 (Conv2D)             (None, 24, 24, 128)       147584
#
#  mp2 (MaxPooling2D)          (None, 12, 12, 128)       0
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 30)                552990
#
#  dense_1 (Dense)             (None, 20)                620
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 30)                330
#
#  Output (Dense)              (None, 2)                 62
#
# =================================================================
# Total params: 841220 (3.21 MB)
# Trainable params: 841220 (3.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/500
# 61/61 [==============================] - 18s 64ms/step - loss: 0.6627 - accuracy: 0.6236 - val_loss: 0.6687 - val_accuracy: 0.6320 - lr: 0.0010
# Epoch 2/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.6703 - accuracy: 0.6309 - val_loss: 0.6628 - val_accuracy: 0.6320 - lr: 0.0010
# Epoch 3/500
# 61/61 [==============================] - 3s 52ms/step - loss: 0.6567 - accuracy: 0.6319 - val_loss: 0.6491 - val_accuracy: 0.6360 - lr: 0.0010
# Epoch 4/500
# 61/61 [==============================] - 3s 42ms/step - loss: 0.6433 - accuracy: 0.6519 - val_loss: 0.6477 - val_accuracy: 0.6340 - lr: 0.0010
# Epoch 5/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.6453 - accuracy: 0.6353 - val_loss: 0.6210 - val_accuracy: 0.6720 - lr: 0.0010
# Epoch 6/500
# 61/61 [==============================] - 3s 42ms/step - loss: 0.6108 - accuracy: 0.6862 - val_loss: 0.6244 - val_accuracy: 0.6500 - lr: 0.0010
# Epoch 7/500
# 61/61 [==============================] - 3s 45ms/step - loss: 0.5943 - accuracy: 0.6971 - val_loss: 0.6241 - val_accuracy: 0.6860 - lr: 0.0010
# Epoch 8/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.5718 - accuracy: 0.7148 - val_loss: 0.5774 - val_accuracy: 0.7060 - lr: 0.0010
# Epoch 9/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.5490 - accuracy: 0.7304 - val_loss: 0.5589 - val_accuracy: 0.7180 - lr: 0.0010
# Epoch 10/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.5428 - accuracy: 0.7377 - val_loss: 0.5596 - val_accuracy: 0.7300 - lr: 0.0010
# Epoch 11/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.5412 - accuracy: 0.7447 - val_loss: 0.5501 - val_accuracy: 0.7360 - lr: 0.0010
# Epoch 12/500
# 61/61 [==============================] - 3s 45ms/step - loss: 0.5368 - accuracy: 0.7439 - val_loss: 0.5752 - val_accuracy: 0.7080 - lr: 0.0010
# Epoch 13/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.4975 - accuracy: 0.7634 - val_loss: 0.5656 - val_accuracy: 0.7200 - lr: 0.0010
# Epoch 14/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.4812 - accuracy: 0.7730 - val_loss: 0.5625 - val_accuracy: 0.7220 - lr: 0.0010
# Epoch 15/500
# 61/61 [==============================] - 3s 45ms/step - loss: 0.4712 - accuracy: 0.7808 - val_loss: 0.6037 - val_accuracy: 0.6900 - lr: 0.0010
# Epoch 16/500
# 61/61 [==============================] - 3s 45ms/step - loss: 0.4709 - accuracy: 0.7805 - val_loss: 0.5598 - val_accuracy: 0.7400 - lr: 0.0010
# Epoch 17/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.4215 - accuracy: 0.8125 - val_loss: 0.6018 - val_accuracy: 0.7160 - lr: 0.0010
# Epoch 18/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.4185 - accuracy: 0.8075 - val_loss: 0.6388 - val_accuracy: 0.7100 - lr: 0.0010
# Epoch 19/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.3898 - accuracy: 0.8229 - val_loss: 0.6325 - val_accuracy: 0.7020 - lr: 0.0010
# Epoch 20/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.3538 - accuracy: 0.8431 - val_loss: 0.6785 - val_accuracy: 0.7160 - lr: 0.0010
# Epoch 21/500
# 61/61 [==============================] - 3s 45ms/step - loss: 0.2989 - accuracy: 0.8696 - val_loss: 0.7941 - val_accuracy: 0.7080 - lr: 0.0010
# Epoch 22/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.2826 - accuracy: 0.8696 - val_loss: 0.8825 - val_accuracy: 0.6800 - lr: 0.0010
# Epoch 23/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.2668 - accuracy: 0.8836 - val_loss: 1.0334 - val_accuracy: 0.6880 - lr: 0.0010
# Epoch 24/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.2127 - accuracy: 0.9055 - val_loss: 0.9903 - val_accuracy: 0.6680 - lr: 0.0010
# Epoch 25/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.1817 - accuracy: 0.9213 - val_loss: 0.8931 - val_accuracy: 0.7140 - lr: 0.0010
# Epoch 26/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.1547 - accuracy: 0.9312 - val_loss: 1.2608 - val_accuracy: 0.6920 - lr: 0.0010
# Epoch 27/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.1276 - accuracy: 0.9426 - val_loss: 1.3583 - val_accuracy: 0.6860 - lr: 0.0010
# Epoch 28/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.1019 - accuracy: 0.9545 - val_loss: 1.5037 - val_accuracy: 0.7080 - lr: 0.0010
# Epoch 29/500
# 61/61 [==============================] - 3s 43ms/step - loss: 0.1428 - accuracy: 0.9377 - val_loss: 1.5495 - val_accuracy: 0.6980 - lr: 0.0010
# Epoch 30/500
# 61/61 [==============================] - 3s 46ms/step - loss: 0.1094 - accuracy: 0.9540 - val_loss: 1.7666 - val_accuracy: 0.6860 - lr: 0.0010
# Epoch 31/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.1058 - accuracy: 0.9553 - val_loss: 1.5940 - val_accuracy: 0.6820 - lr: 0.0010
# Epoch 32/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.0782 - accuracy: 0.9673 - val_loss: 1.7918 - val_accuracy: 0.6700 - lr: 0.0010
# Epoch 33/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.0792 - accuracy: 0.9670 - val_loss: 1.8459 - val_accuracy: 0.6920 - lr: 0.0010
# Epoch 34/500
# 61/61 [==============================] - 3s 45ms/step - loss: 0.0849 - accuracy: 0.9686 - val_loss: 2.0335 - val_accuracy: 0.6960 - lr: 0.0010
# Epoch 35/500
# 61/61 [==============================] - 3s 45ms/step - loss: 0.0469 - accuracy: 0.9816 - val_loss: 2.1930 - val_accuracy: 0.6660 - lr: 0.0010
# Epoch 36/500
# 61/61 [==============================] - 3s 44ms/step - loss: 0.0252 - accuracy: 0.9888 - val_loss: 2.3950 - val_accuracy: 0.6960 - lr: 0.0010

# %%
# !zip -r model.zip {NAME_MODEL} {NAME_PLOT}.png
# Out:
#   adding: model_push/ (stored 0%)
#   adding: model_push/assets/ (stored 0%)
#   adding: model_push/keras_metadata.pb (deflated 93%)
#   adding: model_push/fingerprint.pb (stored 0%)
#   adding: model_push/saved_model.pb (deflated 89%)
#   adding: model_push/variables/ (stored 0%)
#   adding: model_push/variables/variables.data-00000-of-00001 (deflated 22%)
#   adding: model_push/variables/variables.index (deflated 68%)
#   adding: test_push.png (deflated 8%)

# %% [markdown]
# ### Evaluate the Model

# %%
# Evaluate a Different Model From the one Just Trained
NAME_MODEL = ""

# %% [markdown]
# **Load the Model**

# %%
model = tfk.models.load_model(NAME_MODEL)
model.summary()
print()
# Out:
# Model: "Convnet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 96, 96, 3)]       0
#
#  conv00 (Conv2D)             (None, 96, 96, 32)        896
#
#  conv01 (Conv2D)             (None, 96, 96, 32)        9248
#
#  mp0 (MaxPooling2D)          (None, 48, 48, 32)        0
#
#  conv10 (Conv2D)             (None, 48, 48, 64)        18496
#
#  conv11 (Conv2D)             (None, 48, 48, 64)        36928
#
#  mp1 (MaxPooling2D)          (None, 24, 24, 64)        0
#
#  conv20 (Conv2D)             (None, 24, 24, 128)       73856
#
#  conv21 (Conv2D)             (None, 24, 24, 128)       147584
#
#  mp2 (MaxPooling2D)          (None, 12, 12, 128)       0
#
#  flatten (Flatten)           (None, 18432)             0
#
#  dense (Dense)               (None, 30)                552990
#
#  dense_1 (Dense)             (None, 20)                620
#
#  dense_2 (Dense)             (None, 10)                210
#
#  dense_3 (Dense)             (None, 30)                330
#
#  Output (Dense)              (None, 2)                 62
#
# =================================================================
# Total params: 841220 (3.21 MB)
# Trainable params: 841220 (3.21 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Evaluate**

# %%
# Training Comparison
train_predictions = model.predict(XT, verbose=0)
train_predictions = np.argmax(train_predictions, axis=-1)
train_gt = np.argmax(YT, axis=-1)
train_accuracy = accuracy_score(train_gt, train_predictions)
print(f'Accuracy Score over the Train Set: {round(train_accuracy, 4)}')
print()

# Validation Comparison
val_predictions = model.predict(XV, verbose=0)
val_predictions = np.argmax(val_predictions, axis=-1)
val_gt = np.argmax(YV, axis=-1)
val_accuracy = accuracy_score(val_gt, val_predictions)
print(f'Accuracy Score over the Validation Set: {round(val_accuracy, 4)}')
print()

# Test
test_predictions = model.predict(XT, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)
test_gt = np.argmax(YT, axis=-1)
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy Score over the Test Set: {round(test_accuracy, 4)}')
print()
# Out:
# Accuracy Score over the Train Set: 0.813
#
# Accuracy Score over the Validation Set: 0.74
#
# Accuracy Score over the Test Set: 0.813

# %% [markdown]
# ### Extra
